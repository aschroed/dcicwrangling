# %%
from dcicutils import ff_utils
from functions.wfr import *
from functions.wfr_settings import *
from functions.notebook_functions import *

# tibanna = Tibanna(env=env)
my_env = 'data'
my_auth = get_key('koray_data')

# %%
# url for repliseq exps
exp_types = ['Repli-seq']
set_url = '/search/?'+'&'.join(['experiments_in_set.experiment_type='+i for i in exp_types])+ \
          '&type=ExperimentSetReplicate&limit=all' + \
          '&status=pre-release&status=released&status=released%20to%20project'
run_sets = ff_utils.search_metadata(set_url ,key=my_auth)

add_pc = True
add_rel = False
add_wfr = False

counter = 0
all_sets = len(run_sets)
print(str(all_sets)+' total number of sets')

run_sets = [i for i in run_sets if "RepliSeq_Pipeline_v13.1"  not in i.get('completed_processes', [])]
run_sets = [i for i in run_sets if "RepliSeq_Pipeline_v14"  not in i.get('completed_processes', [])]

print(str(all_sets-len(run_sets))+ ' sets completed')


for a_set in run_sets: 
    counter += 1
    print()
    fastqpairs, organism, enzyme, bwa_ref, chrsize_ref, enz_ref, f_size, lab = find_pairs(a_set, my_env, lookfor = 'single')
    if not bwa_ref or not chrsize_ref:
        print(counter, a_set['accession'], organism, enzyme, 'skipping set with not chrsize/bwa index')
        continue  
    print(counter, a_set['accession'], enzyme, organism)      
    # cycle through the experiments
    for exp in fastqpairs.keys():
        if not fastqpairs.get(exp):
            print(exp, 'does not have any fastq files')
            continue
        # Check Part 1 and See if all are okay
        exp_bams = []
        part1 = 'done'
        # part2 = 'done'
        for pair in fastqpairs[exp]:
            #############
            pair_resp = ff_utils.get_metadata(pair, key=my_auth)
            attributions = get_attribution(pair_resp)
            report = get_wfr_out(pair, 'repliseq-parta', my_auth, ['v13.1', 'v14'])
            # if run is not successful
            if report['status'].startswith('no'):
                part1 = 'not done'
                if add_wfr:
                    inp_f = {'fastq':pair, 'chromsizes':chrsize_ref, 'bwaIndex':bwa_ref}
                    name_tag = pair.split('/')[2]
                    run_missing_wfr(step_settings('repliseq-parta', organism, attributions), inp_f, name_tag,my_auth, my_env)
            elif report['status'] == 'running':
                part1 = 'still running'
                print('part1 still running')
            # if successful
            else:
                assert report['status'] == 'complete'
                if add_pc:
                    # TODO check if the files already in processed files field.
                    # don't do it if they are already carried there.
                    print('Adding files to preliminary tab')
                    add_preliminary_processed_files(exp,
                                                    [report['bam'], report['bg']],
                                                    my_auth,
                                                    run_type='repliseq')
        # stop progress to part2 
        if part1 is not 'done':
            print(exp, 'has missing Part1 runs')
            part2 = 'not ready'
            part3 = 'not ready'
            continue
        print(exp, 'part1 complete')
# Out:
# 69 total number of sets
# 0 sets completed
#
# 1 4DNESO4HIS4U None mouse
# part1 still running
# 4DNEXTX3GU66 has missing Part1 runs
#
# 2 4DNESOE7IW9E None mouse
# Adding files to preliminary tab
# 4DNEX5732QDS part1 complete
#
# 3 4DNESSQCYHJB None mouse
# Adding files to preliminary tab
# 4DNEXYAAVQBY part1 complete
#
# 4 4DNESRX5DC6I None mouse
# Adding files to preliminary tab
# 4DNEX6E89VM9 part1 complete
#
# 5 4DNES9IB8HW3 None mouse
# Adding files to preliminary tab
# 4DNEXUN22XKF part1 complete
# Adding files to preliminary tab
# 4DNEX7ML7KID part1 complete
#
# 6 4DNESMZPCTLH None mouse
# Adding files to preliminary tab
# 4DNEXP6VC66C part1 complete
# Adding files to preliminary tab
# 4DNEXU21ER4O part1 complete
#
# 7 4DNESVQW7LXZ None mouse
# Adding files to preliminary tab
# 4DNEX7JW78MW part1 complete
# Adding files to preliminary tab
# 4DNEXS9PR6LY part1 complete
#
# 8 4DNESW9JK6G9 None mouse
# Adding files to preliminary tab
# 4DNEXE4QKHFL part1 complete
# Adding files to preliminary tab
# 4DNEX3E37VBC part1 complete
#
# 9 4DNESPE1BXOP None mouse
# Adding files to preliminary tab
# 4DNEXU72BIPV part1 complete
# Adding files to preliminary tab
# 4DNEXSKDHYQO part1 complete
#
# 10 4DNESAA7V4EC None mouse
# Adding files to preliminary tab
# 4DNEX8NT78XN part1 complete
# Adding files to preliminary tab
# 4DNEXG45T8GF part1 complete
#
# 11 4DNESD6TY736 None mouse
# Adding files to preliminary tab
# 4DNEX72ET7J8 part1 complete
# Adding files to preliminary tab
# 4DNEX1AG97JZ part1 complete
#
# 12 4DNESV5WY2NW None mouse
# Adding files to preliminary tab
# 4DNEXTLJQMDK part1 complete
# Adding files to preliminary tab
# 4DNEX25JIFPV part1 complete
#
# 13 4DNES5CPWZO4 None mouse
# Adding files to preliminary tab
# 4DNEXXXU3DTR part1 complete
# Adding files to preliminary tab
# 4DNEXM2UNXEN part1 complete
#
# 14 4DNESEIP9JB8 None mouse
# Adding files to preliminary tab
# 4DNEX1PNZCSE part1 complete
# Adding files to preliminary tab
# 4DNEXMQGS95Y part1 complete
#
# 15 4DNESBH1KQ7G None mouse
# Adding files to preliminary tab
# 4DNEXGNXDTG9 part1 complete
# Adding files to preliminary tab
# 4DNEXFOCJ852 part1 complete
#
# 16 4DNESVK9AIPJ None mouse
# Adding files to preliminary tab
# 4DNEXX87267M part1 complete
# Adding files to preliminary tab
# 4DNEXFDKGDSS part1 complete
#
# 17 4DNES7ZVDD5G None mouse
# Adding files to preliminary tab
# 4DNEXLPEFEIU part1 complete
# Adding files to preliminary tab
# 4DNEXQLHK5EN part1 complete
#
# 18 4DNESGRJK3LU None mouse
# Adding files to preliminary tab
# 4DNEXJNJKLUG part1 complete
# Adding files to preliminary tab
# 4DNEX2EXD4WB part1 complete
#
# 19 4DNES5P96TIY None mouse
# Adding files to preliminary tab
# 4DNEXHIN8KF5 part1 complete
# Adding files to preliminary tab
# 4DNEXKHPKZFI part1 complete
#
# 20 4DNESLIKKM2F None mouse
# Adding files to preliminary tab
# 4DNEXW5RQ15L part1 complete
# Adding files to preliminary tab
# 4DNEXH2LQR64 part1 complete
#
# 21 4DNESXNJ6FWX None mouse
# Adding files to preliminary tab
# 4DNEX1KN1SV1 part1 complete
# Adding files to preliminary tab
# 4DNEX2RMNOEZ part1 complete
#
# 22 4DNES1NKQNGW None mouse
# Adding files to preliminary tab
# 4DNEX1ASL1SF part1 complete
# Adding files to preliminary tab
# 4DNEXYTC9LEW part1 complete
#
# 23 4DNESJCH5NIA None mouse
# Adding files to preliminary tab
# 4DNEXIAZRUKE part1 complete
# Adding files to preliminary tab
# 4DNEXO4RRV41 part1 complete
#
# 24 4DNESEIOZ1JZ None mouse
# Adding files to preliminary tab
# 4DNEXT6IWWQ8 part1 complete
# Adding files to preliminary tab
# 4DNEXO97VYLS part1 complete
#
# 25 4DNESQXT7DOB None mouse
# Adding files to preliminary tab
# 4DNEX7IY9NLE part1 complete
# Adding files to preliminary tab
# 4DNEXQI7U38O part1 complete
#
# 26 4DNESRCO9ALV None mouse
# Adding files to preliminary tab
# 4DNEXNKDJI6I part1 complete
# Adding files to preliminary tab
# 4DNEX6OHZSTN part1 complete
#
# 27 4DNESPQHCGPU None mouse
# Adding files to preliminary tab
# 4DNEXSNIMVF7 part1 complete
# Adding files to preliminary tab
# 4DNEXACA468U part1 complete
#
# 28 4DNESO4WHZFT None mouse
# Adding files to preliminary tab
# 4DNEXHZIA1J7 part1 complete
# Adding files to preliminary tab
# 4DNEXPJZ4RQW part1 complete
#
# 29 4DNESXUM27JA None mouse
# Adding files to preliminary tab
# 4DNEXL2YLP84 part1 complete
#
# 30 4DNESVFSED4R None mouse
# Adding files to preliminary tab
# 4DNEXIOXOQ86 part1 complete
#
# 31 4DNESUZ3Y5GY None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFI5MKWJBS/ is already in processed files
# 4DNEXG6HJJ27 part1 complete
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFI3EJQYVH/ is already in processed files
# 4DNEXE23WWO1 part1 complete
#
# 32 4DNESIV168N6 None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIQOEL7NP/ is already in processed files
# 4DNEXVRTS3VG part1 complete
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIOG2PA4G/ is already in processed files
# 4DNEXELBLZ37 part1 complete
#
# 33 4DNESXZ2IL4M None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIRAMWYVC/ is already in processed files
# 4DNEXKP295JF part1 complete
#
# 34 4DNESJOH66ZZ None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIZKC814T/ is already in processed files
# 4DNEXYX58PCM part1 complete
#
# 35 4DNESQ3ZDLZM None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIHNZT64Y/ is already in processed files
# 4DNEXCTB91SG part1 complete
#
# 36 4DNES98TS7X2 None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFI79HUNBK/ is already in processed files
# 4DNEXXIXTTXI part1 complete
#
# 37 4DNESX6MGDN2 None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIE64Y5I7/ is already in processed files
# 4DNEXLVWLA33 part1 complete
#
# 38 4DNES6O1SJ4O None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFISTD47QS/ is already in processed files
# 4DNEX1BWBWFA part1 complete
#
# 39 4DNESWS6UT74 None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIPOU7VFY/ is already in processed files
# 4DNEXZPBA82F part1 complete
#
# 40 4DNESBAF7EW5 None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFILZMYWJV/ is already in processed files
# 4DNEXDWEK1ME part1 complete
#
# 41 4DNES9OZNM6T None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIDL87H1F/ is already in processed files
# 4DNEXTM3PBS3 part1 complete
#
# 42 4DNESDFQDLQJ None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIKF3BXRX/ is already in processed files
# 4DNEX8K5TT7Y part1 complete
#
# 43 4DNES3DSRT51 None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIM2ZYTN6/ is already in processed files
# 4DNEXS77PTUK part1 complete
#
# 44 4DNES7OJ7U7X None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIKDFHR5X/ is already in processed files
# 4DNEXQ4EXW3K part1 complete
#
# 45 4DNESLS88OS7 None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFII8Q1YGF/ is already in processed files
# 4DNEXEQB7RNA part1 complete
#
# 46 4DNESDUJHQ6J None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFI37ID2F1/ is already in processed files
# 4DNEX5M9XSGK part1 complete
#
# 47 4DNESCBR4664 None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFITPBC44Z/ is already in processed files
# 4DNEXKCP8338 part1 complete
#
# 48 4DNESJNUUJ66 None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFISZGVUWC/ is already in processed files
# 4DNEXL6WTINA part1 complete
#
# 49 4DNES5PW6NSG None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIICI1L91/ is already in processed files
# 4DNEXDRZLEQV part1 complete
#
# 50 4DNESSV33VOL None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIYILD5UK/ is already in processed files
# 4DNEX63QU5GZ part1 complete
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIB9CLU8G/ is already in processed files
# 4DNEXTG6XPXD part1 complete
#
# 51 4DNESH4XLJCW None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFI9L73HUJ/ is already in processed files
# 4DNEXRK56264 part1 complete
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIBP53I7K/ is already in processed files
# 4DNEXR87VFPR part1 complete
#
# 52 4DNES99LXRYK None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFID7HY47P/ is already in processed files
# 4DNEXWNB33S2 part1 complete
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFILHPONIU/ is already in processed files
# 4DNEX25G1FKX part1 complete
#
# 53 4DNES1P18J2X None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFI8TYILWA/ is already in processed files
# 4DNEXAM4T83J part1 complete
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFI1H8WB3W/ is already in processed files
# 4DNEXBL1Y5N4 part1 complete
#
# 54 4DNESLC8TDK4 None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIH9EFTYP/ is already in processed files
# 4DNEXAPQBU2M part1 complete
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIA5J1HN7/ is already in processed files
# 4DNEX6SUB7CY part1 complete
#
# 55 4DNESSYKYIK3 None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIBQM2JE2/ is already in processed files
# 4DNEXLRK3X6D part1 complete
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIR425JJG/ is already in processed files
# 4DNEXVQ9XCJ5 part1 complete
#
# 56 4DNES1GSPUT8 None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIUJYKO5L/ is already in processed files
# 4DNEXPCVJ25I part1 complete
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIBQEJWSP/ is already in processed files
# 4DNEXKWN7CZT part1 complete
#
# 57 4DNES9YA22WT None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIHPS1DZ8/ is already in processed files
# 4DNEXBCDJFX9 part1 complete
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFI1WWQ6AF/ is already in processed files
# 4DNEXXZUM1J1 part1 complete
#
# 58 4DNES1PHNYOP None mouse
# Adding files to preliminary tab
# 4DNEX14L7KXP part1 complete
# Adding files to preliminary tab
# 4DNEXTTY1KTG part1 complete
#
# 59 4DNESWPIPVZT None mouse
# Adding files to preliminary tab
# 4DNEXWTU45NI part1 complete
# Adding files to preliminary tab
# 4DNEX91MUU81 part1 complete
#
# 60 4DNEST651P8O None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFI9JYRUGT/ is already in processed files
# 4DNEXK7XIMBW part1 complete
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFI2HZCEYH/ is already in processed files
# 4DNEXB7RB9KT part1 complete
#
# 61 4DNESJQH3HJ9 None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIKCV8QL5/ is already in processed files
# 4DNEX9GKA2OI part1 complete
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIHU1PSXI/ is already in processed files
# 4DNEXUFNTG8J part1 complete
#
# 62 4DNES674QWXK None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIFP1SCJH/ is already in processed files
# 4DNEXCDJJVUR part1 complete
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIFD3XT3O/ is already in processed files
# 4DNEX9CR3FWQ part1 complete
#
# 63 4DNESUNOW1OZ None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIHCZL68R/ is already in processed files
# 4DNEXMFJRLJN part1 complete
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIRMB9LUC/ is already in processed files
# 4DNEX1HYSKMF part1 complete
#
# 64 4DNES4CEYDPH None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFILOS11M4/ is already in processed files
# 4DNEX8I12H9D part1 complete
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFI4ZOW6FT/ is already in processed files
# 4DNEXGRP461A part1 complete
#
# 65 4DNES8128EIS None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIYQQ8I63/ is already in processed files
# 4DNEXJFQRJ38 part1 complete
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIVHBBG38/ is already in processed files
# 4DNEXMHCH1TT part1 complete
#
# 66 4DNESUJC9Y83 None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIX4MY59B/ is already in processed files
# 4DNEXSA3QR2O part1 complete
# Adding files to preliminary tab
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIMOR9IMU/ is already in processed files
# 4DNEXN62FHTX part1 complete
#
# 67 4DNES4B7RLAV None human
# Adding files to preliminary tab
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIRSSCVBK/ is already in processed files
# 4DNEXWR7XY8S part1 complete
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIMYCZPSM/ is already in processed files
# 4DNEX6GMB44Z part1 complete
#
# 68 4DNESDQ9PZOX None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFIROE97WV/ is already in processed files
# 4DNEXFBHF2ZI part1 complete
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFITBZJOYT/ is already in processed files
# 4DNEXGZEOJE6 part1 complete
#
# 69 4DNESO83H9ZI None human
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFITDJP8AY/ is already in processed files
# 4DNEXI55T28T part1 complete
# Adding files to preliminary tab
# Error - Cannot add files to pc
# /files-processed/4DNFI6BFDXRX/ is already in processed files
# 4DNEXF2KKZF1 part1 complete

# %%
# Move files from opc to pc
from dcicutils import ff_utils
from functions.notebook_functions import *
from functions.wfr import *

action = True

# get key from keypairs.json
my_key = get_key('koray_data')
# which sets to move data
set_url = '/search/?experiments_in_set.experiment_type=Repli-seq&type=ExperimentSetReplicate&limit=all'

set_url = '/search/?type=ExperimentSetReplicate&experiments_in_set.experiment_type=Repli-seq&experiments_in_set.biosample.biosource.individual.organism.name=mouse'


# move other processed files to processed files field
def move_opc_to_pc(resp, move_title, con_key):
    opc = resp.get('other_processed_files')
    pc = resp.get('processed_files')
    # if processed_files field already has values, exit
    if pc:
        print('There are files in processed_files field, expected empty')
        return False
    # are there files in opc
    if not opc:
        print('there are no other processed files, skipping')
        return False
    # see if there are other_processed_files to move
    if opc:
        titles = [i['title'] for i in opc]
        if move_title in titles:
            print(resp['accession'], 'files will move')
            move_item = [i for i in opc if i['title'] == move_title]
            assert len(move_item) == 1
            assert move_item[0]['type'] == 'preliminary'
            new_pc = move_item[0]['files']
            new_opc = [i for i in opc if i['title'] != move_title]
            # Time to patch
            patch_data = {}
            add_on = ""
            #if there is something left in opc, patch it, if not delete field
            if new_opc:
                patch_data['other_processed_files'] = opc
            else:
                add_on = 'delete_fields=other_processed_files'
            # patch with processed files
            patch_data['processed_files'] = new_pc
            if action: 
                ff_utils.patch_metadata(patch_data, resp['uuid'], key = con_key, add_on = add_on)
                # update status of pc to status of set or exp
                release_files(resp['uuid'], new_pc, con_key)
            return True
        else:
            return False

        
        

run_sets = ff_utils.search_metadata(set_url , key=my_key)
set_w_apf = 0
exp_w_apf = 0
counter = 0
#move_title = 'HiC Processing Pipeline - Preliminary Files'
move_title = "Repli-Seq Pipeline - Preliminary Files"

print(len(run_sets), 'experiment sets in scope')
for a_set in run_sets:
    set_resp = ff_utils.get_metadata(a_set['uuid'],key=my_key, add_on='frame=raw')
    counter += 1
    print(counter, set_resp['accession'])
    exps = set_resp['experiments_in_set']
    res =  move_opc_to_pc(set_resp, move_title, my_key)
    if res:
        set_w_apf += 1
        print(set_resp['accession'], 'moved to pc')
  
    for exp in exps:
        exp_resp = ff_utils.get_metadata(exp, key=my_key, add_on='frame=raw')
        res_e =  move_opc_to_pc(exp_resp,move_title,my_key)
        if res_e:
            exp_w_apf += 1
            print(exp_resp['accession'], 'moved to pc')
    print()

print(set_w_apf)
print(exp_w_apf)
# Out:
# 32 experiment sets in scope
# 1 4DNESO4HIS4U
# there are no other processed files, skipping
# there are no other processed files, skipping
#
# 2 4DNESOE7IW9E
# there are no other processed files, skipping
# 4DNEX5732QDS files will move
# 4DNEX5732QDS moved to pc
#
# 3 4DNESSQCYHJB
# there are no other processed files, skipping
# 4DNEXYAAVQBY files will move
# 4DNEXYAAVQBY moved to pc
#
# 4 4DNESRX5DC6I
# there are no other processed files, skipping
# 4DNEX6E89VM9 files will move
# 4DNEX6E89VM9 moved to pc
#
# 5 4DNES9IB8HW3
# there are no other processed files, skipping
# 4DNEX7ML7KID files will move
# 4DNEX7ML7KID moved to pc
# 4DNEXUN22XKF files will move
# 4DNEXUN22XKF moved to pc
#
# 6 4DNESMZPCTLH
# there are no other processed files, skipping
# 4DNEXU21ER4O files will move
# 4DNEXU21ER4O moved to pc
# 4DNEXP6VC66C files will move
# 4DNEXP6VC66C moved to pc
#
# 7 4DNESVQW7LXZ
# there are no other processed files, skipping
# 4DNEX7JW78MW files will move
# 4DNEX7JW78MW moved to pc
# 4DNEXS9PR6LY files will move
# 4DNEXS9PR6LY moved to pc
#
# 8 4DNESW9JK6G9
# there are no other processed files, skipping
# 4DNEX3E37VBC files will move
# 4DNEX3E37VBC moved to pc
# 4DNEXE4QKHFL files will move
# 4DNEXE4QKHFL moved to pc
#
# 9 4DNESPE1BXOP
# there are no other processed files, skipping
# 4DNEXU72BIPV files will move
# 4DNEXU72BIPV moved to pc
# 4DNEXSKDHYQO files will move
# 4DNEXSKDHYQO moved to pc
#
# 10 4DNESAA7V4EC
# there are no other processed files, skipping
# 4DNEXG45T8GF files will move
# 4DNEXG45T8GF moved to pc
# 4DNEX8NT78XN files will move
# 4DNEX8NT78XN moved to pc
#
# 11 4DNESD6TY736
# there are no other processed files, skipping
# 4DNEX72ET7J8 files will move
# 4DNEX72ET7J8 moved to pc
# 4DNEX1AG97JZ files will move
# 4DNEX1AG97JZ moved to pc
#
# 12 4DNESV5WY2NW
# there are no other processed files, skipping
# 4DNEXTLJQMDK files will move
# 4DNEXTLJQMDK moved to pc
# 4DNEX25JIFPV files will move
# 4DNEX25JIFPV moved to pc
#
# 13 4DNES5CPWZO4
# there are no other processed files, skipping
# 4DNEXM2UNXEN files will move
# 4DNEXM2UNXEN moved to pc
# 4DNEXXXU3DTR files will move
# 4DNEXXXU3DTR moved to pc
#
# 14 4DNESEIP9JB8
# there are no other processed files, skipping
# 4DNEXMQGS95Y files will move
# 4DNEXMQGS95Y moved to pc
# 4DNEX1PNZCSE files will move
# 4DNEX1PNZCSE moved to pc
#
# 15 4DNESBH1KQ7G
# there are no other processed files, skipping
# 4DNEXGNXDTG9 files will move
# 4DNEXGNXDTG9 moved to pc
# 4DNEXFOCJ852 files will move
# 4DNEXFOCJ852 moved to pc
#
# 16 4DNESVK9AIPJ
# there are no other processed files, skipping
# 4DNEXFDKGDSS files will move
# 4DNEXFDKGDSS moved to pc
# 4DNEXX87267M files will move
# 4DNEXX87267M moved to pc
#
# 17 4DNES7ZVDD5G
# there are no other processed files, skipping
# 4DNEXQLHK5EN files will move
# 4DNEXQLHK5EN moved to pc
# 4DNEXLPEFEIU files will move
# 4DNEXLPEFEIU moved to pc
#
# 18 4DNESGRJK3LU
# there are no other processed files, skipping
# 4DNEX2EXD4WB files will move
# 4DNEX2EXD4WB moved to pc
# 4DNEXJNJKLUG files will move
# 4DNEXJNJKLUG moved to pc
#
# 19 4DNES5P96TIY
# there are no other processed files, skipping
# 4DNEXHIN8KF5 files will move
# 4DNEXHIN8KF5 moved to pc
# 4DNEXKHPKZFI files will move
# 4DNEXKHPKZFI moved to pc
#
# 20 4DNESLIKKM2F
# there are no other processed files, skipping
# 4DNEXW5RQ15L files will move
# 4DNEXW5RQ15L moved to pc
# 4DNEXH2LQR64 files will move
# 4DNEXH2LQR64 moved to pc
#
# 21 4DNESXNJ6FWX
# there are no other processed files, skipping
# 4DNEX1KN1SV1 files will move
# 4DNEX1KN1SV1 moved to pc
# 4DNEX2RMNOEZ files will move
# 4DNEX2RMNOEZ moved to pc
#
# 22 4DNES1NKQNGW
# there are no other processed files, skipping
# 4DNEXYTC9LEW files will move
# 4DNEXYTC9LEW moved to pc
# 4DNEX1ASL1SF files will move
# 4DNEX1ASL1SF moved to pc
#
# 23 4DNESJCH5NIA
# there are no other processed files, skipping
# 4DNEXIAZRUKE files will move
# 4DNEXIAZRUKE moved to pc
# 4DNEXO4RRV41 files will move
# 4DNEXO4RRV41 moved to pc
#
# 24 4DNESEIOZ1JZ
# there are no other processed files, skipping
# 4DNEXT6IWWQ8 files will move
# 4DNEXT6IWWQ8 moved to pc
# 4DNEXO97VYLS files will move
# 4DNEXO97VYLS moved to pc
#
# 25 4DNESQXT7DOB
# there are no other processed files, skipping
# 4DNEX7IY9NLE files will move
# 4DNEX7IY9NLE moved to pc
# 4DNEXQI7U38O files will move
# 4DNEXQI7U38O moved to pc
#
# 26 4DNESRCO9ALV
# there are no other processed files, skipping
# 4DNEXNKDJI6I files will move
# 4DNEXNKDJI6I moved to pc
# 4DNEX6OHZSTN files will move
# 4DNEX6OHZSTN moved to pc
#
# 27 4DNESPQHCGPU
# there are no other processed files, skipping
# 4DNEXACA468U files will move
# 4DNEXACA468U moved to pc
# 4DNEXSNIMVF7 files will move
# 4DNEXSNIMVF7 moved to pc
#
# 28 4DNESO4WHZFT
# there are no other processed files, skipping
# 4DNEXHZIA1J7 files will move
# 4DNEXHZIA1J7 moved to pc
# 4DNEXPJZ4RQW files will move
# 4DNEXPJZ4RQW moved to pc
#
# 29 4DNESXUM27JA
# there are no other processed files, skipping
# 4DNEXL2YLP84 files will move
# 4DNEXL2YLP84 moved to pc
#
# 30 4DNESVFSED4R
# there are no other processed files, skipping
# 4DNEXIOXOQ86 files will move
# 4DNEXIOXOQ86 moved to pc
#
# 31 4DNES1PHNYOP
# there are no other processed files, skipping
# 4DNEXTTY1KTG files will move
# 4DNEXTTY1KTG moved to pc
# 4DNEX14L7KXP files will move
# 4DNEX14L7KXP moved to pc
#
# 32 4DNESWPIPVZT
# there are no other processed files, skipping
# 4DNEX91MUU81 files will move
# 4DNEX91MUU81 moved to pc
# 4DNEXWTU45NI files will move
# 4DNEXWTU45NI moved to pc
#
# 0
# 57

# %%
# Repliseq pipeline part 1 also produces a qc object on the files.
# Change their status to the ones of the files (if the files are in processed files field)

set_url = '/search/?experiments_in_set.experiment_type=Repli-seq&type=ExperimentSetReplicate&limit=all'

set_url = '/search/?type=ExperimentSetReplicate&experiments_in_set.experiment_type=Repli-seq&experiments_in_set.biosample.biosource.individual.organism.name=mouse'


run_sets = ff_utils.search_metadata(set_url , key=my_key)

def release_qc(file_id, con_key):
    file_resp = ff_utils.get_metadata(file_id, key=con_key, add_on = 'frame=raw')
    file_status = file_resp['status']
    # skip if file is not released/archived
    if file_status not in ['released', 'released to project', 'archived']:
        return
    qc = file_resp.get('quality_metric')
    if qc:
        qc_resp = ff_utils.get_metadata(qc, key=con_key)
        qc_status = qc_resp['status']
    else:
        return
    
    if qc_status != file_status:
        ff_utils.patch_metadata({'status': file_status}, obj_id=qc, key=con_key)
        print(qc, 'qc object updated with status', file_status)
        return True
    
print(len(run_sets), 'experiment sets in scope')
for a_set in run_sets:
    set_resp = ff_utils.get_metadata(a_set['uuid'],key=my_key, add_on='frame=raw')
    if set_resp.get('processed_files'):
        for a_pf in set_resp['processed_files']:
            release_qc(a_pf, my_key)
            
    exps = set_resp['experiments_in_set']
    for exp in exps:
        exp_resp = ff_utils.get_metadata(exp, key=my_key, add_on='frame=raw')
        if exp_resp.get('processed_files'):
            for a_pf_e in exp_resp['processed_files']:
                release_qc(a_pf_e, my_key)
# Out:
# 32 experiment sets in scope
# 3cce6087-5774-4488-9112-bc60c0e1a3de qc object updated with status released
# 975ef8a5-e82e-4a5a-8b88-7ce15046655c qc object updated with status released
# afff87e2-dfbb-4b32-bc90-e74d689294e5 qc object updated with status released
# 43ff85c2-e770-48b8-b223-21a4c12adf56 qc object updated with status released
# f71cd6c3-a1d5-448f-9da0-408e125dfde9 qc object updated with status released
# 8011ad58-c1bd-482b-b60a-46226e53cb38 qc object updated with status released
# f9b6a279-46e3-4e93-ae2b-cb2e1c985ee2 qc object updated with status released
# 3aafc7a5-b32d-4596-91cc-a25dd1ec4eda qc object updated with status released
# 968d85ee-b1d6-4a11-a416-4dac52b0beed qc object updated with status released
# 8d47d9c5-ec00-4399-a989-a767076a2cbb qc object updated with status released
# 91780248-320c-42cc-993b-73e64892b75d qc object updated with status released
# 630cc086-2969-4b1f-9c28-077a3e55f19a qc object updated with status released
# 7a7ebf38-634e-4a58-a137-436b807fb279 qc object updated with status released
# b51a23ca-7b54-49be-b35e-8a4c5360bb1f qc object updated with status released
# 2737fde1-f08e-47e9-8f76-09a23aae4e4e qc object updated with status released
# 00505af3-d6b7-4a0e-a24e-8e360f46314f qc object updated with status released
# 51c30954-dc79-4973-a594-ddad08797af1 qc object updated with status released
# f823587c-a61d-4ee6-b518-33b3e376bd91 qc object updated with status released
# e2265b93-357f-4187-a0d4-4dbb190b22ef qc object updated with status released
# d64abfb3-aa73-492e-b2be-0a9218c11271 qc object updated with status released
# c4280b2b-7a61-4a40-9aec-669390e6cedd qc object updated with status released
# 1e8ad061-3845-4c81-9351-29b0a57d5542 qc object updated with status released
# 43e72844-e990-4a9c-83e4-05981b8d2df9 qc object updated with status released
# a0c85707-fbc5-461c-b108-2e0c6cd59e52 qc object updated with status released
# a9002a57-db99-4dbf-969c-7893a2249010 qc object updated with status released
# 2d25c7a2-a3cf-4943-864a-3ca5ae050099 qc object updated with status released
# 8d4adfe4-dd7a-476a-b331-1b098e2d51e5 qc object updated with status released
# 36c6f347-7d72-4ffd-8ed9-54b220a25037 qc object updated with status released
# 50e07fe5-3de3-45f2-b5eb-7b8e6ca2c9c2 qc object updated with status released
# e5e98f44-4e37-44da-b523-36c8d9647f5f qc object updated with status released
