# %% [markdown]
# ### PLEASE COPY NOTEBOOKS TO YOUR FOLDERS TO PREVENT COMMIT CONFLICTS
# * If you would like to contribute to this notebook, make changes on it in useful_notebooks folder, run "Restart and Clear Output" before commit.
#
# #### Unexpected Expansion Cases
# ###### Experiment set fetches unrealated labs and awards
# Sometimes a fetch will get some unrelated labs and awards, this is because of the multiple awards a lab can have. This multiple awards are visited, which have users linked to them. This users also have labs, so here you go. Hopefully all are released/current already.
#
# ###### Experiment set fetches unrealted biosmaple/experiment/set
# This was so far because of the experiment and biosample relation field, or the references field that links to a publication. If you ignore these fields, if should be fine.
# `ignore_field = ['experiment_relation', 'biosample_relation', 'references']`

# %%
from dcicutils import ff_utils
from functions.notebook_functions import *
from functions.cleanup import *
import time
time1 = time.time()

my_auth = get_key('koray_data')

# Please Modify the following accordingly 
# do you want to check for duplicate/problematic runs on files?
# it will take some time
check_wfrs = True
delete_problematic = False

# Which status to change
change_status = 'released'

sets_in_scope = [] # ['4DNACCCC', '4DNACCCCC']
search_url = "/search/?experiments_in_set.experiment_type=dilution+Hi-C&experimentset_type=replicate&lab.display_title=Bing+Ren%2C+UCSD&status=pre-release&type=ExperimentSetReplicate"  # "/search/type=AAAAAAAA"


if sets_in_scope:
    set_to_release = [ff_utils.get_metadata(i, my_auth)['uuid'] for i in sets_in_scope]
elif search_url:
    set_to_release = [i['uuid'] for i in ff_utils.search_metadata(search_url, my_auth)]

store={}
item_uuids=[]

store, uuids = ff_utils.expand_es_metadata(set_to_release, my_auth, store_frame='object',add_pc_wfr=True, ignore_field = ['experiment_relation', 'biosample_relation', 'references'])

print(len(store['experiment_set_replicate']), 'exp sets for status change')
print(len(uuids), 'items collected')
time2 = time.time()
print(round((time2-time1), 1), 'sec for collection')

for i in store:
    print(i, len(store[i]))
# Out:
# 10 exp sets for status change
# 1016 items collected
# 6.6 sec for collection
# enzyme 1
# workflow 13
# software 12
# individual_human 10
# static_section 2
# award 7
# vendor 2
# workflow_run_awsem 381
# biosource 10
# higlass_view_config 11
# user 14
# biosample 20
# file_format 15
# biosample_cell_culture 20
# file_fastq 128
# organism 1
# experiment_hi_c 20
# quality_metric_pairsqc 23
# file_processed 152
# ontology_term 24
# experiment_set_replicate 10
# ontology 2
# file_reference 3
# protocol 2
# quality_metric_fastqc 128
# lab 5

# %%
# TODO
# Check audits

# to decide which items to ignore as they have a 'higher' status
STATUS_LEVEL = {
    # standard_status
    "released": 10, "current": 10,
    "released to project": 9,
    "pre-release": 8,
    "planned": 6, "submission in progress": 6,
    "in review by lab": 4,
    "revoked": 0, "archived": 0,"deleted": 0, "obsolete": 0, "replaced": 0, "archived to project": 0,
    # additional file statuses
    'to be uploaded by workflow': 4, 'uploading': 4, 'uploaded': 4, 'upload failed': 4, 'draft': 4, 'released to lab': 4}

change_level = STATUS_LEVEL.get(change_status, 1)

# check expsets
print('EXPSET CHECK')
for a_set in store['experiment_set_replicate']:
    if not a_set.get('completed_processes'):
        print(a_set['accession'], 'missing processing tag', a_set['description'][:50])

# check exps 
print('\nEXP CHECK')
# check for experiment numbers
exp_names = [i for i in store if i.startswith('experiment') and not i.startswith('experiment_set')]
all_exps_on_sets = [a for i in store['experiment_set_replicate'] for a in i['experiments_in_set']]
all_exps = [a['uuid'] for i in store.keys() for a in store[i] if i in exp_names]
if len(all_exps_on_sets) != len(all_exps):
    print('Number of experiments is not same as experiments associated with sets')
    print('# of exps: {}. # of exps on sets: {}'.format(len(all_exps), len(all_exps_on_sets)))
        
print('\nFILE FASTQ CHECK')
for a_file in store['file_fastq']:
    if not a_file.get('quality_metric'):
        print(a_file['accession'], 'missing fastqc')
    if not a_file.get('content_md5sum'):
        print(a_file['accession'], 'missing content md5 sum')
    if not a_file.get('md5sum'):
        print(a_file['accession'], 'md5 was not calculated during upload, missing md5sum')
    if check_wfrs:
        pass
        # dw = delete_wfrs(a_file, my_auth, delete=delete_problematic)

# check processed files
print('\nFILE PROCESSED CHECK')
if store.get('file_processed'):
    for a_file in store['file_processed']:
        if a_file['description'] == 'This is an intermediate file in the HiC processing pipeline':
            print(a_file['accession'], 'is from bwa-mem', a_file['date_created'][:16], end = "---")
            
#         if a_file['file_format'] == '/file-formats/pairs/':
#             if not a_file.get('quality_metric'):
#                 print(a_file['accession'], 'missing Pairsqc')
            if not a_file.get('source_experiments'):
                print('and has no source_experiment')
            else:
                print('is okay')
#             print(a_file['accession'], 'user submitted or produced by sbg runs')
#             print(a_file['description'], a_file['file_format'])
#         if check_wfrs:
#             pass
#             #dw = delete_wfrs(a_file, my_auth, delete=delete_problematic)   

# check wfrs
print('\nWFR CHECK')
# list all wf types found
print('  Following run types are found:')
for wf in set([i['display_title'].split(' run')[0] for i in store.get('workflow_run_awsem')]):
           print('    ' + wf)
if store.get('workflow_run_awsem'):
    for wfr in store['workflow_run_awsem']:
        if wfr['run_status'] != 'complete':
            print('problematic wfr', wfr['uuid'], wfr['run_status'])
        
# check for weird status
print('\nREPORT NUMBERS AND CHECK STATUS')
for i in store:
    print(i, len(store[i]))
    weird = [[i, x['uuid'], x['status']] for x in store[i] if STATUS_LEVEL.get(x['status']) == 0]
    if weird:
        for case in weird:
            print(case)
        print()
# Out:
# EXPSET CHECK
#
# EXP CHECK
#
# FILE FASTQ CHECK
#
# FILE PROCESSED CHECK
# 4DNFIXAHPX8O is from bwa-mem 2019-04-03T03:49---and has no source_experiment
# 4DNFIQLX8ML3 is from bwa-mem 2019-04-03T03:50---and has no source_experiment
# 4DNFIGR8VY1N is from bwa-mem 2019-04-03T03:51---is okay
# 4DNFIVBMB876 is from bwa-mem 2019-04-03T03:52---is okay
# 4DNFII8A81CH is from bwa-mem 2019-04-03T03:54---is okay
# 4DNFIDC612G8 is from bwa-mem 2019-04-03T03:52---is okay
# 4DNFIGNDJGGK is from bwa-mem 2019-04-03T03:51---is okay
# 4DNFIG6EF1Y9 is from bwa-mem 2019-04-03T03:52---is okay
# 4DNFIOURJS5S is from bwa-mem 2019-04-03T03:50---is okay
# 4DNFI22795UJ is from bwa-mem 2019-04-02T18:07---is okay
# 4DNFILNVV8V1 is from bwa-mem 2019-04-03T03:54---is okay
# 4DNFI3E7BB96 is from bwa-mem 2019-04-03T03:51---is okay
# 4DNFIE4Q1JSE is from bwa-mem 2019-04-03T03:54---is okay
# 4DNFIAUZ245Z is from bwa-mem 2019-04-03T03:51---is okay
# 4DNFI4Y9R7M4 is from bwa-mem 2019-04-03T03:51---is okay
# 4DNFIGSWDZKT is from bwa-mem 2019-04-03T03:51---is okay
# 4DNFIWLAIUZ6 is from bwa-mem 2019-04-03T03:53---is okay
# 4DNFI284FIB5 is from bwa-mem 2019-04-03T03:49---is okay
# 4DNFIKAJ7AKY is from bwa-mem 2019-04-02T18:14---is okay
# 4DNFIHFX97MK is from bwa-mem 2019-04-03T03:50---is okay
# 4DNFIGY9NA58 is from bwa-mem 2019-04-03T03:54---is okay
# 4DNFI3IK3NXY is from bwa-mem 2019-04-02T18:14---is okay
# 4DNFIVAOBQLA is from bwa-mem 2019-04-03T03:49---is okay
# 4DNFIXTZ71Z9 is from bwa-mem 2019-04-03T03:52---and has no source_experiment
# 4DNFINM9EAY3 is from bwa-mem 2019-04-03T03:51---is okay
# 4DNFIYVTL965 is from bwa-mem 2019-04-03T03:49---and has no source_experiment
# 4DNFIE6F1G3M is from bwa-mem 2019-04-03T03:48---is okay
# 4DNFIX5ZMD1M is from bwa-mem 2019-04-02T18:08---is okay
# 4DNFIAXZLSCT is from bwa-mem 2019-04-03T03:54---and has no source_experiment
# 4DNFIOFWU53K is from bwa-mem 2019-04-03T03:49---is okay
# 4DNFI6QKAF7W is from bwa-mem 2019-04-03T03:52---and has no source_experiment
# 4DNFIYJAPGX1 is from bwa-mem 2019-04-03T03:53---and has no source_experiment
# 4DNFI4U9TVRP is from bwa-mem 2019-04-02T18:08---is okay
# 4DNFI8N9AYOG is from bwa-mem 2019-04-03T03:49---is okay
# 4DNFIKJQ5ACE is from bwa-mem 2019-04-03T03:51---is okay
# 4DNFINRWQSRI is from bwa-mem 2019-04-03T03:50---is okay
# 4DNFI4MNRECB is from bwa-mem 2019-04-03T03:49---is okay
# 4DNFIQPITH45 is from bwa-mem 2019-04-03T03:49---is okay
# 4DNFI7EP8T8J is from bwa-mem 2019-04-03T03:50---is okay
# 4DNFIPKBMYJN is from bwa-mem 2019-04-03T03:49---is okay
# 4DNFID89ZO3Z is from bwa-mem 2019-04-03T03:51---is okay
# 4DNFI7291GF4 is from bwa-mem 2019-04-03T03:52---is okay
# 4DNFIVV183UK is from bwa-mem 2019-04-03T03:54---is okay
# 4DNFIPLHLXI5 is from bwa-mem 2019-04-03T03:52---and has no source_experiment
# 4DNFICEKFQYI is from bwa-mem 2019-04-03T03:53---and has no source_experiment
# 4DNFIXXM4OA2 is from bwa-mem 2019-04-02T18:08---is okay
# 4DNFIK7FCGBR is from bwa-mem 2019-04-02T18:14---is okay
# 4DNFIMLJAMFS is from bwa-mem 2019-04-03T03:53---and has no source_experiment
# 4DNFI8SVLIS4 is from bwa-mem 2019-04-03T03:50---is okay
# 4DNFI4JXOSY4 is from bwa-mem 2019-04-02T18:14---is okay
# 4DNFIDO5OJPX is from bwa-mem 2019-04-03T03:52---and has no source_experiment
# 4DNFIR1DYCGW is from bwa-mem 2019-04-03T03:51---and has no source_experiment
# 4DNFIWNV5524 is from bwa-mem 2019-04-03T03:54---is okay
# 4DNFIT68UZ7L is from bwa-mem 2019-04-03T03:51---is okay
# 4DNFIA8898X3 is from bwa-mem 2019-04-03T03:52---is okay
# 4DNFICW11UKN is from bwa-mem 2019-04-02T18:15---is okay
# 4DNFIP2SZ4QP is from bwa-mem 2019-04-03T03:49---and has no source_experiment
# 4DNFIAAPZ7H2 is from bwa-mem 2019-04-03T03:50---is okay
# 4DNFIGM4SG56 is from bwa-mem 2019-04-03T03:53---and has no source_experiment
# 4DNFIBYMDV8I is from bwa-mem 2019-04-03T03:52---and has no source_experiment
# 4DNFI4N94H26 is from bwa-mem 2019-04-03T03:50---and has no source_experiment
# 4DNFIB3BRN9J is from bwa-mem 2019-04-02T18:08---is okay
# 4DNFIDNW1M4R is from bwa-mem 2019-04-03T03:50---is okay
# 4DNFITQ8TCGN is from bwa-mem 2019-04-02T18:07---is okay
#
# WFR CHECK
#   Following run types are found:
#     hi-c-processing-bam 0.2.6
#     fastqc-0-11-4-1 0.2.0
#     hi-c-processing-pairs 0.2.7
#     md5 0.2.6
#     pairsqc-single 0.2.6
#     bwa-mem 0.2.6
# problematic wfr ec962722-4f6c-4a95-abe3-8c08ca3a5196 error
# problematic wfr db196c70-dcfc-4624-a0e2-368d4b43cbf5 error
# problematic wfr 970c876d-9e2a-4230-bd49-d299206aeba4 error
# problematic wfr 8defe18f-f21d-472f-911b-f7b6796617c1 started
# problematic wfr 0df2c563-66e3-4ae1-ab68-e1258d7f9870 error
#
# REPORT NUMBERS AND CHECK STATUS
# enzyme 1
# workflow 13
# software 12
# individual_human 10
# static_section 2
# award 7
# vendor 2
# workflow_run_awsem 381
# ['workflow_run_awsem', 'ec962722-4f6c-4a95-abe3-8c08ca3a5196', 'deleted']
# ['workflow_run_awsem', '0b6eafa2-4323-45ed-8b43-b9eaacd596df', 'deleted']
# ['workflow_run_awsem', 'db196c70-dcfc-4624-a0e2-368d4b43cbf5', 'deleted']
# ['workflow_run_awsem', '970c876d-9e2a-4230-bd49-d299206aeba4', 'deleted']
# ['workflow_run_awsem', '8defe18f-f21d-472f-911b-f7b6796617c1', 'deleted']
# ['workflow_run_awsem', '73017955-b72e-44bf-89b4-335254530b13', 'deleted']
# ['workflow_run_awsem', '0df2c563-66e3-4ae1-ab68-e1258d7f9870', 'deleted']
#
# biosource 10
# higlass_view_config 11
# user 14
# biosample 20
# file_format 15
# biosample_cell_culture 20
# file_fastq 128
# organism 1
# experiment_hi_c 20
# quality_metric_pairsqc 23
# file_processed 152
# ['file_processed', 'e02d99e2-7b86-441a-8f2e-57f8e300270e', 'deleted']
# ['file_processed', '3c80b3c3-fec3-4fd2-8f49-25687f3a9945', 'deleted']
# ['file_processed', '9636e493-5ec1-4013-a0ca-0fa256bcaa43', 'deleted']
# ['file_processed', '892d0186-fcd1-47d6-a364-ae14af01b7f9', 'deleted']
# ['file_processed', '6549c70c-ba0e-4a4f-ad6e-b69fde29853b', 'deleted']
# ['file_processed', '506d30ab-b268-4f0b-af62-0fee6dbf04a1', 'deleted']
# ['file_processed', '36366467-b8bf-4670-8adc-50a577092534', 'deleted']
# ['file_processed', 'f2a3ef1f-e771-4c1a-b557-3dc15453a425', 'deleted']
# ['file_processed', '46376336-334d-4536-aa04-4898a5eb6796', 'deleted']
# ['file_processed', '1416cac7-a109-4334-821e-7eba99dba928', 'deleted']
# ['file_processed', 'bb50cba3-42c7-4f89-acd0-23b56eb1ffa4', 'deleted']
# ['file_processed', '24e4f79b-3144-4af3-ac5a-23ec84d4ea3e', 'deleted']
# ['file_processed', 'b8c14a34-2ee7-4a89-b310-c09c3fbc248e', 'deleted']
# ['file_processed', '8dfc8335-247e-4ab9-93e7-134f86862e01', 'deleted']
# ['file_processed', '5272d9c3-08a0-4670-95b8-0d4c9cf59fee', 'deleted']
# ['file_processed', '42b4e0cf-3df7-4b22-a094-722aa0aefbbb', 'deleted']
# ['file_processed', '28d2d799-0106-4634-8278-6c237d27ace0', 'deleted']
# ['file_processed', '07cad4ec-bf7a-4887-b5c1-ac918ea9149f', 'deleted']
#
# ontology_term 24
# experiment_set_replicate 10
# ontology 2
# file_reference 3
# protocol 2
# quality_metric_fastqc 128
# lab 5

# %%
for i in store:
    print(i, len(store[i]))
    weird = [x for x in store[i] if x['status'] == 'revoked']
    if weird:
        for case in weird:
            if case.get('static_content'):
                sc = [i for i in case['static_content'] if i.get('description', '').startswith('auto_generated')]
                if sc:
                    sc_uuid = sc[0]['content'].split('/')[2]
                    scit = [i for i in store['higlass_view_config'] if i['uuid'] == sc_uuid][0]
                    print(i, case['uuid'], sc_uuid, scit['status'])
                    ff_utils.patch_metadata({'status': 'released to lab'}, sc_uuid, my_auth)
            print(i, case['uuid'])
            ff_utils.patch_metadata({'status': 'pre-release'}, case['uuid'], my_auth)
# Out:
# file_processed 113
# file_processed fd9a037b-ddc9-4086-8339-10163fb6121d 3ef3d359-b3be-48a1-9167-5f056f4161e0 released
# file_processed fd9a037b-ddc9-4086-8339-10163fb6121d
# file_processed f37b66d0-fc4a-4490-95b3-674548f53972
# file_processed e74550c2-aa57-4ffb-8ef1-3b7227ca8cf9 f1c2eab3-63ab-4382-b673-ab51bb578277 released
# file_processed e74550c2-aa57-4ffb-8ef1-3b7227ca8cf9
# file_processed e275e5bf-f44b-4d68-bf3d-3fb24bd81023
# file_processed e0d4f71b-249b-4065-b004-879e630fc91c
# file_processed dbfd8f87-7463-4fe1-9c56-5d5612780073 23a715d3-ee99-4c66-8e18-c2f54c610501 released
# file_processed dbfd8f87-7463-4fe1-9c56-5d5612780073
# file_processed da45ae30-7faa-44c9-9563-f3b6ce73fd5c
# file_processed c774e6d0-d972-4c94-b425-d90dd6b12dfc
# file_processed c0d02802-b6e0-44b9-ad3b-43354060f559 3ee877f2-d3d6-463f-9fe5-79595c31edc6 released
# file_processed c0d02802-b6e0-44b9-ad3b-43354060f559
# file_processed bb028d51-4a59-47eb-a560-8939d3cb2115
# file_processed b1b54589-4231-4c8d-a992-25cd10e50e8d 02c4fc13-5e76-40d6-b484-af996b9b2a7b released
# file_processed b1b54589-4231-4c8d-a992-25cd10e50e8d
# file_processed abc7085e-81d0-4f94-bbc1-28d579364b11 2bbb2971-7212-46be-84a0-2519592afcfe released
# file_processed abc7085e-81d0-4f94-bbc1-28d579364b11
# file_processed a262dce9-f2d1-4d9f-99df-eb30ecd9b3e8 cab3c4af-3bcd-4e7f-82be-67277f7ee9d8 released
# file_processed a262dce9-f2d1-4d9f-99df-eb30ecd9b3e8
# file_processed 9e23b1c7-f7a5-4700-882d-3a39f4d803a5 a11a4e0a-f7c1-437b-a4f6-3566341a8ba3 released
# file_processed 9e23b1c7-f7a5-4700-882d-3a39f4d803a5
# file_processed 9c5d68ce-4bf8-411f-9c5a-89e1a05ca08d e3dc02bb-8281-43d6-a814-92a9647c504b released
# file_processed 9c5d68ce-4bf8-411f-9c5a-89e1a05ca08d
# file_processed 9a420689-4866-4d8f-b803-128f3206d357 32993421-9174-4e02-ab01-ff392e49431c released
# file_processed 9a420689-4866-4d8f-b803-128f3206d357
# file_processed 8d7ded86-663c-4d4b-aafb-a2a67de8383f 181d9a28-955a-4490-abf6-c2081e314bbe released
# file_processed 8d7ded86-663c-4d4b-aafb-a2a67de8383f
# file_processed 375e5880-ed34-4321-a654-026112726f4d 9290e08a-e0af-4cc9-b4b5-56be45007ec8 released
# file_processed 375e5880-ed34-4321-a654-026112726f4d
# file_processed 323be148-657e-45c9-8ff0-56e697d7c11e
# file_processed 30bbdbb4-789d-40f0-bb7e-0bd99425aec8
# file_processed 2f89c0f7-f8ae-4f97-bd46-65ffc03f2a3a 057c0ca5-15bc-41a6-99dc-cd529ca833e2 released
# file_processed 2f89c0f7-f8ae-4f97-bd46-65ffc03f2a3a
# file_processed 259d63ae-96ef-4f40-81e9-bd794c4332da
# file_processed f8b55cbf-a9ca-4315-9809-5dfc0415b0c0 392660c3-9b04-4b52-b59b-68ab3c091865 released
# file_processed f8b55cbf-a9ca-4315-9809-5dfc0415b0c0
# file_processed f4526fe0-f0e6-41c5-81ba-e4a7d221b0ef
# file_processed e6523575-03df-4de3-a111-470b2ed7cacd
# file_processed bd8d5412-5da1-4d34-90a3-0728aca86095 b2796efb-c83e-4bbc-8d2c-c7e39252414b released
# file_processed bd8d5412-5da1-4d34-90a3-0728aca86095
# file_processed a167eefc-c60e-412b-8d9c-b991eb2c6b5f
# file_processed 8e4e05d3-d4d0-40da-9ad1-7fb341693cd1 07e5700a-2f77-4199-a8f1-f8695ae51c14 released
# file_processed 8e4e05d3-d4d0-40da-9ad1-7fb341693cd1
# file_processed 5f532596-7c02-4aba-bb56-6a1bf0c431cf 9ad4c510-6282-4cff-9701-a841f1548993 released
# file_processed 5f532596-7c02-4aba-bb56-6a1bf0c431cf
# file_processed 4bda2040-65ef-46cf-a414-c57b46f44cd7 15679e74-f992-44c3-9c62-0598a1bac641 released
# file_processed 4bda2040-65ef-46cf-a414-c57b46f44cd7
# file_processed 48fa96d3-1ff5-4630-8828-d118867b7474
# file_processed 43fc38af-d363-4804-a9c4-4112a2fd7ee3
# file_processed 3fe1e603-4c38-47bb-8544-149f702f1ac9
# file_processed 2bf0b821-5d22-42d4-8109-1dcde8165a50
# file_processed 27e81a96-741c-47ce-8527-64cb58263505
# file_processed 25af07f2-8136-4375-8209-c01d136c6574 73b4e3a8-75c5-4bd4-92dd-a6ab3d080827 released
# file_processed 25af07f2-8136-4375-8209-c01d136c6574
# file_processed 1a964e05-c66e-4664-a843-690c01acb3f7 958af260-a1bc-4bde-ac3f-e399e03656ae released
# file_processed 1a964e05-c66e-4664-a843-690c01acb3f7
# lab 5
# ontology_term 15
# static_section 4
# biosource 1
# protocol 26
# biosample 11
# file_format 10
# award 4
# ontology 1
# badge 1
# antibody 8
# file_fastq 44
# experiment_set_replicate 28
# quality_metric_dedupqc_repliseq 44
# quality_metric_dedupqc_repliseq d2745e28-8536-450b-9fbb-e9d0ff92fbed
# quality_metric_dedupqc_repliseq bac75add-aee3-4ad5-8066-fe2f68a23f90
# quality_metric_dedupqc_repliseq b6f3ecd3-28d5-4273-8a70-6e054728cefb
# quality_metric_dedupqc_repliseq afd4970f-1dee-4f5d-a9a1-64df30b9fab9
# quality_metric_dedupqc_repliseq a65b54d3-9ca5-41ba-b06a-ec3462054e53
# quality_metric_dedupqc_repliseq 83beb364-966a-4840-bbb8-15a92505763e
# quality_metric_dedupqc_repliseq 42a340cb-564c-4b0c-90c7-2c5970d57b50
# quality_metric_dedupqc_repliseq 2a0c9dcc-ddc4-43a1-b466-bf8243ed47df
# quality_metric_dedupqc_repliseq 07b5dc39-52d0-40ee-92aa-98b0ee78a522
# organism 1
# higlass_view_config 111
# workflow_run_awsem 182
# workflow_run_awsem f2c046d4-c492-4840-8c56-5f9a0afba325
# workflow_run_awsem ca35f4e0-7809-4567-9b98-64767f3e5362
# workflow_run_awsem ac634f4a-24b0-44a0-a3cd-77455eb09b9c
# workflow_run_awsem ab5e4581-afe9-417d-ad38-63ce650287a9
# workflow_run_awsem 8e77bed2-bc74-4de4-89ec-52e50d35e986
# workflow_run_awsem 73a5eae5-02a5-43ec-8ba8-8d98500f08bb
# workflow_run_awsem 72414998-4e61-4752-9072-88fac2c6a983
# workflow_run_awsem 41ba1e00-6770-4b35-9247-330ec69fea51
# workflow_run_awsem 3715b18c-e387-4011-a996-e14f7774776b
# workflow_run_awsem 2b1bef85-7a39-4cd1-bbe5-207c5c232fe2
# workflow_run_awsem 28d0534f-a6c8-45c7-9a97-a72e377147ff
# workflow_run_awsem ec2e8dad-6901-41a3-838b-f15187d8f853
# workflow_run_awsem d259651d-9d2d-492f-af7d-b1ca45b76ef9
# workflow_run_awsem b99b7355-58ab-4c3f-8f99-e4058acee00e
# workflow_run_awsem 7add6514-7b36-47cd-90d2-02d04e8ed3bf
# workflow_run_awsem 773a1f97-91c0-4ba5-a10c-28bacc7cc0af
# workflow_run_awsem 6aaaa6c6-e36c-4bd6-b9a8-5849b144a40f
# workflow_run_awsem 5d848c2f-f154-498e-8ea1-1f22667e64c4
# workflow_run_awsem 49a7169b-121d-4c2d-abbe-42c884a728f7
# workflow_run_awsem 1ea1433d-4ab0-4902-88de-e4de2000d4d6
# workflow_run_awsem ef4ae35f-9324-4620-9b59-76d15cf450dd
# workflow_run_awsem e3a1b803-ce07-4bff-9a78-6e29c1fabbc5
# workflow_run_awsem d8a81e9e-ad34-4027-a443-e05fc77a2023
# workflow_run_awsem cbddfde6-97ee-4649-b774-0d1cfc93a6bd
# workflow_run_awsem c5204a0c-6441-4608-8b2c-4a4140ad1f52
# workflow_run_awsem 6696bf67-a38f-46cf-90c2-26305e6680d2
# workflow_run_awsem 5f7764d2-25d3-4f81-a670-8663b37d6f52
# workflow_run_awsem 4fe671a1-4265-43da-92eb-30e16634d573
# workflow_run_awsem 4fd9c455-00c6-4abe-a998-c4c3795537b2
# workflow_run_awsem 4ec7787b-32cf-4475-8249-723af2c59671
# workflow_run_awsem 1be98d12-146b-4f25-8e31-3b0d9a500892
# workflow_run_awsem e10765e2-ebaf-40c8-ac7d-a9ce006fff0b
# workflow_run_awsem b4f054df-7da1-4dbd-9136-dd2ff7fa8c0a
# workflow_run_awsem b2be5f49-ccdb-4bfa-83cc-233286469f29
# workflow_run_awsem ae7192fe-ba76-4bb4-9d96-8f5c4ad587e4
# workflow_run_awsem 91df6432-18cc-43af-b13c-762293acc395
# workflow_run_awsem 7df56644-0b22-4fee-8375-c75a63bca7f5
# workflow_run_awsem 4ad3b4b3-ba26-4fa7-9886-6661eeb015a8
# workflow_run_awsem 3d7b287f-2b66-4844-8cee-2a5a6620e6b4
# workflow_run_awsem 35217a4b-c4fd-4895-8d0b-12594198ee7e
# workflow_run_awsem 2248f6f9-79fa-4d97-8adf-0fb2f3d7c0fb
# workflow_run_awsem 1e5a7027-a6d4-4577-8f5e-f28f96cb781b
# workflow_run_awsem 1a75ef34-32f4-4c60-9dcc-55dac08180ea
# workflow_run_awsem 0d74feae-cffc-4ae0-84df-bee2825c5909
# experiment_tsaseq 44
# workflow 8
# vendor 6
# individual_human 1
# target 5
# biosample_cell_culture 11
# quality_metric_fastqc 44
# user 13
# file_reference 4
# software 11
# document 21

# %%
# Check status
print_each = False
counter = 0
for a_type in store:
    total = len(store[a_type])
    change = 0
    matching = 0
    unusual = 0
    skipping = 0
    for raw_data in store[a_type]:
        if STATUS_LEVEL.get(raw_data['status']) > change_level:
            skipping += 1
            msg = ('{} {} ITEM HAS STATUS {} HIGHER THAN {} - SKIPPING'.format(a_type, raw_data['uuid'], raw_data['status'], change_status))
        elif STATUS_LEVEL.get(raw_data['status']) == STATUS_LEVEL.get(change_status):
            matching += 1
            msg = ('MATCHING ACCESS STATUS', a_type, raw_data['uuid'], raw_data['status'])
        elif STATUS_LEVEL.get(raw_data['status']) == 0:
            unusual += 1
            msg = ('SKIP UNUSUAL STATUS  ', a_type, raw_data['uuid'], raw_data['status'])
        else:
            change += 1
            msg = ('       CHANGE        ', a_type, raw_data['uuid'], raw_data['status'])
        if print_each:
            print(msg)
    print('{:<25} Out of {t}, {r} skipped, {m} matching, {u} unusual, and {c} needs change'.format(a_type, t=total, r=skipping, m=matching, u=unusual, c=change))

# %%
# If you want to patch the status, change action to True
action = False

reviewed = ""
reviewed = input('Did another wrangler review this release? (y/n):')
if reviewed != 'y':
    raise KeyError('A key step is missing!')
    
print_each = False
counter = 0
for a_type in store:
    total = len(store[a_type])
    change = 0
    matching = 0
    unusual = 0
    skipping = 0
    for raw_data in store[a_type]:
        if STATUS_LEVEL.get(raw_data['status']) > change_level:
            skipping += 1
            msg = ('{} {} ITEM HAS STATUS {} HIGHER THAN {} - SKIPPING'.format(a_type, raw_data['uuid'], raw_data['status'], change_status))
        elif STATUS_LEVEL.get(raw_data['status']) == STATUS_LEVEL.get(change_status):
            matching += 1
            msg = ('MATCHING ACCESS STATUS', a_type, raw_data['uuid'], raw_data['status'])
        elif STATUS_LEVEL.get(raw_data['status']) == 0:
            unusual += 1
            msg = ('SKIP UNUSUAL STATUS  ', a_type, raw_data['uuid'], raw_data['status'])
        else:
            change += 1
            msg = ('       CHANGE        ', a_type, raw_data['uuid'], raw_data['status'])
            if action:
                patch_data = {'status': change_status}
                if change_status == 'released' and a_type in ['publication']:
                    patch_data = {'status': 'current'}
                   
                ff_utils.patch_metadata(patch_data, obj_id=raw_data['uuid'] ,key=my_auth) 

        if print_each:
            print(msg)
    print('{:<25} Out of {t}, {r} skipped, {m} matching, {u} unusual, and {c} UPDATED with status'.format(a_type, t=total, r=skipping, m=matching, u=unusual, c=change))
