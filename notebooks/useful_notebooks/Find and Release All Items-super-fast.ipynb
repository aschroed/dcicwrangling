# %%
# Find items starting with a publication or experiment set
from dcicutils import ff_utils
from functions.notebook_functions import *
import time
time1 = time.time()
env = 'data'
my_auth = get_key('koray_data')   #use your key name in keypairs.json
schema_name = get_schema_names(my_auth) 

set_to_release = ['83e74398-ac79-4372-91d3-250e7390d636']  # place the uuid of the item here
store1, uuids = record_object_es_super_fast(set_to_release, my_auth, schema_name, add_pc_wfr=True)
print(len(uuids))
print(len(list(set(uuids))))
time2 = time.time()
print((time2-time1)/60)
# Out:
# 1
# 1 uniques
# 1 all resps
# 1 uuids from resp
# 64
# 64 uniques
# 64 all resps
# 64 uuids from resp
# 304
# 304 uniques
# 304 all resps
# 304 uuids from resp
# []
# ['5a3a737d-dabf-4d3e-b4f4-8a5fee2892a1', '743e45cb-78a4-4cac-849e-3815c7d4b6dc', '791444bf-9003-4903-8d65-5397bf888a38', 'dd8e7378-401a-42fc-aedc-9637e3a98eea', 'fb09aa27-e90b-4892-b68e-9efd79d4901d', '2eafbb40-4840-4430-81c6-ea8032f90990', '71277339-3dae-4007-8c38-b0d806374680', 'ce198dd8-8f80-4ee4-b535-2e2b25353682', '44116f35-3164-4918-8abd-897a432b47dc', 'ceb8de08-8d6f-4590-8156-f836b0c5afc1', '877623af-a084-4217-adbf-8cbef1a34f42', '14ff7c8e-0c48-44d9-8bbb-ab073d041732', 'a2e33470-5a94-4163-9a8c-1fb51c1af496', '96524f31-965c-478c-ab3c-8f9582845d71', 'f92d7dc9-3b46-4cf9-abce-90b1afb993b0', 'd1262ebc-c3a1-460a-ac68-d00c0ae15d44', 'a69d9943-c0c0-4f13-b015-1f5b43452c2d', '60b7365b-3209-4ba3-87b4-009f8e1f1bc8', 'ae2fbec0-32fd-406f-941b-5f95102a627d', '846424ae-e66b-450b-b633-6bfef443a1c8', 'eaa94d41-b4ba-40b8-a435-d52096eb4214', 'f48ecd50-b5b5-4187-b2c5-f3dcbe79b98d', '3969a3c8-cac9-42ea-895b-8a5094fddd9b', 'ac659811-a533-4a31-ba77-aff6b3ce15c0', '38d99201-2515-4ffe-80f3-7c2fa4f445b5', '80fc17a6-3a0e-4451-91b8-f7e06327b8e3', '365333f7-d49f-42e0-8362-227dd9522b12']
# Duplicate encountered - skipped - check
# Duplicate encountered - skipped - check
# Duplicate encountered - skipped - check
# Duplicate encountered - skipped - check
# Duplicate encountered - skipped - check
# Duplicate encountered - skipped - check
# Duplicate encountered - skipped - check
# Duplicate encountered - skipped - check
# Duplicate encountered - skipped - check
# Duplicate encountered - skipped - check
# Duplicate encountered - skipped - check
# Duplicate encountered - skipped - check
# Duplicate encountered - skipped - check
# Duplicate encountered - skipped - check
# Duplicate encountered - skipped - check
# Duplicate encountered - skipped - check
# Duplicate encountered - skipped - check
# Duplicate encountered - skipped - check
# Duplicate encountered - skipped - check
# Duplicate encountered - skipped - check
# Duplicate encountered - skipped - check
# Duplicate encountered - skipped - check
# Duplicate encountered - skipped - check
# Duplicate encountered - skipped - check
# Duplicate encountered - skipped - check
# Duplicate encountered - skipped - check
# Duplicate encountered - skipped - check
# 122
# 122 uniques
# 122 all resps
# 122 uuids from resp
# 28
# 28 uniques
# 28 all resps
# 28 uuids from resp
# 6
# 6 uniques
# 6 all resps
# 6 uuids from resp
# 7
# 7 uniques
# 7 all resps
# 7 uuids from resp
# 7
# 7 uniques
# 7 all resps
# 7 uuids from resp
# 1
# 1 uniques
# 1 all resps
# 1 uuids from resp
# 513
# 513
# 0.3804798801740011

# %%
# Find items starting with a publication or experiment set
from dcicutils import ff_utils
from functions.notebook_functions import *
import time
time1 = time.time()
env = 'data'
my_auth = get_key('koray_data')   #use your key name in keypairs.json
schema_name = get_schema_names(my_auth) 

set_to_release = ['83e74398-ac79-4372-91d3-250e7390d636']  # place the uuid of the item here
store2, uuids = record_object_es_fast(set_to_release, my_auth, schema_name, add_pc_wfr=True)
print(len(uuids))
print(len(list(set(uuids))))
time2 = time.time()
print((time2-time1)/60)
# Out:
# 1
# 64
# 304
# 122
# 28
# 6
# 7
# 7
# 1
# 540
# 540
# 0.46177030007044473

# %%
for a_key in store2:
    fast_type = store2[a_key]
    s_fast_type = store1[a_key]
    fast_uuid = [i['uuid'] for i in fast_type]
    s_fast_uuid = [i['uuid'] for i in s_fast_type]
    
    if len(fast_uuid) != len(s_fast_uuid):
        print(a_key)
        print(len(fast_uuid)-len(s_fast_uuid))
        print([i for i in fast_uuid if i not in s_fast_uuid])

# %%
# Release the items

action = False # change to True if you want to patch
change_status = 'released'

counter = 0
for a_type in store:
    for raw_data in store[a_type]:
        if raw_data['status'] in ['deleted']: 
            print('deleted data', a_type ,raw_data['uuid'])
            continue        
        if raw_data['status'] not in ['current', 'released', 'released to project']:    
            counter +=1
            print(a_type, raw_data['status'], raw_data['uuid'])
            patch_data = {'status': "released to project"}
            if action:
                ff_utils.patch_metadata(patch_data, obj_id=raw_data['uuid'] ,key=my_auth)
        else:
            print('ALREADY RELEASED/TO PROJECT', a_type, raw_data['status'], raw_data['uuid'])
            pass
            
print(counter)
