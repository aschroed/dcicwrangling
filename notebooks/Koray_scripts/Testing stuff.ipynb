# %%
#get profiles
from dcicutils import ff_utils
from functions.wfr import *
from functions.wfr_settings import *
from functions.notebook_functions import *

# get key from keypairs.json
my_env = 'data'
my_key = get_key('koray_data')

q = '/search/?file_format=other&type=FileProcessed'
items = ff_utils.search_metadata(q, key=my_key)

for i in items:
    print(i['display_title'], i['status'], i.get('filename',"no_name"), i['lab']['@id'])
# Out:
# 4DNFI5RCIF4F released pipeline.statistics.txt /labs/bas-van-steensel-lab/
# 4DNFIIFBEEEU released H1_LMNB1_replicate.html /labs/bas-van-steensel-lab/
# 4DNFIJZXXMHV released H1_r3_LMNB1_report.html /labs/bas-van-steensel-lab/
# 4DNFI2SZX561 released H1_r2_LMNB1_report.html /labs/bas-van-steensel-lab/
# 4DNFIQZJ9IWX released H1_r1_LMNB1_report.html /labs/bas-van-steensel-lab/
# 4DNFIY5F9DWG released HFF_LMNB1_replicate.html /labs/bas-van-steensel-lab/
# 4DNFISCUNQCP released HFF_r2_LMNB1_report.html /labs/bas-van-steensel-lab/
# 4DNFIL2T46JK released HFF_r1_LMNB1_report.html /labs/bas-van-steensel-lab/
# 4DNFIQCGRZ8M uploaded Untitled.py.zip /labs/4dn-dcic-lab/
# 4DNFI3BAU2XE archived pipeline.statistics.txt /labs/bas-van-steensel-lab/
# 4DNFID89K985 archived HFF_LMNB1_replicate.html /labs/bas-van-steensel-lab/
# 4DNFID4DMS1T archived HFF_r2_LMNB1_report.html /labs/bas-van-steensel-lab/
# 4DNFI87UP7UN archived HFF_r1_LMNB1_report.html /labs/bas-van-steensel-lab/
# 4DNFID1GKJAQ uploaded unicorns.svg /labs/4dn-dcic-lab/
# 4DNFIWKGJERO released to project no_name /labs/4dn-dcic-lab/
# 4DNFIFESYUR1 released to project no_name /labs/4dn-dcic-lab/
# 4DNFIQE2WLSB released to project no_name /labs/4dn-dcic-lab/
# 4DNFIILI6UNC released to project no_name /labs/4dn-dcic-lab/
# 4DNFIC71Q02Q released to project no_name /labs/4dn-dcic-lab/
# 4DNFI3BKDEZD released to project no_name /labs/4dn-dcic-lab/
# 4DNFIZASGQW3 released to project no_name /labs/4dn-dcic-lab/
# 4DNFICMNN63X released to project no_name /labs/4dn-dcic-lab/
# 4DNFI0ISP6QA released to project no_name /labs/4dn-dcic-lab/
# 4DNFI6NSZ3UV released to project no_name /labs/4dn-dcic-lab/
# 4DNFIQ2SRY11 released to project no_name /labs/4dn-dcic-lab/
# 4DNFIBSZMNM3 released to project no_name /labs/4dn-dcic-lab/
# 4DNFIV9ESXM8 released to project no_name /labs/4dn-dcic-lab/
# 4DNFIGHDUTUU released to project no_name /labs/4dn-dcic-lab/
# 4DNFIK2IU4PC released to project no_name /labs/4dn-dcic-lab/
# 4DNFIZU8FP50 released to project no_name /labs/4dn-dcic-lab/
# 4DNFIBFRTLW0 released to project no_name /labs/4dn-dcic-lab/
# 4DNFI6KOULN3 released to project no_name /labs/4dn-dcic-lab/
# 4DNFI4D6CGBO released to project no_name /labs/4dn-dcic-lab/
# 4DNFIJVLZ6S5 released to project no_name /labs/4dn-dcic-lab/
# 4DNFIVKA1B7R released to project no_name /labs/4dn-dcic-lab/
# 4DNFIMFNQVZ7 released to project no_name /labs/4dn-dcic-lab/
# 4DNFIDSNRRU6 released to project no_name /labs/4dn-dcic-lab/
# 4DNFIPI773E7 released to project no_name /labs/4dn-dcic-lab/
# 4DNFI8SW0YA1 released to project no_name /labs/4dn-dcic-lab/
# 4DNFIRLDB31T released to project no_name /labs/4dn-dcic-lab/
# 4DNFIIGTTG31 released to project no_name /labs/4dn-dcic-lab/
# 4DNFIT11ATNV released to project no_name /labs/4dn-dcic-lab/
# 4DNFIF3MKFB4 released to project no_name /labs/4dn-dcic-lab/
# 4DNFISRLK32B released to project no_name /labs/4dn-dcic-lab/
# 4DNFI6HSCH9Y released to project no_name /labs/4dn-dcic-lab/
# 4DNFIXS10GFJ released to project no_name /labs/4dn-dcic-lab/
# 4DNFIZUFUAEB released to project no_name /labs/4dn-dcic-lab/
# 4DNFIMPXLQQY released to project no_name /labs/4dn-dcic-lab/
# 4DNFI4YHD4YL released to project no_name /labs/4dn-dcic-lab/
# 4DNFITHXW9MA released to project no_name /labs/4dn-dcic-lab/
# 4DNFIBZ8LQ9K released to project no_name /labs/4dn-dcic-lab/
# 4DNFIG7VIUIX released to project no_name /labs/4dn-dcic-lab/
# 4DNFIESXI3GC released to project no_name /labs/4dn-dcic-lab/
# 4DNFID8P985Z released to project no_name /labs/4dn-dcic-lab/
# 4DNFIAYN59WS released to project no_name /labs/4dn-dcic-lab/
# 4DNFIEG2P8MO released to project no_name /labs/4dn-dcic-lab/
# 4DNFIKIJXTR0 released to project no_name /labs/4dn-dcic-lab/
# 4DNFIEMSQZ4N released to project no_name /labs/4dn-dcic-lab/
# 4DNFIYC95I6C released to project no_name /labs/4dn-dcic-lab/
# 4DNFISYRFN06 released to project no_name /labs/4dn-dcic-lab/
# 4DNFIKYUSJ9S released to project no_name /labs/4dn-dcic-lab/
# 4DNFIANRU3X9 released to project no_name /labs/4dn-dcic-lab/
# 4DNFI5MH9KTH released to project no_name /labs/4dn-dcic-lab/
# 4DNFI335F9OP released to project no_name /labs/4dn-dcic-lab/
# 4DNFIEL756JO released to project no_name /labs/4dn-dcic-lab/
# 4DNFIJ9V67FR released to project no_name /labs/4dn-dcic-lab/
# 4DNFIPLV6CWL released to project no_name /labs/4dn-dcic-lab/
# 4DNFISSPQRFR released to project no_name /labs/4dn-dcic-lab/
# 4DNFI2FD5YGB released to project no_name /labs/4dn-dcic-lab/
# 4DNFIC2Q18O1 released to project no_name /labs/4dn-dcic-lab/
# 4DNFIJNQW2W3 released to project no_name /labs/4dn-dcic-lab/
# 4DNFIQ9QGM7Z released to project no_name /labs/4dn-dcic-lab/
# 4DNFIUQ4DGWN released to project no_name /labs/4dn-dcic-lab/
# 4DNFILB7836C released to project no_name /labs/4dn-dcic-lab/
# 4DNFIVY9U4I6 released to project no_name /labs/4dn-dcic-lab/
# 4DNFIFL8W9R9 released to project no_name /labs/4dn-dcic-lab/
# 4DNFIP406VVM released to project no_name /labs/4dn-dcic-lab/
# 4DNFIRN07A9M released to project no_name /labs/4dn-dcic-lab/
# 4DNFI66DYVK3 released to project no_name /labs/4dn-dcic-lab/
# 4DNFIA9TUVMR released to project no_name /labs/4dn-dcic-lab/
# 4DNFIFD6GOJ1 released to project no_name /labs/4dn-dcic-lab/
# 4DNFI1XIELDQ released to project no_name /labs/4dn-dcic-lab/
# 4DNFI47KLZVZ released to project no_name /labs/4dn-dcic-lab/
# 4DNFIMOWK9MT released to project no_name /labs/4dn-dcic-lab/
# 4DNFIWIJ7EU5 released to project no_name /labs/4dn-dcic-lab/
# 4DNFIRR5LO8P released to project no_name /labs/4dn-dcic-lab/
# 4DNFI0FIK833 released to project no_name /labs/4dn-dcic-lab/
# 4DNFI7GC0BN5 released to project no_name /labs/4dn-dcic-lab/
# 4DNFIXVHRMBL released to project no_name /labs/4dn-dcic-lab/
# 4DNFISIX6DLC released to project no_name /labs/4dn-dcic-lab/
# 4DNFITUOEB81 released to project no_name /labs/4dn-dcic-lab/
# 4DNFI26O38QE released to project no_name /labs/4dn-dcic-lab/
# 4DNFIV3QVZGY released to project no_name /labs/4dn-dcic-lab/
# 4DNFIQ9PV38M released to project no_name /labs/4dn-dcic-lab/
# 4DNFIVYK1UJ4 released to project no_name /labs/4dn-dcic-lab/
# 4DNFIUCEFWU8 released to project no_name /labs/4dn-dcic-lab/
# 4DNFI49UVHWY released to project no_name /labs/4dn-dcic-lab/
# 4DNFI54BRKYD released to project no_name /labs/4dn-dcic-lab/
# 4DNFIBTDCJ4H released to project no_name /labs/4dn-dcic-lab/
# 4DNFIZDHASMW released to project no_name /labs/4dn-dcic-lab/
# 4DNFIASQ2K9A released to project no_name /labs/4dn-dcic-lab/
# 4DNFIYJ3BZV1 released to project no_name /labs/4dn-dcic-lab/
# 4DNFIGO8J6T4 released to project no_name /labs/4dn-dcic-lab/
# 4DNFIZ6TPESN released to project no_name /labs/4dn-dcic-lab/
# 4DNFIT8N60P8 released to project no_name /labs/4dn-dcic-lab/
# 4DNFI9F099AL released to project no_name /labs/4dn-dcic-lab/
# 4DNFIUI2Q3YW released to project no_name /labs/4dn-dcic-lab/
# 4DNFI791UNQ7 released to project no_name /labs/4dn-dcic-lab/
# 4DNFIQMUBTVA released to project no_name /labs/4dn-dcic-lab/
# 4DNFI692OTBC released to project no_name /labs/4dn-dcic-lab/
# 4DNFISRTLFN1 released to project no_name /labs/4dn-dcic-lab/

# %%
from dcicutils import ff_utils
from functions.notebook_functions import *
my_key = get_key('koray_data')
input_json = {
  "wfr_meta": {
    "contributing_labs": [
      "/labs/4dn-dcic-lab/"
    ],
    "award": "/awards/1U54DK107965-01/",
    "lab": "/labs/david-gilbert-lab/"
  },
  "parameters": {
    "memperthread": "2G",
    "nthreads": 4
  },
  "env_name": "fourfront-webprod",
  "_tibanna": {
    "run_type": "repliseq-parta",
    "run_id": "4DNFI64XJOEQ",
    "url": "https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:repliseq-parta_4DNFI64XJOEQ",
    "exec_arn": "arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:repliseq-parta_4DNFI64XJOEQ",
    "env": "data",
    "run_name": "repliseq-parta_4DNFI64XJOEQ"
  },
  "output_bucket": "elasticbeanstalk-fourfront-webprod-wfoutput",
  "tag": "0.2.5",
  "app_name": "repliseq-parta",
  "config": {
    "ebs_type": "io1",
    "key_name": "4dn-encode",
    "json_bucket": "4dn-aws-pipeline-run-json",
    "shutdown_min": 30,
    "copy_to_s3": True,
    "ebs_iops": 500,
    "launch_instance": True,
    "password": "dragonfly",
    "log_bucket": "tibanna-output"
  },
  "custom_pf_fields": {
    "count_bg": {
      "description": "read counts per 50kb bin, unfiltered, unnormalized",
      "file_type": "counts",
      "lab": "/labs/david-gilbert-lab/",
      "contributing_labs": [
        "/labs/4dn-dcic-lab/"
      ],
      "award": "/awards/1U54DK107965-01/",
      "genome_assembly": "GRCm38"
    },
    "filtered_sorted_deduped_bam": {
      "description": "This is an output file of the RepliSeq processing pipeline",
      "file_type": "alignment",
      "lab": "/labs/david-gilbert-lab/",
      "contributing_labs": [
        "/labs/4dn-dcic-lab/"
      ],
      "award": "/awards/1U54DK107965-01/",
      "genome_assembly": "GRCm38"
    }
  },
  "workflow_uuid": "146da22a-502d-4500-bf57-a7cf0b4b2364",
  "input_files": [
    {
      "object_key": "4DNFI823LSI8.bwaIndex.tgz",
      "bucket_name": "elasticbeanstalk-fourfront-webprod-files",
      "uuid": "4a6d10ee-2edb-4402-a98f-0edb1d58f5e1",
      "workflow_argument_name": "bwaIndex"
    },
    {
      "object_key": "4DNFI64XJOEQ.fastq.gz",
      "bucket_name": "elasticbeanstalk-fourfront-webprod-files",
      "uuid": "619da19f-c269-45f3-9b0b-3d59c7632fd5",
      "workflow_argument_name": "fastq"
    },
    {
      "object_key": "4DNFI3UBJ3HZ.chrom.sizes",
      "bucket_name": "elasticbeanstalk-fourfront-webprod-files",
      "uuid": "bd0784a5-2a3d-42f0-ba9c-d9b3dc0539c6",
      "workflow_argument_name": "chromsizes"
    }
  ]
}

ff_utils.post_metadata(input_json, 'WorkflowRun/run', key=my_key)
# Out:
# {'ResponseMetadata': {'HTTPHeaders': {'content-length': '2845',
#    'content-type': 'application/x-amz-json-1.0',
#    'x-amzn-requestid': '8a716a41-9c08-11e8-aa0b-a91b967dd45d'},
#   'HTTPStatusCode': 200,
#   'RequestId': '8a716a41-9c08-11e8-aa0b-a91b967dd45d',
#   'RetryAttempts': 0},
#  'executionArn': 'arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:repliseq-parta_4DNFI64XJOEQe8566448-0dcc-4da8-b4b1-86b39cf1c1be',
#  'input': '{"_tibanna": {"run_type": "repliseq-parta", "run_id": "4DNFI64XJOEQ", "url": "https://console.aws.amazon.com/states/home?region=us-east-1#/executions/details/arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:repliseq-parta_4DNFI64XJOEQe8566448-0dcc-4da8-b4b1-86b39cf1c1be", "exec_arn": "arn:aws:states:us-east-1:643366669028:execution:tibanna_pony:repliseq-parta_4DNFI64XJOEQe8566448-0dcc-4da8-b4b1-86b39cf1c1be", "env": "data", "run_name": "repliseq-parta_4DNFI64XJOEQe8566448-0dcc-4da8-b4b1-86b39cf1c1be"}, "parameters": {"memperthread": "2G", "nthreads": 4}, "wfr_meta": {"contributing_labs": ["/labs/4dn-dcic-lab/"], "award": "/awards/1U54DK107965-01/", "lab": "/labs/david-gilbert-lab/"}, "env_name": "fourfront-webprod2", "output_bucket": "elasticbeanstalk-fourfront-webprod-wfoutput", "tag": "0.2.5", "input_files": [{"workflow_argument_name": "bwaIndex", "bucket_name": "elasticbeanstalk-fourfront-webprod-files", "uuid": "4a6d10ee-2edb-4402-a98f-0edb1d58f5e1", "object_key": "4DNFI823LSI8.bwaIndex.tgz"}, {"workflow_argument_name": "fastq", "bucket_name": "elasticbeanstalk-fourfront-webprod-files", "uuid": "619da19f-c269-45f3-9b0b-3d59c7632fd5", "object_key": "4DNFI64XJOEQ.fastq.gz"}, {"workflow_argument_name": "chromsizes", "bucket_name": "elasticbeanstalk-fourfront-webprod-files", "uuid": "bd0784a5-2a3d-42f0-ba9c-d9b3dc0539c6", "object_key": "4DNFI3UBJ3HZ.chrom.sizes"}], "config": {"ebs_type": "io1", "json_bucket": "4dn-aws-pipeline-run-json", "ebs_iops": 500, "shutdown_min": 30, "copy_to_s3": true, "key_name": "4dn-encode", "launch_instance": true, "password": "dragonfly", "log_bucket": "tibanna-output"}, "custom_pf_fields": {"count_bg": {"description": "read counts per 50kb bin, unfiltered, unnormalized", "file_type": "counts", "lab": "/labs/david-gilbert-lab/", "contributing_labs": ["/labs/4dn-dcic-lab/"], "award": "/awards/1U54DK107965-01/", "genome_assembly": "GRCm38"}, "filtered_sorted_deduped_bam": {"description": "This is an output file of the RepliSeq processing pipeline", "file_type": "alignment", "lab": "/labs/david-gilbert-lab/", "contributing_labs": ["/labs/4dn-dcic-lab/"], "award": "/awards/1U54DK107965-01/", "genome_assembly": "GRCm38"}}, "workflow_uuid": "146da22a-502d-4500-bf57-a7cf0b4b2364", "app_name": "repliseq-parta"}',
#  'name': 'repliseq-parta_4DNFI64XJOEQe8566448-0dcc-4da8-b4b1-86b39cf1c1be',
#  'startDate': '2018-08-09 19:15:12.881000+00:00',
#  'stateMachineArn': 'arn:aws:states:us-east-1:643366669028:stateMachine:tibanna_pony',
#  'status': 'RUNNING'}
