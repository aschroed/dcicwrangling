DNA FISH on Chr18	misteli:160922_8
DNA FISH on Chr18	misteli:160922_7
DNA FISH on Chr18	misteli:160922_6
DNA FISH on Chr18	misteli:160922_5
DNA FISH on Chr18	misteli:160922_4
DNA FISH on Chr18	misteli:160922_3
DNA FISH on Chr18	misteli:160922_2
DNA FISH on Chr18	misteli:160922_1
DNA FISH on Chr18	misteli:160905_14
DNA FISH on Chr18	misteli:160905_13
DNA FISH on Chr18	misteli:160905_12
DNA FISH on Chr18	misteli:160905_11
DNA FISH on Chr18	misteli:160905_10
DNA FISH on Chr18	misteli:160905_9
DNA FISH on Chr18	misteli:160905_8
DNA FISH on Chr18	misteli:160905_7
DNA FISH on Chr18	misteli:160905_6
DNA FISH on Chr18	misteli:160905_5
DNA FISH on Chr18	misteli:160905_4
DNA FISH on Chr18	misteli:160905_3
DNA FISH on Chr18	misteli:160905_2
DNA FISH on Chr18	misteli:160905_1
DNA FISH on Chr18	misteli:161005_12
DNA FISH on Chr18	misteli:161005_11
DNA FISH on Chr18	misteli:161005_10
DNA FISH on Chr18	misteli:161005_9
DNA FISH on Chr18	misteli:161005_8
DNA FISH on Chr18	misteli:161005_7
DNA FISH on Chr18	misteli:161005_6
DNA FISH on Chr18	misteli:161005_5
DNA FISH on Chr18	misteli:161005_4
DNA FISH on Chr18	misteli:161005_3
DNA FISH on Chr18	misteli:161005_2
DNA FISH on Chr18	misteli:161005_1
DNA FISH on Chr1 and Chr17	misteli:160829_14
DNA FISH on Chr1 and Chr17	misteli:160829_13
DNA FISH on Chr1 and Chr17	misteli:160829_12
DNA FISH on Chr1 and Chr17	misteli:160829_11
DNA FISH on Chr1 and Chr17	misteli:160829_10
DNA FISH on Chr1 and Chr17	misteli:160829_9
DNA FISH on Chr1 and Chr17	misteli:160829_8
DNA FISH on Chr1 and Chr17	misteli:160829_7
DNA FISH on Chr1 and Chr17	misteli:160829_6
DNA FISH on Chr1 and Chr17	misteli:160829_5
DNA FISH on Chr1 and Chr17	misteli:160829_4
DNA FISH on Chr1 and Chr17	misteli:160829_3
DNA FISH on Chr1 and Chr17	misteli:160829_2
DNA FISH on Chr1 and Chr17	misteli:160829_1'''

add=[]
for i in text.split('\n'):
    des, ac = i.split('\t')
    res = ff_utils.get_metadata(ac,key=my_key)
    if res['status'] == 'archived':
        print('skipped')
    else:
        add.append(ac)
print(len(add))
# Out:
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# skipped
# 245

# %%
add.append('4DNES9L4AK6Q')
ff_utils.patch_metadata({"exp_sets_prod_in_pub":add}, obj_id='80007b23-7748-4492-9e49-c38400acbe60', key=my_key)
# Out:
# {'@graph': [{'@id': '/publications/80007b23-7748-4492-9e49-c38400acbe60/',
#    '@type': ['Publication', 'Item'],
#    'ID': 'doi:10.1101/171801',
# ...

# %%
def find_loc(chr, no, probes):
    chr = str(chr)
    no = str(no)
    if '.0' in no:
        no = no.split(".0")[0]
        
    found = False
    
    for ix in probes:
        if ix[1] == chr:
            if ix[4] == no:
                if ix[2] == 'missing':
                    print('need to fix')
                return [ix[0], ix[1], ix[2], ix[3]]

    print('not found', chr, no)
    return False
        
                
for i, row in df.iterrows():
    p_chr = row['chr']
    bait = row['Bait']
    target = row['Target']
    b_l = find_loc(p_chr, bait, probes)
    t_l = find_loc(p_chr, target, probes)
    
    if b_l:   
        df.at[i,'Bait Chr'] = b_l[1]
        df.at[i,'Bait Start'] = b_l[2]
        df.at[i,'Bait End'] = b_l[3]
    else:
        df.at[i,'Bait Chr'] = None
        df.at[i,'Bait Start'] = None
        df.at[i,'Bait End'] = None
        
    if t_l:
        df.at[i,'Target Chr'] = t_l[1]
        df.at[i,'Target Start'] = t_l[2]
        df.at[i,'Target End'] = t_l[3]
    else:
        df.at[i,'Target Chr'] = None
        df.at[i,'Target Start'] = None
        df.at[i,'Target End'] = None


df.shape
# Out:
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# not found 1 88
# ...

# %%
df.columns.values
# Out:
# array(['assay.id', 'nrow', 'ncol', 'Bait', 'Target', 'chr', 'FieldIndex',
#        'CellIndex', 'BaitSpotIndex', 'TargetSpotIndex', 'SpotDist.2D',
#        'SpotDist.3D', 'Bait Chr', 'Bait Start', 'Bait End', 'Target Chr',
#        'Target Start', 'Target End'], dtype=object)

# %%
df_drop = df.dropna(subset=['Bait Chr', 'Bait Start', 'Bait End', 'Target Chr',
       'Target Start', 'Target End','nrow', 'ncol'])
df_drop.shape
# Out:
# (974587, 18)

# %%
df_drop.columns.values
# Out:
# array(['assay.id', 'nrow', 'ncol', 'Bait', 'Target', 'chr', 'FieldIndex',
#        'CellIndex', 'BaitSpotIndex', 'TargetSpotIndex', 'SpotDist.2D',
#        'SpotDist.3D', 'Bait Chr', 'Bait Start', 'Bait End', 'Target Chr',
#        'Target Start', 'Target End'], dtype=object)

# %%
df_final = df_drop[['Bait Chr', 'Bait Start', 'Bait End', 'Target Chr',
       'Target Start', 'Target End', 'chr', 'FieldIndex',
       'CellIndex', 'BaitSpotIndex', 'TargetSpotIndex', 'SpotDist.2D',
       'SpotDist.3D', 'assay.id', 'nrow', 'ncol', 'Bait', 'Target']]
df_final.shape
# Out:
# (974587, 18)

# %%
df_final.head()
# Out:
#   Bait Chr Bait Start   Bait End Target Chr Target Start Target End  chr  \
# 0        4  150978277  151124968          4    151542617  151679223    4
# 1        4  150978277  151124968          4    151542617  151679223    4
# 2        4  150978277  151124968          4    151542617  151679223    4
# 3        4  150978277  151124968          4    151542617  151679223    4
# 4        4  150978277  151124968          4    151542617  151679223    4
#
#    FieldIndex  CellIndex  BaitSpotIndex  TargetSpotIndex  SpotDist.2D  \
# 0           1          1              1                1     0.108333
# 1           1          1              2                2     0.390600
# 2           1          2              1                1     0.216666
# 3           1          2              2                2     0.433332
# 4           1          4              1                1     0.459618
#
#    SpotDist.3D   assay.id  nrow  ncol   Bait  Target
# ...

# %%
df_final.to_csv('/Users/koray/Desktop/misteli/minDist.All.DCIC_filtered.txt')
