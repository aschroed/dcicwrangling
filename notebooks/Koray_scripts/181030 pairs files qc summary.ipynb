# %%
from dcicutils import ff_utils
from functions.notebook_functions import *

# get key from file
my_key = get_key('koray_data')

# all usable env names
all_envs = ['data', 'staging', 'fourfront-webdev', 'fourfront-mastertest', 'fourfront-hotseat']
# get admin key from s3
#my_key = ff_utils.get_authentication_with_server({}, ff_env = 'data')

# %%
q = '/search/?file_format.file_format=pairs&file_type=contact+list-replicate&file_type=contact+list-combined&quality_metric.uuid%21=No+value&status=uploaded&status=released&status=released&status=released+to+project&type=FileProcessed'
gen = ff_utils.search_metadata(q, key=my_key)
print(len(gen))
# Out:
# 489

# %%
for f in gen:
    qc = f['quality_metric']
    cis = qc["Cis reads (>20kb)"]
    tra = qc["Trans reads"]
    tot = qc["Total reads"]
    scis = qc["Short cis reads (<20kb)"]
    print(f['accession'],f['file_type'][13:], int(f['file_size']/(1024*1024*1024)), int(cis/tot*100.),int(scis/tot*100.), int(tra/tot*100.))
# Out:
# 4DNFIRCC7SFB combined 2 49 38 12
# 4DNFIKNWM36K combined 1 45 43 10
# 4DNFI7FT7REY replicate 1 46 43 9
# 4DNFITUPOL6I replicate 1 51 32 15
# 4DNFI6U9TG2B replicate 1 47 41 11
# 4DNFIZ8QOUA3 replicate 0 44 46 8
# 4DNFIA1SQZR5 combined 2 48 21 29
# 4DNFIEKCLUSM replicate 3 59 20 19
# 4DNFI7TR3V8M replicate 1 46 22 30
# 4DNFI65WJKMT combined 39 40 26 33
# 4DNFIQ4G74OW combined 35 37 27 35
# 4DNFIHTCMTBB replicate 0 48 24 27
# 4DNFIIDPB2DF combined 4 44 26 28
# 4DNFIOQ6KYMN combined 4 33 44 21
# 4DNFICIK4Y8I combined 3 42 32 25
# 4DNFI93VQW93 combined 4 49 33 17
# 4DNFIQWVV324 combined 7 58 19 22
# 4DNFI82JWZX8 combined 1 56 21 22
# 4DNFIIX5BNC9 combined 2 55 20 23
# 4DNFIY4IX5PI replicate 22 41 25 33
# 4DNFIEI947LD replicate 19 38 27 34
# 4DNFI3265LZT replicate 16 36 26 37
# 4DNFIMA6DZHF replicate 21 38 28 33
# 4DNFISDBD9PO combined 3 8 84 7
# 4DNFIRHCPFJ9 combined 3 5 86 7
# 4DNFICZ94KJD replicate 1 9 83 7
# 4DNFIYCP7T2H replicate 1 7 85 7
# 4DNFIHSEIO32 replicate 1 5 86 7
# 4DNFIL87S5VW replicate 1 4 86 8
# 4DNFIQ9X577Y replicate 2 44 28 27
# 4DNFIHUXVEYU replicate 1 42 25 31
# 4DNFI5Y9LO42 replicate 1 13 78 7
# 4DNFITG7ZWQL replicate 1 52 26 21
# 4DNFIJOJ3OLJ replicate 0 62 14 23
# 4DNFIYSFSI4P replicate 0 60 16 22
# 4DNFIYMLP8C5 replicate 1 52 23 24
# 4DNFI4K87ZXW replicate 2 48 19 31
# 4DNFIDIOB1IS replicate 1 47 29 23
# 4DNFIHT36NUP replicate 4 60 23 16
# 4DNFILEWWANZ replicate 2 38 34 26
# 4DNFINMUWU5V replicate 2 53 28 18
# 4DNFI6I5F4FD replicate 1 43 40 16
# 4DNFIT6XTO39 replicate 1 12 80 6
# 4DNFIYM6F8Y5 replicate 2 21 68 10
# 4DNFI5463BGB replicate 1 50 20 28
# 4DNFIVSPDVD2 replicate 3 59 18 21
# 4DNFISNLJWVH replicate 3 57 20 22
# 4DNFIASLBBXV combined 18 56 30 12
# 4DNFIZ3RDODA combined 7 26 63 10
# 4DNFICLCWWLH replicate 8 48 40 11
# 4DNFI3Y5YTC6 combined 6 35 54 9
# 4DNFIDHNCVEM combined 9 52 33 14
# 4DNFIW3YHQXS combined 7 27 58 13
# 4DNFIIUM9A7W combined 2 26 58 15
# 4DNFIG5TY53R combined 0 59 24 16
# 4DNFIXZQSFQZ combined 0 54 24 20
# 4DNFIBDZ8KDQ replicate 12 62 24 13
# 4DNFIYRP9RLI replicate 3 17 73 9
# 4DNFIQIXK1HJ combined 0 54 16 28
# 4DNFIKYF3V7I replicate 5 45 39 15
# 4DNFI6S3I9XZ replicate 6 34 48 16
# 4DNFIAUTKRU7 combined 0 56 21 22
# 4DNFI2W2IZNS combined 0 55 26 18
# 4DNFI8B3YH87 combined 0 57 15 27
# 4DNFIYYYDX3Z combined 0 51 19 28
# 4DNFIAUN2JFY combined 0 58 22 19
# 4DNFIA3HP8UK combined 0 53 24 21
# 4DNFIMZCZMCK combined 0 63 21 14
# 4DNFIOZFDQWK combined 0 62 22 15
# 4DNFISMGV1P6 combined 0 63 21 14
# 4DNFIPO83K6L combined 0 57 25 16
# 4DNFI1RI8CH9 combined 0 52 24 23
# 4DNFI35Q4EYQ combined 0 52 24 22
# 4DNFID3GB9S5 combined 0 45 29 25
# 4DNFIF8DU9R3 combined 0 63 21 15
# 4DNFIWA7Q3JF combined 0 55 23 21
# 4DNFI4VWKT5E combined 0 55 22 22
# 4DNFICVK3ARK combined 0 55 24 20
# 4DNFITRRRBZD combined 0 54 21 23
# 4DNFIVPADLI2 replicate 2 61 27 10
# 4DNFIVMRIR5H replicate 4 59 25 14
# 4DNFIUZJOJW9 replicate 2 10 82 6
# 4DNFIWMKPCJS combined 0 53 20 25
# 4DNFIWU9T2FE combined 0 57 19 22
# 4DNFIA21WDYH combined 0 59 25 15
# 4DNFIF2WIXVB combined 2 6 76 17
# 4DNFI3V7X4CJ combined 6 4 78 16
# 4DNFIJTB6SBF combined 5 34 47 17
# 4DNFIZDCXIL7 combined 1 11 78 9
# 4DNFIWRDI1OS combined 2 8 81 9
# 4DNFID43ITQ1 combined 2 31 60 8
# 4DNFI59XA48J combined 0 54 25 19
# 4DNFIDAHLNNV combined 0 52 14 33
# 4DNFIVTA8GEE combined 0 45 28 25
# 4DNFIALFP4HV combined 0 55 20 24
# 4DNFILZBUG96 combined 4 46 26 26
# 4DNFI5NBOQL6 combined 2 59 23 16
# 4DNFI2WWXWR3 combined 24 25 59 14
# 4DNFI21EIR1D combined 4 24 46 29
# 4DNFIFCQQAGT combined 5 24 46 28
# 4DNFIC12SGRA combined 6 17 48 34
# 4DNFI53L5LSY combined 4 30 36 32
# 4DNFILL56BEZ replicate 1 18 71 9
# 4DNFI6IZYDDW combined 2 23 63 13
# 4DNFICAV2SHE combined 2 25 53 21
# 4DNFI2S641OK combined 1 26 59 14
# 4DNFI7BB4SOR combined 2 48 21 29
# 4DNFIOW2L46Z combined 28 40 22 36
# 4DNFIB5G24G6 combined 21 42 21 36
# 4DNFIHZIIVXC combined 48 19 74 6
# 4DNFIXTMCDBY replicate 0 36 37 26
# 4DNFI2S53S41 replicate 2 23 63 13
# 4DNFIEJIO7TQ replicate 2 25 53 21
# 4DNFIAIDD5SM replicate 1 26 59 14
# 4DNFICUP7WGM replicate 2 48 21 29
# 4DNFIRAHL9B5 replicate 7 26 63 10
# 4DNFI1KTTETW replicate 0 26 64 9
# 4DNFIOLCUOJ5 replicate 0 37 42 20
# 4DNFI2CSMBT8 replicate 3 3 81 14
# 4DNFILJZ2US1 replicate 2 4 78 16
# 4DNFIJRZZ2WP replicate 1 7 72 19
# 4DNFILEZCXE8 replicate 3 34 47 18
# 4DNFIE95P87I replicate 0 54 19 25
# 4DNFIV9QH4LQ replicate 0 58 15 25
# 4DNFILXTX2FK replicate 2 33 46 20
# 4DNFIEXMANLK replicate 0 63 18 17
# 4DNFIAMWRV1G replicate 0 62 22 15
# 4DNFI3ABDDOV replicate 0 59 24 15
# 4DNFIOKONCOP replicate 2 49 28 22
# 4DNFI25GTKYT replicate 2 44 25 30
# 4DNFISBCWNBV replicate 1 59 23 16
# 4DNFIH69H81W replicate 1 60 23 16
# 4DNFI5DA67YU replicate 0 8 69 22
# 4DNFITMP41L8 replicate 0 11 62 26
# 4DNFIHT2VYC1 replicate 1 2 87 9
# 4DNFIXB7BSRD replicate 0 10 81 8
# 4DNFIIFTZ6EH replicate 2 34 47 17
# 4DNFI2ZOWMSI replicate 0 10 80 9
# 4DNFIF4ROSFQ replicate 0 15 72 12
# 4DNFIPD15L7F replicate 0 7 85 6
# 4DNFIPO3B1PB replicate 0 6 85 8
# 4DNFILGYM2LC replicate 0 9 82 8
# 4DNFIP14P3DA replicate 0 11 75 12
# 4DNFIER3LJY8 replicate 0 6 85 7
# 4DNFIDD1ZPCX replicate 1 32 58 9
# 4DNFIO5UB723 replicate 1 30 61 7
# 4DNFIY3CIM91 replicate 2 36 42 21
# 4DNFIHBGHFJW replicate 3 22 47 30
# 4DNFILYZ9YSA replicate 1 27 45 26
# 4DNFI1I3NFHG replicate 2 29 47 23
# 4DNFIV57K7CS replicate 3 21 46 31
# 4DNFIPZK844C replicate 3 17 46 35
# 4DNFIO2FMSL3 replicate 3 17 49 32
# 4DNFI6ZBWB81 replicate 2 29 37 32
# 4DNFI85DU7IM replicate 2 32 35 31
# 4DNFID618BP5 combined 13 30 48 21
# 4DNFIES3S7VJ combined 9 47 28 24
# 4DNFIREZHHOV combined 15 65 19 15
# 4DNFIZ3R6HD9 combined 11 56 29 14
# 4DNFIA52PMNW combined 10 59 21 19
# 4DNFIW175DY7 combined 11 66 17 15
# 4DNFIEV8B3CZ combined 13 59 24 16
# 4DNFIF6UEOC7 combined 13 59 18 22
# 4DNFIL8WH9W9 combined 4 58 21 19
# 4DNFIOWTBACC combined 10 37 25 36
# 4DNFI1QBCSKR combined 11 46 19 33
# 4DNFIWAA9Q8H combined 5 59 20 19
# 4DNFIC5AHBPV combined 9 48 15 36
# 4DNFIB13H9QZ replicate 25 25 36 38
# 4DNFITS4P1QA combined 1 15 51 32
# 4DNFIQ2UKELM combined 3 52 17 30
# 4DNFIT3RD5VO replicate 1 27 41 30
# 4DNFI155DWSK replicate 0 31 46 21
# 4DNFI54UUBPY replicate 1 33 50 16
# 4DNFITHXDLLC replicate 1 36 46 17
# 4DNFISMHCSSH replicate 1 31 51 16
# 4DNFI5DDBY89 replicate 0 28 48 23
# 4DNFI37N5TCD replicate 1 37 44 17
# 4DNFIL9C2NVL replicate 0 15 54 30
# 4DNFIX9FYTTA replicate 1 32 50 17
# 4DNFIS6ISGW7 replicate 0 13 56 29
# 4DNFI8L2GKFO replicate 0 25 46 27
# 4DNFIYOUXDA5 replicate 0 29 41 29
# 4DNFI9U9NJ89 replicate 0 28 43 28
# 4DNFIKP2V6HQ replicate 0 18 58 22
# 4DNFI6ETC1JB replicate 0 35 41 22
# 4DNFIT57JYMU replicate 15 65 19 15
# 4DNFIHTXJC8B replicate 11 56 29 14
# 4DNFI224W9FM replicate 11 66 17 15
# 4DNFIHCQLL2H replicate 10 59 21 19
# 4DNFILWV3C1I replicate 13 59 24 16
# 4DNFIQXWVVB6 replicate 13 59 18 22
# 4DNFI3O8M6SZ replicate 8 38 24 37
# 4DNFIBEV8M9E replicate 21 41 21 36
# 4DNFI2HQA2EE replicate 5 42 16 40
# 4DNFIVN95UEZ replicate 5 33 34 32
# 4DNFIBO9M2WY replicate 7 47 21 30
# 4DNFIDFRSE2G replicate 4 44 16 38
# 4DNFI4PDERVK replicate 5 59 20 19
# 4DNFIEIEFZMD replicate 10 40 22 36
# 4DNFICY5CI8Q replicate 12 43 20 35
# 4DNFI3CBEV3I replicate 9 45 21 32
# 4DNFIC2O325X replicate 6 48 15 35
# 4DNFIPWEWCY3 replicate 4 47 14 37
# 4DNFIYECESRC combined 72 53 21 25
# 4DNFI2EK1IOQ combined 6 57 25 17
# 4DNFIU585JSM replicate 1 46 34 19
# 4DNFIUHPB9VC combined 4 59 18 22
# 4DNFI5BZAVNR combined 5 48 29 22
# 4DNFIDDMNL9R combined 7 47 33 18
# 4DNFIXIFOEV9 combined 8 45 21 33
# 4DNFIWMYVPYD combined 6 35 20 44
# 4DNFI25TK6MT combined 17 24 50 25
# 4DNFIJEOJ221 combined 51 46 22 31
# 4DNFI6GHPTLB replicate 1 48 32 18
# 4DNFINOS8VK8 replicate 1 54 26 19
# 4DNFI6VCVYAL combined 12 40 27 32
# 4DNFIO9HS2U4 replicate 1 15 51 32
# 4DNFI8XISGKL replicate 3 52 17 30
# 4DNFI8JEIBV6 replicate 3 39 24 36
# 4DNFIT7H8HNZ replicate 2 41 19 38
# 4DNFITBTZVSY replicate 4 30 21 47
# 4DNFIU22GSZG combined 0 19 18 61
# 4DNFINFW7GAJ combined 6 50 27 22
# 4DNFIIG4IWKW combined 19 57 25 16
# 4DNFIWE8W2WS combined 2 15 44 39
# 4DNFIXKAVZL3 combined 7 27 17 55
# 4DNFITU7K8VQ combined 45 30 16 52
# 4DNFIOTABE46 combined 3 33 17 48
# 4DNFIE9XZEIP combined 2 40 35 24
# 4DNFI733IUMB combined 3 46 22 30
# 4DNFIWGGYEW2 combined 13 54 29 16
# 4DNFISGO7OS7 replicate 24 33 16 50
# 4DNFI2R1W3YW combined 16 56 20 22
# 4DNFIACOTIGL combined 10 25 18 55
# 4DNFIQJLTRNZ combined 13 36 20 43
# 4DNFIINYRY8H replicate 25 30 16 52
# 4DNFILR6CKEJ replicate 23 30 16 53
# 4DNFINYPH4LW replicate 0 55 23 21
# 4DNFIDIYN1II replicate 0 53 25 21
# 4DNFI9ZFRE7L replicate 0 47 29 23
# 4DNFISVDXLEZ replicate 0 59 22 17
# 4DNFIGK86M6L replicate 0 49 30 20
# 4DNFI3TCHWVK replicate 0 54 15 29
# 4DNFI49Q1SBS replicate 0 55 24 19
# 4DNFI3Q32WJP replicate 0 59 22 18
# 4DNFIPNVIPH2 replicate 5 25 18 55
# 4DNFIBTBLZPT replicate 0 62 17 20
# 4DNFI2HTCYH7 replicate 0 53 29 17
# 4DNFIROD4C9U replicate 0 57 25 16
# 4DNFI3U9YFLF replicate 0 55 26 18
# 4DNFIHQR1GCT replicate 0 54 22 22
# 4DNFIKQO3N4X replicate 0 53 14 32
# 4DNFIH2DFKQM replicate 0 61 22 16
# 4DNFING6ZFDF replicate 8 22 59 18
# 4DNFIMT4PHZ1 replicate 3 24 61 13
# 4DNFIATMYDMG replicate 4 51 28 19
# 4DNFIMYACUIM replicate 2 60 23 15
# 4DNFILKTQCKE replicate 0 51 24 24
# 4DNFIRI9EXKZ replicate 0 59 22 18
# 4DNFIZZMH77V replicate 0 59 22 18
# 4DNFI4SLDM4I replicate 0 54 23 22
# 4DNFITCY5DED replicate 0 58 26 14
# 4DNFIMUQ1JN9 replicate 0 52 24 22
# 4DNFIJL1WMK2 replicate 0 55 21 22
# 4DNFIT3D7P5N replicate 0 52 25 21
# 4DNFIPMCVMBU replicate 0 54 24 20
# 4DNFIW2BKSNF replicate 3 59 25 14
# 4DNFI6FXMIGS replicate 1 37 33 29
# 4DNFIV92ZW1J replicate 3 25 13 60
# 4DNFILOL3RLR replicate 3 29 22 48
# 4DNFIS8JO2QX replicate 0 50 26 23
# 4DNFIUY2P7SH replicate 0 55 14 30
# 4DNFIH8C9SZD replicate 0 56 14 28
# 4DNFIIR9PN72 replicate 0 53 20 25
# 4DNFIWJOITMI replicate 0 51 19 28
# 4DNFILTHMYLW replicate 0 57 24 17
# 4DNFICBVHXUA replicate 0 58 17 24
# 4DNFI3O82QVV replicate 2 57 20 21
# 4DNFIIB2U8M1 replicate 0 65 20 14
# 4DNFI2HTENAI replicate 2 51 30 17
# 4DNFI7E69FHJ replicate 0 18 43 37
# 4DNFI24MDDBZ replicate 4 50 29 20
# 4DNFIWO1FTN5 replicate 0 49 27 22
# 4DNFIZTW3MEY replicate 4 56 26 16
# 4DNFI2MWGKFU replicate 0 55 23 20
# 4DNFIZZBAFJX replicate 0 62 18 18
# 4DNFIBMG8YA3 replicate 5 33 49 16
# 4DNFI8GM4EL9 replicate 8 23 66 9
# 4DNFIRHH2E7D replicate 1 54 11 34
# 4DNFIZG1VRKW replicate 28 44 22 33
# 4DNFI5G9HJMT replicate 0 9 50 39
# 4DNFI91S1U76 replicate 0 58 15 25
# 4DNFIEIE3ZA2 replicate 0 53 25 21
# 4DNFIMN8T3ND replicate 0 56 22 21
# 4DNFIJVTLLVW replicate 0 55 21 23
# 4DNFIZPYZTBX replicate 0 55 20 24
# 4DNFIHGRXQWZ replicate 3 46 22 30
# 4DNFIV4NK5UG replicate 0 57 14 27
# 4DNFIXSRR92O replicate 0 59 26 13
# 4DNFIJA2ICDW replicate 0 54 21 23
# 4DNFIJMOWTE1 replicate 0 61 21 16
# 4DNFI4PQ4BSE replicate 0 53 24 21
# 4DNFIILGVREY replicate 5 25 18 55
# 4DNFIFRBPPVE replicate 0 63 21 14
# 4DNFIGKYRZBT replicate 0 43 41 14
# 4DNFIT5LC9RX replicate 1 25 13 60
# 4DNFILXNOYC7 replicate 0 47 35 17
# 4DNFIA8OXKNB replicate 0 44 32 23
# 4DNFIU3H6H3W replicate 0 53 13 32
# 4DNFIFH9S9J5 replicate 0 60 26 13
# 4DNFIQUDP8EU replicate 0 45 28 25
# 4DNFIKFV5Y88 replicate 1 54 11 34
# 4DNFI1M8IANX replicate 4 39 21 39
# 4DNFI4DGNY7J replicate 6 58 25 16
# 4DNFI2H4JHCG replicate 0 53 17 29
# 4DNFIJCD92IB replicate 0 54 22 22
# 4DNFIIWJWJV5 replicate 0 51 13 34
# 4DNFIV39S65V replicate 0 53 24 21
# 4DNFIBIDW6KL replicate 0 64 19 15
# 4DNFI7CIF2JL replicate 1 54 12 33
# 4DNFIQ5RZSXU replicate 0 58 15 26
# 4DNFIW581OQ3 replicate 0 57 19 22
# 4DNFIX3XYSU2 replicate 0 56 23 19
# 4DNFIF79FS7Z replicate 0 54 25 19
# 4DNFISUCPLVT replicate 0 42 30 26
# 4DNFIUAUS2H6 replicate 0 45 27 27
# 4DNFISXSDGJH replicate 0 54 23 21
# 4DNFI6RW6BDI replicate 0 61 23 14
# 4DNFIPJGCH5R combined 6 28 32 38
# 4DNFIBC4JJSB combined 3 14 26 58
# 4DNFI7EMQA79 combined 6 30 29 40
# 4DNFI7RUGED8 combined 5 32 26 41
# 4DNFI864X1JK combined 2 39 19 41
# 4DNFIXC4LZNP combined 3 16 16 66
# 4DNFI1JBDZA8 combined 3 39 24 36
# 4DNFI91AL21C combined 5 33 20 45
# 4DNFIWH1KVD4 combined 2 63 17 19
# 4DNFII461Q5Z combined 3 34 22 43
# 4DNFIK4PEOP8 combined 6 56 23 19
# 4DNFILA6HZAY combined 3 52 27 19
# 4DNFI32BAWJ2 combined 3 34 28 37
# 4DNFIUO8KG4O combined 8 40 18 40
# 4DNFISUIRRB3 combined 1 8 38 52
# 4DNFIGDS8FEX combined 2 35 18 45
# 4DNFIIQ5YL7C combined 10 42 27 29
# 4DNFI8HHP7VN combined 7 48 17 33
# 4DNFIJGGRF79 combined 6 30 34 34
# 4DNFI5OYZND2 combined 3 60 24 14
# 4DNFIEU7B3RD combined 2 51 28 19
# 4DNFIIFAUT24 combined 6 45 29 25
# 4DNFIYL35EHL combined 4 48 15 36
# 4DNFI4EYPEYT combined 3 46 19 33
# 4DNFIEIXESWQ combined 2 46 34 18
# 4DNFIZ9DS7VN combined 16 39 27 33
# 4DNFINLG3IU4 combined 1 34 29 35
# 4DNFI2R1VS8E combined 3 61 17 20
# 4DNFII6CJBM5 replicate 5 48 20 31
# 4DNFIO9FYBN9 replicate 1 32 27 39
# 4DNFII4JC7KV replicate 12 17 49 32
# 4DNFIJHG5AA8 replicate 5 46 29 24
# 4DNFIACGE2DJ replicate 9 47 28 24
# 4DNFIS1QJDPA replicate 5 25 18 55
# 4DNFI654OVO4 replicate 3 43 18 38
# 4DNFIGQBMKEG replicate 3 29 27 42
# 4DNFIXXM1IBQ replicate 5 39 18 41
# 4DNFIX4AIQHN replicate 3 27 35 37
# 4DNFIU9WBSFC replicate 2 39 19 40
# 4DNFIOSJRQD7 replicate 4 26 33 40
# 4DNFIOCWXJ7G replicate 3 29 26 44
# 4DNFIFTMART5 replicate 1 41 33 25
# 4DNFIIO9OYD9 replicate 2 51 28 19
# 4DNFIDO73LLP replicate 2 63 17 19
# 4DNFIRLIHSBS replicate 1 38 19 42
# 4DNFISPRKYIO replicate 2 14 30 55
# 4DNFI7EWKU92 replicate 1 37 28 33
# 4DNFIGC79U53 replicate 2 40 21 38
# 4DNFISGG3QI2 replicate 1 38 19 42
# 4DNFI197IG9Y replicate 1 15 22 62
# 4DNFIQMLUCDP replicate 1 35 28 35
# 4DNFIQZ5VUS8 replicate 1 52 27 20
# 4DNFI7A95OFH replicate 1 30 25 44
# 4DNFI1FP4C98 replicate 2 35 17 46
# 4DNFIUSHIK15 replicate 0 36 41 21
# 4DNFIDQOLVA1 replicate 1 12 15 71
# 4DNFIO5MTMI8 replicate 1 38 18 42
# 4DNFIDUCCV8B replicate 6 39 26 33
# 4DNFITW2EGPF replicate 3 37 21 41
# 4DNFICHGXIC3 replicate 3 31 32 36
# 4DNFIPHSDRFL replicate 3 28 21 50
# 4DNFISNS2EBY replicate 4 13 64 22
# 4DNFIEBHQU8O replicate 7 48 17 33
# 4DNFIFGHMCXK replicate 2 35 32 31
# 4DNFIN5BWCF2 replicate 5 35 17 47
# 4DNFIV74X7T4 replicate 3 31 31 36
# 4DNFIREXVV6S replicate 2 36 40 23
# 4DNFI3G7ACRU replicate 1 33 18 48
# 4DNFI7KA982D replicate 3 15 65 19
# 4DNFIJWAAHYH replicate 1 8 38 52
# 4DNFI6GC9T2Y replicate 2 35 24 40
# 4DNFIRYYHEUI replicate 0 21 16 62
# 4DNFI6VABEIW replicate 0 16 21 61
# 4DNFICPNG5HJ replicate 1 31 18 50
# 4DNFIBXVKLYT replicate 1 40 19 39
# 4DNFILS6PDR3 replicate 2 19 17 62
# 4DNFI5M796WN replicate 5 42 18 39
# 4DNFI1PYJDJX replicate 2 17 65 16
# 4DNFIZWEE353 replicate 1 29 28 42
# 4DNFI2KMRDTF replicate 1 31 27 40
# 4DNFIDP8MAP7 replicate 1 13 30 55
# 4DNFIE41V9R6 replicate 1 23 53 23
# 4DNFIU832CGU replicate 1 52 28 18
# 4DNFIBHI5YI9 replicate 8 19 74 6
# 4DNFIJZDEIZ3 replicate 8 19 74 5
# 4DNFICOEXGPJ replicate 8 19 74 6
# 4DNFIN7IIIY6 replicate 8 19 73 6
# 4DNFIYBTHGNA replicate 8 20 74 5
# 4DNFIK8UIB5B replicate 8 19 73 6
# 4DNFIIT7LQ6M replicate 2 53 25 21
# 4DNFI7HPMW1O replicate 28 44 22 33
# 4DNFISQCBGL1 replicate 2 58 26 14
# 4DNFIUXFBVHA replicate 1 53 26 20
# 4DNFIMU9T2QI replicate 1 59 23 17
# 4DNFIL8A48BN replicate 3 56 23 19
# 4DNFIMLQR82B replicate 0 51 27 20
# 4DNFIGSQVM9I replicate 0 60 20 19
# 4DNFIOYAO8IF replicate 3 49 27 23
# 4DNFI36TIXEX replicate 1 46 15 38
# 4DNFIHUVCM35 replicate 4 51 31 16
# 4DNFIAAUZ7EP replicate 3 62 20 17
# 4DNFI7QWGXGQ replicate 0 48 32 18
# 4DNFIWBALW9K replicate 1 49 15 34
# 4DNFIAIBSEAG replicate 27 47 23 28
# 4DNFIANAU65D replicate 2 58 24 17
# 4DNFIPAEWHQC replicate 3 54 27 17
# 4DNFIQQRRQSP replicate 0 12 55 31
# 4DNFIG4GG38V replicate 5 40 25 34
# 4DNFI34KOJMZ replicate 2 45 15 38
# 4DNFIA38JZQ6 replicate 2 54 24 20
# 4DNFIKQY3ILC replicate 3 39 12 47
# 4DNFIIS73OJN replicate 4 57 21 21
# 4DNFIF71VGQ3 replicate 1 51 15 32
# 4DNFIXR9BRGT replicate 2 51 16 32
# 4DNFI97O9SAZ replicate 6 44 28 26
# 4DNFIYBWQG4A replicate 2 57 18 24
# 4DNFI3T437K2 replicate 3 38 13 48
# 4DNFID8N3SCC replicate 1 53 10 36
# 4DNFIQ65WNKK replicate 1 57 17 24
# 4DNFINB9OWO9 replicate 3 61 17 20
# 4DNFIWO14LYW replicate 2 50 31 17
# 4DNFIHJQRHCL replicate 3 45 15 38
# 4DNFIXUCQWSJ replicate 0 8 31 60
# 4DNFI74S4R6N replicate 0 18 36 44
# 4DNFIZGHJ9EM replicate 4 50 16 33
# 4DNFI6GY4932 replicate 4 37 30 32
# 4DNFI9G9FRJJ replicate 5 55 23 20
# 4DNFIKZP38N6 replicate 0 32 47 20
# 4DNFIUVGBN25 replicate 1 49 29 21
# 4DNFIK433OI5 replicate 4 58 21 19
# 4DNFIY6348QN replicate 3 35 31 32
# 4DNFIWSXKIRR replicate 0 45 31 23
# 4DNFI1RTJOBJ replicate 1 36 29 34
# 4DNFIR53NCUM replicate 1 39 42 17
# 4DNFI7ICGXY9 replicate 1 56 17 26
# 4DNFI3YOU78V replicate 1 42 38 18
# 4DNFI1W46362 replicate 0 57 18 23
# 4DNFI64TTB1C replicate 3 56 23 19
# 4DNFIG59MQN6 replicate 1 51 22 26
# 4DNFIZZO8TNU replicate 1 46 35 18
# 4DNFI2I5JC3L replicate 4 59 18 22
# 4DNFIN1XTP8M replicate 3 51 27 20
# 4DNFI1CMC4NQ replicate 5 52 16 31
# 4DNFIROARX7U replicate 5 52 17 30
# 4DNFIS5PRTL5 replicate 3 46 19 33
# 4DNFIMC4GWKO replicate 5 48 29 22
# 4DNFIHW7O3BR replicate 1 50 25 24
# 4DNFIXFQDLLU replicate 1 47 33 18
# 4DNFIH1ZQWOM replicate 3 58 25 16
# 4DNFIUOVQH68 replicate 7 56 23 19
# 4DNFIJAKH2X3 replicate 3 60 24 14
# 4DNFI563E6GS replicate 2 57 21 20
# 4DNFI4Y4Z7AF replicate 3 51 31 17
# 4DNFI8KN3VWI replicate 5 41 43 15
# 4DNFIDN4BQ8Z replicate 2 55 22 21
# 4DNFIMCSMWKT replicate 0 43 35 20
# 4DNFIFQL2K6N replicate 4 54 21 24
# 4DNFIW97L8UQ replicate 1 52 15 31
# 4DNFIVQZA7YJ replicate 1 52 16 31
# 4DNFIGYY2YMF replicate 1 23 24 51

# %%
text = '''4DNFIS1ZVUWO	restriction sites for MboI on the fruitfly genome build dm6, juicer-formatted
4DNFIO5MGY32	This tar-gzipped file includes the bwa index for the fruitfly genome build Release 6 (dm6)
4DNFIBEEN92C	Chromosome sizes file for the fruitfly genome build Release 6 (dm6); Only the assembled chromosomes are included; unlocalized or unplaced contigs are excluded. 
4DNFI9PGZ7S6	The reference fasta file for the fruitfly genome build Release 6 (dm6)
4DNFI0NK4G14	restriction sites for MboI on hg38, juicer-formatted
4DNFI3HVC1SE	restriction sites for DpnII on mm10, juicer-formatted
4DNFI3HVU20D	restriction sites for NcoII on hg38, juicer-formatted
4DNFI3UBJ3HZ	Chromosome sizes for mouse genome build mm10; Only the assembled chromosomes are included; unlocalized or unplaced contigs are excluded. 
4DNFIBNAPW30	restriction sites for DpnII on hg38, juicer-formatted
4DNFI823MBKE	restriction sites for HindIII on hg38, juicer-formatted
4DNFI823LSII	Chromosome sizes file for the human genome build hg38. Only the assembled chromosomes are included; unlocalized or unplaced contigs are excluded. 
4DNFI823L812	restriction sites for MboI on hg38, juicer-formatted
4DNFI823L811	restriction sites for HindIII on hg38, juicer-formatted (OLD)
4DNFI823LSI8	This tar-gzipped file includes the bwa index for the mouse genome build GRCm38. We use the UCSC mm10 version of the genome, corresponsing to GRCm38/GCA_000001635.2,  including the 22 assembled chromosomes (1-19, X, Y, M), the 22 unplaced contigs, and the 22 unlocalized contigs, but excluding any alternative sequences. This is the same reference as used by the ENCODE Consortium for data processing: https://www.encodeproject.org/data-standards/reference-sequences/ .
4DNFIZQZ39L9	This tar-gzipped file includes the bwa index for the human genome build GRCh38. We use the UCSC hg38 version of the genome, corresponsing to GRCh38/GCA_000001405.15 including the 25 assembled chromosomes (1-22, X, Y, M), the 127 unplaced contigs, the 42 unlocalized contigs, but excluding the 261 alternative haplotypes. The assembly also includes the Epstein-Barr virus (EBV) genome. This is the same reference as used by the ENCODE Consortium for data processing: https://www.encodeproject.org/data-standards/reference-sequences/ .'''

for t in text.split('\n'):
    i,d = t.split('	')
    ff_utils.patch_metadata({d})
# Out:
# 4DNFIS1ZVUWO
# restriction sites for MboI on the fruitfly genome build dm6, juicer-formatted
# 4DNFIO5MGY32
# This tar-gzipped file includes the bwa index for the fruitfly genome build Release 6 (dm6)
# 4DNFIBEEN92C
# Chromosome sizes file for the fruitfly genome build Release 6 (dm6); Only the assembled chromosomes are included; unlocalized or unplaced contigs are excluded.
# 4DNFI9PGZ7S6
# The reference fasta file for the fruitfly genome build Release 6 (dm6)
# 4DNFI0NK4G14
# restriction sites for MboI on hg38, juicer-formatted
# 4DNFI3HVC1SE
# restriction sites for DpnII on mm10, juicer-formatted
# 4DNFI3HVU20D
# restriction sites for NcoII on hg38, juicer-formatted
# 4DNFI3UBJ3HZ
# Chromosome sizes for mouse genome build mm10; Only the assembled chromosomes are included; unlocalized or unplaced contigs are excluded.
# 4DNFIBNAPW30
# restriction sites for DpnII on hg38, juicer-formatted
# 4DNFI823MBKE
# restriction sites for HindIII on hg38, juicer-formatted
# 4DNFI823LSII
# Chromosome sizes file for the human genome build hg38. Only the assembled chromosomes are included; unlocalized or unplaced contigs are excluded.
# 4DNFI823L812
# restriction sites for MboI on hg38, juicer-formatted
# 4DNFI823L811
# restriction sites for HindIII on hg38, juicer-formatted (OLD)
# 4DNFI823LSI8
# This tar-gzipped file includes the bwa index for the mouse genome build GRCm38. We use the UCSC mm10 version of the genome, corresponsing to GRCm38/GCA_000001635.2,  including the 22 assembled chromosomes (1-19, X, Y, M), the 22 unplaced contigs, and the 22 unlocalized contigs, but excluding any alternative sequences. This is the same reference as used by the ENCODE Consortium for data processing: https://www.encodeproject.org/data-standards/reference-sequences/ .
# 4DNFIZQZ39L9
# This tar-gzipped file includes the bwa index for the human genome build GRCh38. We use the UCSC hg38 version of the genome, corresponsing to GRCh38/GCA_000001405.15 including the 25 assembled chromosomes (1-22, X, Y, M), the 127 unplaced contigs, the 42 unlocalized contigs, but excluding the 261 alternative haplotypes. The assembly also includes the Epstein-Barr virus (EBV) genome. This is the same reference as used by the ENCODE Consortium for data processing: https://www.encodeproject.org/data-standards/reference-sequences/ .
