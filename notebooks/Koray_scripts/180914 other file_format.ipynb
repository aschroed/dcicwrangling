# %%
from dcicutils import ff_utils
from functions.notebook_functions import *

# get key from file
my_key = get_key('koray_data')

# all usable env names
all_envs = ['data', 'staging', 'fourfront-webdev', 'fourfront-mastertest', 'fourfront-hotseat']
# get admin key from s3
#my_key = ff_utils.get_authentication_with_server({}, ff_env = 'data')

# %%
q_a = '/search/?file_format=other&type=File'
q_d = '/search/?file_format=other&type=File&status=deleted'

for q in [q_a, q_d]:
    hits = ff_utils.search_metadata(q, key = my_key)
    for a_hit in hits:
        print(a_hit['@type'][0], a_hit.get('filename'))
# Out:
# FileProcessed pipeline.statistics.txt
# FileProcessed H1_LMNB1_replicate.html
# FileProcessed H1_r3_LMNB1_report.html
# FileProcessed H1_r2_LMNB1_report.html
# FileProcessed H1_r1_LMNB1_report.html
# FileProcessed HFF_LMNB1_replicate.html
# FileProcessed HFF_r2_LMNB1_report.html
# FileProcessed HFF_r1_LMNB1_report.html
# FileProcessed pipeline.statistics.txt
# FileProcessed HFF_LMNB1_replicate.html
# FileProcessed HFF_r2_LMNB1_report.html
# FileProcessed HFF_r1_LMNB1_report.html
# FileMicroscopy RefImg.tar.gz
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed H1_LMNB1_replicate.html
# FileProcessed H1_r2_LMNB1_report.html
# FileProcessed H1_r1_LMNB1_report.html
# FileProcessed pipeline.statistics.txt
# FileProcessed HFF_LMNB1_replicate.html
# FileProcessed HFF_r2_LMNB1_report.html
# FileProcessed HFF_r1_LMNB1_report.html
# FileReference wfr.txt
# FileProcessed Untitled.py.zip
# FileProcessed unicorns.svg
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed snow.jpg
# FileProcessed delete.py
# FileProcessed respo.json
# FileMicroscopy 170206-chr4SRa-allpairs_2.tar
# FileMicroscopy 170206-chr4SRa-allpairs_2.tar
# FileCalibration test_doc.doc
# FileCalibration out.csv
# FileCalibration None
# FileCalibration None
# FileCalibration None
# FileCalibration None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileCalibration SRR1658734_2.fastq.gz
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed None
# FileProcessed 4DNFIN232YYY.pairs.txt.gz.px2
# FileProcessed GM12878_SRR1658581_1pc_1_R1_fastqc.zip
# FileProcessed _5_HiCtool_normalized_fend_contact_matrix_chr22_0.05mb_0.0mb_51.0mb.txt
# FileProcessed _6_HiCtool_normalized_fend_contact_matrix_chr21_0.05mb_0.0mb_48.0mb.txt
# FileProcessed _5_HiCtool_normalized_enrich_contact_matrix_chr22_0.05mb_0.0mb_51.0mb.txt
# FileProcessed _6_HiCtool_normalized_enrich_contact_matrix_chr21_0.05mb_0.0mb_48.0mb.txt
# FileProcessed _5_HiCtool_observed_contact_matrix_chr22_0.05mb_0.0mb_51.0mb.txt
# FileProcessed _6_HiCtool_observed_contact_matrix_chr21_0.05mb_0.0mb_48.0mb.txt
# FileProcessed _13_HiC_project_object.hdf5
# FileProcessed _6_out_noDup.sort.bam
# FileProcessed _6_HiC_data_object.hdf5
# FileProcessed _5_HiCtool_expected_fend_contact_matrix_chr22_0.05mb_0.0mb_51.0mb.txt
# FileProcessed _6_HiCtool_expected_fend_contact_matrix_chr21_0.05mb_0.0mb_48.0mb.txt
# FileProcessed _6_fend_object.hdf5
# FileProcessed _13_HiC_distance_function.hdf5
# FileProcessed _5_HiCtool_expected_enrich_contact_matrix_chr22_0.05mb_0.0mb_51.0mb.txt
# FileProcessed _6_HiCtool_expected_enrich_contact_matrix_chr21_0.05mb_0.0mb_48.0mb.txt
# FileProcessed _6_out_pair2.bam
# FileProcessed _6_HiC_norm_binning.hdf5
# FileProcessed _6_out_pair1.bam
