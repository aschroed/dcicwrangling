# %%
from dcicutils import ff_utils
from functions.notebook_functions import *

# get key from file
my_key = get_key('koray_data')

# all usable env names
all_envs = ['data', 'staging', 'fourfront-webdev', 'fourfront-mastertest', 'fourfront-hotseat']
# get admin key from s3
#my_key = ff_utils.get_authentication_with_server({}, ff_env = 'data')

# %%
q = '/search/?file_type=No+value&status=released+to+project&type=FileProcessed&workflow_run_outputs.workflow.title%21=No+value'
q2 = '/search/?file_type=No+value&type=FileProcessed&workflow_run_outputs.workflow.title=No+value'
q3 = '/search/?file_type=No+value&type=FileReference'
gen = ff_utils.search_metadata(q3, key=my_key)
print(len(gen))
# Out:
# 12

# %%
Conv = {"bam": "alignments",
 "pairs": 'contact list',
 "pairs_px2": 'other',
 "normvector_juicerformat": "juicebox norm vector",
 "hic": "contact matrix",
 "mcool":"contact matrix",
 "merged_nodups": "other",
 "cool": "intermediate file",
 'bwaIndex': "genome index",
 'juicer_format_restriction_site_file': "restriction sites",
 'compressed_fasta': "other",
 'chromsizes': "other"
}
i=0
for a_file in gen:
    f_type = Conv[a_file['file_format']['display_title']]
    i += 1
    print(a_file['file_format']['display_title'], f_type)
    ff_utils.patch_metadata({'file_type':f_type}, obj_id=a_file['uuid'], key=my_key)
    print(i, sep= ' ')
# Out:
# juicer_format_restriction_site_file restriction sites
# 1
# juicer_format_restriction_site_file restriction sites
# 2
# juicer_format_restriction_site_file restriction sites
# 3
# chromsizes other
# 4
# juicer_format_restriction_site_file restriction sites
# 5
# juicer_format_restriction_site_file restriction sites
# 6
# chromsizes other
# 7
# juicer_format_restriction_site_file restriction sites
# 8
# juicer_format_restriction_site_file restriction sites
# 9
# compressed_fasta other
# 10
# bwaIndex genome index
# 11
# bwaIndex genome index
# 12

# %%
q4 = '/search/?file_type=contact+list-combined&status=released+to+project&type=FileProcessed&workflow_run_outputs.workflow.title=hi-c-processing-parta-juicer'
gen = ff_utils.search_metadata(q4, key=my_key)
print(len(gen))
# Out:
# 97

# %%
i=0
for a_file in gen:
    f_type = 'contact list-replicate'
    i += 1
    print(a_file['file_format']['display_title'], f_type)
    ff_utils.patch_metadata({'file_type':f_type}, obj_id=a_file['uuid'], key=my_key)
    print(i, sep= ' ')
# Out:
# pairs contact list-replicate
# 1
# pairs contact list-replicate
# 2
# pairs contact list-replicate
# 3
# pairs contact list-replicate
# 4
# pairs contact list-replicate
# 5
# pairs contact list-replicate
# 6
# pairs contact list-replicate
# 7
# pairs contact list-replicate
# 8
# pairs contact list-replicate
# 9
# pairs contact list-replicate
# 10
# pairs contact list-replicate
# 11
# pairs contact list-replicate
# 12
# pairs contact list-replicate
# 13
# pairs contact list-replicate
# 14
# pairs contact list-replicate
# 15
# pairs contact list-replicate
# 16
# pairs contact list-replicate
# 17
# pairs contact list-replicate
# 18
# pairs contact list-replicate
# 19
# pairs contact list-replicate
# 20
# pairs contact list-replicate
# 21
# pairs contact list-replicate
# 22
# pairs contact list-replicate
# 23
# pairs contact list-replicate
# 24
# pairs contact list-replicate
# 25
# pairs contact list-replicate
# 26
# pairs contact list-replicate
# 27
# pairs contact list-replicate
# 28
# ...
