# %%
from dcicutils import ff_utils
from functions.notebook_functions import *

# get key from file
my_key = get_key('koray_data')

# all usable env names
all_envs = ['data', 'staging', 'fourfront-webdev', 'fourfront-mastertest', 'fourfront-hotseat']
# get admin key from s3
#my_key = ff_utils.get_authentication_with_server({}, ff_env = 'data')

# %%
q = '/search/?file_format.display_title=other&type=File&status=deleted'
resp = ff_utils.search_metadata(q, key=my_key)
q_uuid = [i['uuid'] for i in resp]
print(len(q_uuid))
# Out:
# 0

# %%
for a_file in resp:
    print(a_file['@type'])
    if a_file['@type'][0] == 'FileProcessed':
        ff_utils.patch_metadata({"file_format": "txt"},
                                    obj_id= a_file['uuid'],
                                    key=my_key,
                                    add_on='delete_fields=filename')
    if a_file['@type'][0] == 'FileReference':
        print(a_file['display_title'])
        ff_utils.patch_metadata({"file_format": "fasta"},
                                    obj_id= a_file['uuid'],
                                    key=my_key,
                                    add_on='delete_fields=filename')
    if a_file['@type'][0] == 'FileCalibration':
        print(a_file['display_title'])
        ff_utils.patch_metadata({"file_format": "tiff"},
                                    obj_id= a_file['uuid'],
                                    key=my_key,
                                    add_on='delete_fields=filename')
    if a_file['@type'][0] == 'FileMicroscopy':
        ff_utils.patch_metadata({"file_format": "tiff"},
                                    obj_id= a_file['uuid'],
                                    key=my_key,
                                    add_on='delete_fields=filename')

# %%
for a_file in resp:
    if a_file.get('filename'):
        print(a_file.get('filename'), a_file.get('upload_key'))
        ext = a_file['filename'].split('.')[-1]
        ff_utils.patch_metadata({"file_format": ext},
                                obj_id= a_file['uuid'],
                                key=my_key)
        print('done')
        continue
        
    if a_file.get('workflow_run_outputs'):
        for o_file in a_file['workflow_run_outputs'][0]['output_files']:
            val = o_file.get('value')
            if val:
                if val['uuid'] == a_file['uuid']:
                    print(a_file.get('upload_key'),o_file['workflow_argument_name'], a_file['status'])
                    ff_utils.patch_metadata({"file_format": o_file['workflow_argument_name']},
                                obj_id= a_file['uuid'],
                                key=my_key)
                    print('done')
                    continue
# Out:
# pipeline.statistics.txt 8896846b-9c19-493a-ad78-b29162eea666/4DNFI5RCIF4F
# done
# H1_LMNB1_replicate.html fcfa884e-a5df-47b2-a708-6c34f03ceb8c/4DNFIIFBEEEU
# done
# H1_r3_LMNB1_report.html a01ec5fc-5016-43d1-a3fa-f435146aab02/4DNFIJZXXMHV
# done
# H1_r2_LMNB1_report.html 9cc0442d-9a51-4e7a-985a-aa345d0e0322/4DNFI2SZX561
# done
# H1_r1_LMNB1_report.html 0f3b47e4-2365-4b5b-94fe-35b0fcc0b3c4/4DNFIQZJ9IWX
# done
# HFF_LMNB1_replicate.html 97a96128-6266-4f46-87bf-4ff45be57b6b/4DNFIY5F9DWG
# done
# HFF_r2_LMNB1_report.html 8b421848-acde-4d8d-ab08-6f42e26446f0/4DNFISCUNQCP
# done
# HFF_r1_LMNB1_report.html 33ce3684-f4a2-46f8-b30d-f4e766a8b8ae/4DNFIL2T46JK
# done
# pipeline.statistics.txt e9fb4541-0a3c-40cd-9097-e2d0e310ec70/4DNFI3BAU2XE
# done
# HFF_LMNB1_replicate.html f0bd3010-e1fb-4039-a434-0c43c248fcaf/4DNFID89K985
# done
# HFF_r2_LMNB1_report.html 5c19bdfa-d5fd-4e03-ac48-9e196d72bb4b/4DNFID4DMS1T
# done
# HFF_r1_LMNB1_report.html a19e7c08-5bf2-4962-a09d-1a870f3bd5bf/4DNFI87UP7UN
# ...

# %%
pipeline.statistics.txt 8896846b-9c19-493a-ad78-b29162eea666/4DNFI5RCIF4F
done
H1_LMNB1_replicate.html fcfa884e-a5df-47b2-a708-6c34f03ceb8c/4DNFIIFBEEEU
done
H1_r3_LMNB1_report.html a01ec5fc-5016-43d1-a3fa-f435146aab02/4DNFIJZXXMHV
done
H1_r2_LMNB1_report.html 9cc0442d-9a51-4e7a-985a-aa345d0e0322/4DNFI2SZX561
done
H1_r1_LMNB1_report.html 0f3b47e4-2365-4b5b-94fe-35b0fcc0b3c4/4DNFIQZJ9IWX
done
HFF_LMNB1_replicate.html 97a96128-6266-4f46-87bf-4ff45be57b6b/4DNFIY5F9DWG
done
HFF_r2_LMNB1_report.html 8b421848-acde-4d8d-ab08-6f42e26446f0/4DNFISCUNQCP
done
HFF_r1_LMNB1_report.html 33ce3684-f4a2-46f8-b30d-f4e766a8b8ae/4DNFIL2T46JK
done
pipeline.statistics.txt e9fb4541-0a3c-40cd-9097-e2d0e310ec70/4DNFI3BAU2XE
done
HFF_LMNB1_replicate.html f0bd3010-e1fb-4039-a434-0c43c248fcaf/4DNFID89K985
done
HFF_r2_LMNB1_report.html 5c19bdfa-d5fd-4e03-ac48-9e196d72bb4b/4DNFID4DMS1T
done
HFF_r1_LMNB1_report.html a19e7c08-5bf2-4962-a09d-1a870f3bd5bf/4DNFI87UP7UN
done
233dfae6-46d5-425c-b56c-811aef15df67/4DNFIWKGJERO merged_nodups released to project
done
487f2ada-f92c-4a17-a841-7dd577143104/4DNFIFESYUR1 merged_nodups released to project
done
c288abe7-4211-4d3d-b2b6-64de3edc8c59/4DNFIQE2WLSB merged_nodups released to project
done
5a8fdaf9-b5c5-4e8b-b697-90667a2a5f7c/4DNFIILI6UNC merged_nodups released to project
done
62b80768-eeee-4a5a-aeda-baa574b3934f/4DNFIC71Q02Q merged_nodups released to project
done
b87bfb3a-05b3-432a-bfe2-faa01b7a31ce/4DNFI3BKDEZD merged_nodups released to project
done
344149c0-19f5-4870-a9fa-57381f15e599/4DNFIZASGQW3 merged_nodups released to project
done
32aafd1a-79f9-4b29-89af-9a35dec97246/4DNFICMNN63X merged_nodups released to project
done
bcf0ff5e-3d45-437a-be27-145881347ba6/4DNFI0ISP6QA merged_nodups released to project
done
881467fe-ec4f-4016-8df2-283f144f2b40/4DNFI6NSZ3UV merged_nodups released to project
done
580c96cb-53f6-4f87-97a6-43b9a9934fe4/4DNFIQ2SRY11 merged_nodups released to project
done
4cb04562-a6c8-4d02-88e9-f1acfe5927a1/4DNFIBSZMNM3 merged_nodups released to project
done
934197ec-8c15-4a0f-aa78-29cb29fdcec2/4DNFIV9ESXM8 merged_nodups released to project
done
1d3a2a65-32d2-41dd-a0a1-0930bfaaf694/4DNFIGHDUTUU merged_nodups released to project
done
142f7098-f432-48fe-810e-3fec89363e41/4DNFIK2IU4PC merged_nodups released to project
done
63d10bda-9533-497c-89a9-2f78ee83028c/4DNFIZU8FP50 merged_nodups released to project
done
370fc55b-9534-4c8f-b25c-a9f7b333a560/4DNFIBFRTLW0 merged_nodups released to project
done
5bdaa25d-cbea-41bc-a850-a36c022ddc46/4DNFI6KOULN3 merged_nodups released to project
done
7ff85324-82cb-4aee-949c-c433ae2e0f8e/4DNFI4D6CGBO merged_nodups released to project
done
1e3740c8-8433-45d4-b82f-03de6f3e5606/4DNFIJ9V67FR merged_nodups released to project
done
dad8ba1b-b62a-4f43-9d59-27c213a98407/4DNFIPLV6CWL merged_nodups released to project
done
8780d191-4d6b-457d-a32f-c67019495d2e/4DNFISSPQRFR merged_nodups released to project
done
d7071882-f323-4a4b-9819-a6cd7ff5a5f9/4DNFI2FD5YGB merged_nodups released to project
done
9225b3fe-a2c4-4df7-9020-4ace5213986b/4DNFIC2Q18O1 merged_nodups released to project
done
c0909059-0016-4dae-a54c-956daae4a46b/4DNFIJNQW2W3 merged_nodups released to project
done
704858fd-cf97-4253-a9d2-baafb4dc5945/4DNFIQ9QGM7Z merged_nodups released to project
done
bdfc643b-47b6-4310-871c-c14089b8ba9f/4DNFIUQ4DGWN merged_nodups released to project
done
55ebd0ef-652f-4750-bc84-c4614d4f64d4/4DNFILB7836C merged_nodups released to project
done
c2d0eea1-2281-4001-bfba-c227656188f9/4DNFIVY9U4I6 merged_nodups released to project
done
f0f12da5-42ea-4065-b483-3ba4bcb85487/4DNFIFL8W9R9 merged_nodups released to project
done
0d37afcc-9f86-4085-ac1f-63152068935a/4DNFIP406VVM merged_nodups released to project
done
155d2f7a-803d-48fb-8092-4d56175f9e86/4DNFIRN07A9M merged_nodups released to project
done
7022b519-cbcd-43bf-9683-fc578146ede3/4DNFI66DYVK3 merged_nodups released to project
done
1cc38a34-db99-4305-a50e-856e6a451e50/4DNFIA9TUVMR merged_nodups released to project
done
d827b307-6355-412b-9ede-1befa44099cf/4DNFIFD6GOJ1 merged_nodups released to project
done
2e746367-8560-44ed-ab7c-f9be807557c6/4DNFI1XIELDQ merged_nodups released to project
done
138bd7cc-0494-4930-bd8f-f3e46fa44b43/4DNFI47KLZVZ merged_nodups released to project
done
b260d2fc-15f6-4b3e-a42d-fc52d2683037/4DNFIMOWK9MT merged_nodups released to project
done
51b8b484-a3aa-4642-9d6c-684d77d83a56/4DNFIWIJ7EU5 merged_nodups released to project
done
c84763c0-c168-4a43-bf71-d27b81d673dc/4DNFIRR5LO8P merged_nodups released to project
done
1c3eaa8c-8a61-4342-8409-8a9bc95e82cd/4DNFI0FIK833 merged_nodups released to project
done
3a24f2be-7e6e-43a2-82ca-de67ed76dd96/4DNFI7GC0BN5 merged_nodups released to project
done
8f5fe216-e313-49ff-98c8-07a82793f514/4DNFIXVHRMBL merged_nodups released to project
done
75e34e3b-17b1-4bec-a4e8-a3278b8fb272/4DNFISIX6DLC merged_nodups released to project
done
dff964e8-883b-400a-b5f0-20507d0866f3/4DNFITUOEB81 merged_nodups released to project
done
3a20393c-0888-4904-86a8-a8ba5883c73a/4DNFI26O38QE merged_nodups released to project
done
1605b726-fd89-4923-adf1-5eeef289a71f/4DNFIV3QVZGY merged_nodups released to project
done
8b262e03-276d-4a4f-8792-46f088356fda/4DNFIQ9PV38M merged_nodups released to project
done
ae790a92-f3fe-4229-a995-55ce3d55351b/4DNFIVYK1UJ4 merged_nodups released to project
done
246e0f4a-d58b-4cd3-adab-620ebf8c1e3c/4DNFIUCEFWU8 merged_nodups released to project
done
9a6cb47f-9319-4a6e-af1d-f1a343efa116/4DNFI49UVHWY merged_nodups released to project
done
92cd924f-7cba-4b73-8600-e4fb89f6910b/4DNFI54BRKYD merged_nodups released to project
03-276d-4a4f-8792-46f088356fda', 'ae790a92-f3fe-4229-a995-55ce3d55351b', '246e0f4a-d58b-4cd3-adab-620ebf8c1e3c', '9a6cb47f-9319-4a6e-af1d-f1a343efa116', '92cd924f-7cba-4b73-8600-e4fb89f6910b', 'b72ea0f6-c5a8-4d76-8706-f6ff6df2b0d9', '8e0d438f-e15c-4aa2-ba76-c8bf2d91db6c', '67d9dd67-906c-492a-b279-5e65a36aa017', 'e1b157ad-15f5-42c3-b771-1d9f647ae05b', 'd0d4f68f-ba51-4b0c-856d-870883a0cc99', '758001a5-7944-4aa0-a94d-72b6a8314066', '99b9c872-363a-461c-a9ff-b51c33a45aff', '18a56406-0a4d-4c78-b119-a63abed29b00', 'a0ff61c1-444c-41cb-abfe-e0a462936d8d', '469843a1-3922-4fab-8242-141dd27b01fe', '206698fa-d127-4dba-a1ac-871bcdbe1a5c', 'c4bbd771-23c7-4489-b273-c344913c76f8', '2ede1b80-8785-43b6-aa49-30d04ce00816']

# %%
# Round III - move attachments
import boto3
s3 = boto3.resource('s3')

#source_addresses
source_health = ff_utils.get_metadata('/health', key = my_key)
source_pf = source_health['processed_file_bucket'] 
print(source_pf)
            
for a_uuid in other_format:
    file_resp = ff_utils.get_metadata(a_uuid, key=my_key)
    new_key = file_resp['upload_key'] + '.' + file_resp['file_format']['display_title']
    print(new_key)
    try:
        s3.Object(source_pf, new_key).load()
        print('file exists')
        continue
    except:
        print('file does not exist')
        
    copy_source = {'Bucket': source_pf, 'Key': file_resp['upload_key']}
    try:
        s3.meta.client.copy(copy_source, source_pf, new_key)
    except:
        print('Can not find file on source', file_key)
        continue
    print('file copied')
# Out:
# elasticbeanstalk-fourfront-webprod-wfoutput
# 8896846b-9c19-493a-ad78-b29162eea666/4DNFI5RCIF4F.txt
# file exists
# fcfa884e-a5df-47b2-a708-6c34f03ceb8c/4DNFIIFBEEEU.html
# file exists
# a01ec5fc-5016-43d1-a3fa-f435146aab02/4DNFIJZXXMHV.html
# file exists
# 9cc0442d-9a51-4e7a-985a-aa345d0e0322/4DNFI2SZX561.html
# file exists
# 0f3b47e4-2365-4b5b-94fe-35b0fcc0b3c4/4DNFIQZJ9IWX.html
# file exists
# 97a96128-6266-4f46-87bf-4ff45be57b6b/4DNFIY5F9DWG.html
# file exists
# 8b421848-acde-4d8d-ab08-6f42e26446f0/4DNFISCUNQCP.html
# file exists
# 33ce3684-f4a2-46f8-b30d-f4e766a8b8ae/4DNFIL2T46JK.html
# file exists
# e9fb4541-0a3c-40cd-9097-e2d0e310ec70/4DNFI3BAU2XE.txt
# file exists
# f0bd3010-e1fb-4039-a434-0c43c248fcaf/4DNFID89K985.html
# file exists
# 5c19bdfa-d5fd-4e03-ac48-9e196d72bb4b/4DNFID4DMS1T.html
# file exists
# a19e7c08-5bf2-4962-a09d-1a870f3bd5bf/4DNFI87UP7UN.html
# file exists
# 233dfae6-46d5-425c-b56c-811aef15df67/4DNFIWKGJERO.merged_nodups
# file exists
# ...

# %%
my_key = get_key('koray_data')
q = '/file-formats/other/@@links/?format=json'
resp = ff_utils.get_metadata(q, key=my_key)
for i in resp['uuids_linking_to']:
    ff_utils.patch_metadata({'description': ""}, i['uuid'], key = my_key)
