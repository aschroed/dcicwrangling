# %%
#get profiles
from dcicutils import ff_utils
from functions.wfr import *
from functions.wfr_settings import *
from functions.notebook_functions import *

# get key from keypairs.json
my_env = 'data'
my_key = get_key('koray_data')

my_dict = ff_utils.get_metadata('/profiles/', key = my_key)
print(my_dict.keys())

# %%
import glob
import os

files = glob.glob("/Users/koray/Downloads/August_2_2018/**/*")
print(files)
print(len(files))

# %%
aliases = []
for i in files:
    folder = i.split('/')[5]
    name = i.split('/')[6]
    formats= name.split('.')[-2]+"."+name.split('.')[-1]
    #print(i,folder, name,formats, sep=",")
    palias = name.replace("."+formats, "")
    alias = 'dekker-lab:' + palias.replace(".", "_")
    aliases.append(alias)
# 4DNES2M5JIGV
# 4DNES2M5JIGV
# 4DNES2M5JIGV
# 4DNES2R6PUEK
# 4DNES2R6PUEK
# 4DNES2R6PUEK
# 4DNES2M5JIGV
# 4DNES2R6PUEK
# 4DNES2M5JIGV
# 4DNES2R6PUEK
# 4DNES2R6PUEK
# 4DNES2M5JIGV
# 4DNES2M5JIGV
# 4DNES2R6PUEK
# 4DNES2M5JIGV
# 4DNES2M5JIGV
# 4DNES2R6PUEK
# 4DNES2R6PUEK
# 4DNES2R6PUEK
# 4DNES2M5JIGV
# 4DNES2R6PUEK
# 4DNES2R6PUEK
# 4DNES2M5JIGV
# 4DNES2M5JIGV

hff = [i for i in aliases if 'HFF' in i]
print(hff)
DNES2R6PUEK = [i for i in hff if '-p17-p22-' in i]
DNEX7POCO84 = [i for i in hff if '6-p22-' in i]
DNEXRAEERUF = [i for i in hff if '6-p17-F' in i]

esc = [i for i in aliases if 'ESC' in i]
print(esc)
DNES2M5JIGV = [i for i in esc if '-R1-R2' in i]
DNEXENKINA2 = [i for i in esc if '-R1_' in i]
DNEXZJZ5EBZ = [i for i in esc if '4-R2_' in i]

print(len(DNES2R6PUEK))
print(len(DNEX7POCO84))
print(len(DNEXRAEERUF))
print(len(DNES2M5JIGV))
print(len(DNEXENKINA2))
print(len(DNEXZJZ5EBZ))


print(DNES2R6PUEK)
print(DNEX7POCO84)
print(DNEXRAEERUF)
print(DNES2M5JIGV)
print(DNEXENKINA2)
print(DNEXZJZ5EBZ)

# %%
from functions.notebook_functions import *
jawg_data = {
'4DNES2R6PUEK':['dekker-lab:U54-HFFc6-p17-p22-FA-DpnII-20170327_hg38_diamond_ins', 'dekker-lab:U54-HFFc6-p17-p22-FA-DpnII-20170327_hg38_compartments_cis_vecs', 'dekker-lab:U54-HFFc6-p17-p22-FA-DpnII-20170327_hg38_inspot', 'dekker-lab:final_cloops_U54-HFFc6-p17-p22-FA-DpnII-20170327_hg38_5000-10000'],
'4DNEX7POCO84':['dekker-lab:U54-HFFc6-p22-FA-DpnII-20170327_hg38_diamond_ins', 'dekker-lab:U54-HFFc6-p22-FA-DpnII-20170327_hg38_compartments_cis_vecs', 'dekker-lab:U54-HFFc6-p22-FA-DpnII-20170327_hg38_inspot', 'dekker-lab:final_cloops_U54-HFFc6-p22-FA-DpnII-20170327_hg38_5000-10000'],
'4DNEXRAEERUF':['dekker-lab:U54-HFFc6-p17-FA-DpnII-20170327_hg38_diamond_ins', 'dekker-lab:U54-HFFc6-p17-FA-DpnII-20170327_hg38_compartments_cis_vecs', 'dekker-lab:U54-HFFc6-p17-FA-DpnII-20170327_hg38_inspot', 'dekker-lab:final_cloops_U54-HFFc6-p17-FA-DpnII-20170327_hg38_5000-10000'],
'4DNES2M5JIGV':['dekker-lab:U54-ESC4DN-FA-DpnII-2017524-R1-R2_diamond_ins', 'dekker-lab:U54-ESC4DN-FA-DpnII-2017524-R1-R2_compartments_cis_vecs', 'dekker-lab:U54-ESC4DN-FA-DpnII-2017524-R1-R2_inspot', 'dekker-lab:final_cloops_U54-ESC4DN-FA-DpnII-2017524-R1-R2_5000-10000'],
'4DNEXENKINA2':['dekker-lab:U54-ESC4DN-FA-DpnII-2017524-R1_diamond_ins', 'dekker-lab:U54-ESC4DN-FA-DpnII-2017524-R1_compartments_cis_vecs', 'dekker-lab:U54-ESC4DN-FA-DpnII-2017524-R1_inspot', 'dekker-lab:final_cloops_U54-ESC4DN-FA-DpnII-2017524-R1_5000-10000'],
'4DNEXZJZ5EBZ':['dekker-lab:U54-ESC4DN-FA-DpnII-2017524-R2_diamond_ins', 'dekker-lab:U54-ESC4DN-FA-DpnII-2017524-R2_compartments_cis_vecs', 'dekker-lab:U54-ESC4DN-FA-DpnII-2017524-R2_inspot', 'dekker-lab:final_cloops_U54-ESC4DN-FA-DpnII-2017524-R2_5000-10000']
}

my_key = get_key('koray_data')


def add_preliminary_processed_files(item_id, list_pc, auth):
    pc_set_title = "JAWG results - Dekker Lab"
    patch_data = ff_utils.get_metadata(item_id, key=auth, add_on = 'frame=raw').get('other_processed_files')
    if patch_data:
        # does the same title exist
        if pc_set_title in [i['title'] for i in patch_data]:
            print(item_id, 'already has preliminary results')
            return
        else:
            pass
    else:
        patch_data = []

    new_data = {'title': pc_set_title,
                'type': 'supplementary',
                'files': list_pc}
    patch_data.append(new_data)
    patch = {'other_processed_files': patch_data}
    print(patch)
    ff_utils.patch_metadata(patch, obj_id=item_id, key=auth)


for tid, listpc in jawg_data.items():
    add_preliminary_processed_files(tid, listpc, my_key)

# %%
{'other_processed_files': [{'files': ['6169212f-9a1c-4f17-aca6-3c8562d2919a', '42ac46e8-1fff-4342-a3e4-29e34799a754', 'ce74f51c-4174-4baa-963e-b1c515470c81', 'a7a847ed-9649-4cf5-b37d-b349743dea0d', '45865c4c-c854-4ed7-bcc1-aff2dd554ee5'], 'title': 'Results of 4DN DCIC HiC Pipeline, early version', 'type': 'archived', 'description': 'Moved from archived_processed_files '}, {'type': 'supplementary', 'title': 'JAWG results - Dekker Lab', 'files': ['dekker-lab:U54-ESC4DN-FA-DpnII-2017524-R1_diamond_ins', 'dekker-lab:U54-ESC4DN-FA-DpnII-2017524-R1_compartments_cis_vecs', 'dekker-lab:U54-ESC4DN-FA-DpnII-2017524-R1_inspot', 'dekker-lab:final_cloops_U54-ESC4DN-FA-DpnII-2017524-R1_5000-10000']}]}
{'other_processed_files': [{'type': 'archived', 'description': 'Moved from archived_processed_files ', 'title': 'Results of 4DN DCIC HiC Pipeline, early version', 'files': ['aff4c78b-b07a-4fb0-b568-388f0a8ff0e3', 'd0237baf-973a-45f4-acb3-33ee6cf7c7f6', '2d661756-da8c-44be-ab49-321ec5763ae0']}, {'type': 'supplementary', 'title': 'JAWG results - Dekker Lab', 'files': ['dekker-lab:U54-ESC4DN-FA-DpnII-2017524-R1-R2_diamond_ins', 'dekker-lab:U54-ESC4DN-FA-DpnII-2017524-R1-R2_compartments_cis_vecs', 'dekker-lab:U54-ESC4DN-FA-DpnII-2017524-R1-R2_inspot', 'dekker-lab:final_cloops_U54-ESC4DN-FA-DpnII-2017524-R1-R2_5000-10000']}]}
{'other_processed_files': [{'files': ['461b19b3-530b-4f21-8736-d5628453158f', '1c8b2f40-ecae-4343-b6e2-8b90a9b5fbba', '09c59c3f-1f2f-4dfc-b6e5-d6062a7f336f', '47856772-bbd8-4760-8607-8bcec67aede8', 'afcd281d-a420-4ec9-b6fa-a7a46e06e0c1'], 'title': 'Results of 4DN DCIC HiC Pipeline, early version', 'type': 'archived', 'description': 'Moved from archived_processed_files '}, {'type': 'supplementary', 'title': 'JAWG results - Dekker Lab', 'files': ['dekker-lab:U54-ESC4DN-FA-DpnII-2017524-R2_diamond_ins', 'dekker-lab:U54-ESC4DN-FA-DpnII-2017524-R2_compartments_cis_vecs', 'dekker-lab:U54-ESC4DN-FA-DpnII-2017524-R2_inspot', 'dekker-lab:final_cloops_U54-ESC4DN-FA-DpnII-2017524-R2_5000-10000']}]}
{'other_processed_files': [{'type': 'archived', 'description': 'Moved from archived_processed_files ', 'title': 'Results of 4DN DCIC HiC Pipeline, early version', 'files': ['fb53ad62-089e-422b-90a8-339c05ae39eb', 'd3adf4b3-f144-4222-99a0-57e0dd8e3691', 'e0a01f92-ba83-4395-8690-7b50f78f6238', '619c0657-cd7a-4dfb-a4ad-73e48308fb49', '53a87204-8a91-4a11-8448-89234ca010dd']}, {'type': 'supplementary', 'title': 'JAWG results - Dekker Lab', 'files': ['dekker-lab:U54-HFFc6-p22-FA-DpnII-20170327_hg38_diamond_ins', 'dekker-lab:U54-HFFc6-p22-FA-DpnII-20170327_hg38_compartments_cis_vecs', 'dekker-lab:U54-HFFc6-p22-FA-DpnII-20170327_hg38_inspot', 'dekker-lab:final_cloops_U54-HFFc6-p22-FA-DpnII-20170327_hg38_5000-10000']}]}
{'other_processed_files': [{'files': ['de8fe91e-1260-4d5c-a51f-c7b1546bed0f', '72139936-73af-4e08-98d1-32547207e8d2', 'f6d5ba22-aaf9-48e9-8df4-bc5c131c96af'], 'title': 'Results of 4DN DCIC HiC Pipeline, early version', 'type': 'archived', 'description': 'Moved from archived_processed_files '}, {'type': 'supplementary', 'title': 'JAWG results - Dekker Lab', 'files': ['dekker-lab:U54-HFFc6-p17-p22-FA-DpnII-20170327_hg38_diamond_ins', 'dekker-lab:U54-HFFc6-p17-p22-FA-DpnII-20170327_hg38_compartments_cis_vecs', 'dekker-lab:U54-HFFc6-p17-p22-FA-DpnII-20170327_hg38_inspot', 'dekker-lab:final_cloops_U54-HFFc6-p17-p22-FA-DpnII-20170327_hg38_5000-10000']}]}
{'other_processed_files': [{'type': 'archived', 'description': 'Moved from archived_processed_files ', 'title': 'Results of 4DN DCIC HiC Pipeline, early version', 'files': ['a3056e06-3a2c-465b-9d29-9871b4a8f50d', '340b4ae0-263b-4232-b830-d6c78dad73ab', '78d2fc27-73a2-488c-a1b8-74cabc3e9815', '4d4833a2-340e-4190-9527-ac0ae1ad47c0', '72287218-84de-466f-a5a7-2addc6e30ce0']}, {'type': 'supplementary', 'title': 'JAWG results - Dekker Lab', 'files': ['dekker-lab:U54-HFFc6-p17-FA-DpnII-20170327_hg38_diamond_ins', 'dekker-lab:U54-HFFc6-p17-FA-DpnII-20170327_hg38_compartments_cis_vecs', 'dekker-lab:U54-HFFc6-p17-FA-DpnII-20170327_hg38_inspot', 'dekker-lab:final_cloops_U54-HFFc6-p17-FA-DpnII-20170327_hg38_5000-10000']}]}
