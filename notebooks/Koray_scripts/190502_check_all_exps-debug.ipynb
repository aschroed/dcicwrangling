# %% [markdown]
# ### PLEASE COPY NOTEBOOKS TO YOUR FOLDERS TO PREVENT COMMIT CONFLICTS
# * If you would like to contribute to this notebook, make changes on it in useful_notebooks folder, run "Restart and Clear Output" before commit.
#
# #### Unexpected Expansion Cases
# ###### Experiment set fetches unrealated labs and awards
# Sometimes a fetch will get some unrelated labs and awards, this is because of the multiple awards a lab can have. This multiple awards are visited, which have users linked to them. This users also have labs, so here you go. Hopefully all are released/current already.
#
# ###### Experiment set fetches unrealted biosmaple/experiment/set
# This was so far because of the experiment and biosample relation field, or the references field that links to a publication. If you ignore these fields, if should be fine.
# `ignore_field = ['experiment_relation', 'biosample_relation', 'references']`

# %%
from dcicutils import ff_utils
from functions.notebook_functions import *
from functions.cleanup import *
import time


#my_auth = get_key('andyprod', keyfile='~/saved_keypairs.json')
my_auth = get_key('koray_data')

# Please Modify the following accordingly 
# do you want to check for duplicate/problematic runs on files?
# it will take some time

set_to_release = [ff_utils.get_metadata('4DNES3JX38V5', my_auth)]
print(len(set_to_release))
for a_set in set_to_release: 

        
    time1 = time.time()
    store, uuids = ff_utils.expand_es_metadata([a_set['uuid']], my_auth, store_frame='embedded',add_pc_wfr=True, ignore_field = ['experiment_relation', 'biosample_relation', 'references', 'reference_pubs'])
    time2 = time.time()
    diff = round((time2-time1), 1)
    print(a_set['accession'], len(uuids), 'items collected in', diff)
    analyze(store, True, False, a_set['status'])
# Out:
# 1
# 4DNES3JX38V5 1166 items collected in 7.7
# 4DNFI46FL10B user submitted or produced by sbg runs
# 4DNFI7URVWX5 user submitted or produced by sbg runs
# 4DNFIFL8W9R9 user submitted or produced by sbg runs
# 4DNFIH2E59ND user submitted or produced by sbg runs
# 4DNFIUQ4DGWN user submitted or produced by sbg runs
# 4DNFIC0CTNIK user submitted or produced by sbg runs
# 4DNFIC2Q18O1 user submitted or produced by sbg runs
# 4DNFIY5NQZKS user submitted or produced by sbg runs
# 4DNFIK7BFT18 user submitted or produced by sbg runs
# 4DNFIESXI3GC user submitted or produced by sbg runs
# 4DNFILVBKSMC user submitted or produced by sbg runs
# 4DNFIYC95I6C user submitted or produced by sbg runs
# 4DNFIANRU3X9 user submitted or produced by sbg runs
# 4DNFIP7SERXM user submitted or produced by sbg runs
# 4DNFIICAH4SE user submitted or produced by sbg runs
# 4DNFISNQRMUT user submitted or produced by sbg runs
# 4DNFIILT9UAC user submitted or produced by sbg runs
# 4DNFIEMSQZ4N user submitted or produced by sbg runs
# 4DNFID8P985Z user submitted or produced by sbg runs
# 4DNFIXVE2BEG user submitted or produced by sbg runs
# 4DNFIEN5Y1JE user submitted or produced by sbg runs
# 4DNFIBZ8LQ9K user submitted or produced by sbg runs
# 4DNFIPLV6CWL user submitted or produced by sbg runs
# 4DNFI2FD5YGB user submitted or produced by sbg runs
# 4DNFIW5805PZ user submitted or produced by sbg runs
# 4DNFISYRFN06 user submitted or produced by sbg runs
# 4DNFI022C7SS user submitted or produced by sbg runs
# 4DNFI906HTJW user submitted or produced by sbg runs
# 4DNFI3H1BL2S user submitted or produced by sbg runs
# 4DNFIAR5UVDV user submitted or produced by sbg runs
# 4DNFIMYJGXY6 user submitted or produced by sbg runs
# 4DNFIP406VVM user submitted or produced by sbg runs
# 4DNFIPDA3140 user submitted or produced by sbg runs
# 4DNFI4YHD4YL user submitted or produced by sbg runs
# 4DNFI1YZ2R2A user submitted or produced by sbg runs
# 4DNFIKEN54CP user submitted or produced by sbg runs
# 4DNFI67DGUUM user submitted or produced by sbg runs
# 4DNFIMPXLQQY user submitted or produced by sbg runs
# 4DNFIOFE1HZU user submitted or produced by sbg runs
# 4DNFIEG2P8MO user submitted or produced by sbg runs
# 4DNFIK7L5NLC user submitted or produced by sbg runs
# 4DNFIJ9V67FR user submitted or produced by sbg runs
# 4DNFI59I619R user submitted or produced by sbg runs
# 4DNFITII2FFF user submitted or produced by sbg runs
# 4DNFIG7VIUIX user submitted or produced by sbg runs
# 4DNFIAYN59WS user submitted or produced by sbg runs
# 4DNFIEL756JO user submitted or produced by sbg runs
# 4DNFIZRF1NW4 user submitted or produced by sbg runs
# 4DNFIBR9Q0JZ user submitted or produced by sbg runs
# 4DNFITHXW9MA user submitted or produced by sbg runs
# 4DNFIGY3F548 user submitted or produced by sbg runs
# 4DNFISKR3C53 user submitted or produced by sbg runs
# 4DNFIFTJPJMT user submitted or produced by sbg runs
# 4DNFIQ9QGM7Z user submitted or produced by sbg runs
# 4DNFIX8R93FZ user submitted or produced by sbg runs
# 4DNFIYJE6FWE user submitted or produced by sbg runs
# 4DNFIZNH1T7Y user submitted or produced by sbg runs
# 4DNFIL8TNRUA user submitted or produced by sbg runs
# 4DNFIVLLOBEZ user submitted or produced by sbg runs
# 4DNFIJNQW2W3 user submitted or produced by sbg runs
# 4DNFIGHH0577 user submitted or produced by sbg runs
# 4DNFIXS10GFJ user submitted or produced by sbg runs
# 4DNFILB7836C user submitted or produced by sbg runs
# 4DNFI1RF7MMX user submitted or produced by sbg runs
# 4DNFIZT3VUU5 user submitted or produced by sbg runs
# 4DNFI2FZZAVL user submitted or produced by sbg runs
# 4DNFIWTDGKAT user submitted or produced by sbg runs
# 4DNFIZUFUAEB user submitted or produced by sbg runs
# 4DNFIWVEWXHG user submitted or produced by sbg runs
# 4DNFIKYUSJ9S user submitted or produced by sbg runs
# 4DNFIJC5NVHM user submitted or produced by sbg runs
# 4DNFIPUGPFYJ user submitted or produced by sbg runs
# 4DNFIO2S2WVZ user submitted or produced by sbg runs
# 4DNFIZJKM1AZ user submitted or produced by sbg runs
# 4DNFI3ER81T0 user submitted or produced by sbg runs
# 4DNFIKIJXTR0 user submitted or produced by sbg runs
# 4DNFIW7MAVD4 user submitted or produced by sbg runs
# 4DNFI335F9OP user submitted or produced by sbg runs
# 4DNFIJRMV4OY user submitted or produced by sbg runs
# 4DNFIM74ZN3O user submitted or produced by sbg runs
# 4DNFIIAGZST8 user submitted or produced by sbg runs
# 4DNFID633W7V user submitted or produced by sbg runs
# 4DNFI3Q5U3TN user submitted or produced by sbg runs
# 4DNFIIHKZVO1 user submitted or produced by sbg runs
# 4DNFIVPAMUW4 user submitted or produced by sbg runs
# 4DNFI5MH9KTH user submitted or produced by sbg runs
# 4DNFI5GMT4U1 user submitted or produced by sbg runs
# 4DNFIVY9U4I6 user submitted or produced by sbg runs
# 4DNFIZHD4I6Q user submitted or produced by sbg runs
# 4DNFIYJTKNCR user submitted or produced by sbg runs
# 4DNFIWJXN4TL user submitted or produced by sbg runs
# 4DNFISSPQRFR user submitted or produced by sbg runs
# 4DNFI1DPCLVO user submitted or produced by sbg runs
# 4DNFIABMIHH0 user submitted or produced by sbg runs
# 4DNFI3AUFAZ4 user submitted or produced by sbg runs
# 4DNFIVWNYTL7 user submitted or produced by sbg runs
# 4DNFIU59TRDY user submitted or produced by sbg runs
# 4DNFIHKCL9SF user submitted or produced by sbg runs
# 4DNFIIMYDD1G user submitted or produced by sbg runs
# 4DNFI2S6KNZ1 user submitted or produced by sbg runs
# 4DNFIE3GWTFI user submitted or produced by sbg runs
# 4DNFIRACAE1W user submitted or produced by sbg runs
# file_processed            Out of 192, 0 skipped, 90 matching, 0 unusual, and 102 needs change
# file_reference            Out of 4, 0 skipped, 3 matching, 0 unusual, and 1 needs change
# higlass_view_config       Out of 3, 0 skipped, 2 matching, 0 unusual, and 1 needs change
# workflow_run_sbg          Out of 345, 0 skipped, 343 matching, 0 unusual, and 2 needs change
# workflow_run_awsem        Out of 89, 0 skipped, 88 matching, 0 unusual, and 1 needs change
# workflow                  Out of 11, 0 skipped, 10 matching, 0 unusual, and 1 needs change

# %%
def fetch_wfr_associated(wfr_uuid, my_key):
    """Given wfr_uuid, find associated output files and qcs"""
    wfr_as_list = []
    wfr_info = ff_utils.get_metadata(wfr_uuid, my_key)
    print(wfr_info['display_title'])
    wfr_as_list.append(wfr_info['uuid'])
    if wfr_info.get('output_files'):
        for o in wfr_info['output_files']:
                if o.get('value'):
                    wfr_as_list.append(o['value']['uuid'])
                if o.get('value_qc'):
                    wfr_as_list.append(o['value_qc']['uuid']) # this is a @id
    if wfr_info.get('output_quality_metrics'):
        for qc in wfr_info['output_quality_metrics']:
            if qc.get('value'):
                wfr_as_list.append(qc['value']['uuid'])
    return wfr_as_list

for wfr in store['workflow_run_sbg']:
    if wfr['display_title'].startswith('md5'):
        continue
    if wfr['display_title'].startswith('fastq'):
        continue
    lip = fetch_wfr_associated(wfr['uuid'], my_auth)
    print(lip)
    for uu in lip:
        ff_utils.patch_metadata({'status': 'deleted'}, uu, my_auth)
        pass
# Out:
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:54:04.930634
# ['c89e21a5-b8f2-4787-aa3f-63dbff534f6b', '6a175ab2-9dc9-4c47-bd0b-dbed9941edff', '06896813-f419-48b4-8daf-0f1e0c1a4f9c', '55ebd0ef-652f-4750-bc84-c4614d4f64d4']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:57:52.233537
# ['bb49b009-446c-4923-83e6-d8878e3c9d3a', '3d6e9ee6-3a30-40bc-85c1-e96a570786d6', '18b08368-dbb7-4911-bf3a-0502125d732b', '04582754-f547-4f28-92bb-d3cfa9daa602']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:59:05.194272
# ['1fa789ce-b991-4372-8821-ea746814dd5a', '2185c586-689b-420c-931c-09f0db123957', '5e907dd2-e515-4452-bd4c-db84c074fdfc', '02bd8fdb-71a5-42e6-9405-31bedeed06d7']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:54:16.962182
# ['1872ac28-cdca-478f-911a-04a127042373', '3f84f9e5-68a1-4e9f-8fc5-ab42db44806c', '8a10d504-bf5b-4024-b3b4-f1f22ad4164a', 'bdfc643b-47b6-4310-871c-c14089b8ba9f']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:54:40.876823
# ['ef02ff90-18b4-4b6c-a16d-495ba1d5fc70', 'e090e687-9b85-4092-8de6-a75d77edbfaa', 'd2379fae-7c9a-4040-8b66-d65edb2f9250', 'c0909059-0016-4dae-a54c-956daae4a46b']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:59:16.836208
# ['adf063b6-4469-4195-98e2-afb0d4d71958', 'ca9a8cea-f33b-486f-977f-aa54a61f3bef', 'f3d1dd2f-1396-4d94-9a77-c97c287bee03', 'a4ef4eac-3343-4ab3-bd2b-f2456a1953e8']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:56:41.375797
# ['aaca3268-bc51-4b05-8aba-463b2c501315', 'add49684-5514-4367-8306-7c77e68aa72a', 'dffbd51f-a750-4bc6-8f67-c84adf4328fa', 'f7144c14-f0bf-412c-ba7f-89deb8de5560']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:57:40.515496
# ['2e13bff1-1622-41b0-b666-d5e7600bb351', 'd90875d0-7260-47dd-9895-afb4bb161911', '4ece5da6-5d16-4801-9627-b8353287c545', '49a76a86-7856-4375-8ce8-29520e68169c']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:58:04.261169
# ['0cbc8204-cd7d-44b2-93f6-3588bd97aac1', 'b6e22896-9339-4e82-a6d9-a1da84917794', 'e2f652e5-7d61-46fc-a7d7-426e9a346f00', '6d3a1bbf-d07e-4eb3-84cf-a304afd61c6b']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:53:29.036792
# ['070a8241-f5de-4682-ae57-cb88413aaf5e', 'a724d25a-01a2-47f5-8dd5-25c661946dd3', '49fd304d-b34d-494c-aee9-8f269f4c2f1e', '0d37afcc-9f86-4085-ac1f-63152068935a']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:55:17.338699
# ['d37d6d3e-f883-404f-83c3-ebcde8a40f7c', '60e6f465-9a89-498b-acd9-50a26be34297', 'e937535d-2cf3-4359-b8d9-9dee1bd7a069', '8780d191-4d6b-457d-a32f-c67019495d2e']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:57:28.906237
# ['8f93f8e6-e93c-4721-bdb0-03afb1239dfe', 'c151ea1c-c175-4927-89c8-b1fda1f0d2c5', '1272f6b6-9859-4321-bf7e-03b97c060c34', '6f27685e-2001-486c-8f9d-733bbdc71c18']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:54:29.030887
# ['66e4a96e-867b-4d79-b169-ee026586d163', '06bd6439-230b-4838-aee4-b1d2206eef7c', 'f30366ee-5e19-468d-9736-7ced48432ab2', '704858fd-cf97-4253-a9d2-baafb4dc5945']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:57:04.775432
# ['45c721f1-38c1-49dc-85f7-ee3d14c68c8e', '43b9f807-0e18-4d60-bd12-fb16a4bc879f', '5f2d5e5c-2e64-4a9c-8b7c-8cde704dfbd5', '1e861106-a773-4b90-abb0-43b1eb931994']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:53:42.196367
# ['e4c5ef3e-866b-45e4-b0b2-b6d5b3ec0b12', '7efa6b5a-a2d0-4e3b-b465-f295b231b592', '5bab6fc4-ec35-498e-8cd1-670df6478e31', 'f0f12da5-42ea-4065-b483-3ba4bcb85487']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:55:53.595466
# ['d48b8f32-57b3-40a0-806d-41d78ea59471', 'ac1ede0b-93d9-4df1-9c6f-303ce405e907', '50eff572-726d-47db-959a-90d78653c8b3', '0030f332-32b2-4a7c-933c-5e3d46cf6570']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:58:28.816573
# ['9f7b61b4-5087-417e-8b7b-e38664d388a6', '492558e1-7090-44ee-ad62-c9e6d2f09362', '6014f367-f2d1-4243-8a72-2dfdcbd05da2', '08a5992e-31cb-4137-83e3-8de7eb0880e4']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:58:39.817600
# ['f2a00ee9-0bad-42ff-b939-90da02b24ae8', 'ee14fdb2-8dac-4363-bb4d-f79282038edc', 'dbf0b11b-c6a4-471d-8290-b1072c7fea42', 'fedd5940-c72d-44fd-ad48-2931ea67fa9d']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:57:16.656230
# ['ee7b3d01-1f8f-46bf-bd72-ed13015fabed', '3f510464-fb6e-4b31-9372-f4f56e11b049', '164eed09-e983-408c-ad0c-fb1116eb5adb', '6f152cb3-e562-4058-80f0-1ad8a2826150']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:58:51.914947
# ['77bade53-4910-455f-9cf9-c359cbdeaca8', '69205107-f6c9-4bc2-ac33-1701abd01a75', '5c26dfb8-6420-4848-9a2b-cbcce6c0e0ac', 'b6535998-5171-4191-b676-a4adaa343178']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:56:05.670846
# ['35a98065-cbaa-40c9-aa88-9d4fb9be7de1', '161cd680-cd80-4e2e-bad8-d7fa5d6e5823', 'f92f2e84-42bb-4be5-816e-90e905bb4431', '5655f6d4-0e7d-494c-b79b-929dcaded0d7']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:56:53.053940
# ['11a8ccc2-8ffe-4969-bdc0-549f716eff76', '94a436aa-b1ba-4095-a409-9a43554f881a', '91c040e0-845e-430f-bdeb-f927cdc4a9cb', 'ad9751f1-a916-4159-8823-58f6156e7c9f']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:59:40.801915
# ['fd59c542-7283-499b-8c2b-7921e523b1c3', '81b8c3a8-2eee-4628-b945-c47ef3388da0', '629b0aeb-7e35-4cd7-b287-c8480b76b028', '5e140984-4807-4a00-adf2-86a2f5548152']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:56:29.130538
# ['9b35a641-0ea0-4b07-9c12-a8c398450a96', '777df1dd-30b3-47f4-8621-871803541627', 'c17a3e15-671a-41f8-ad91-1c38160d7e8a', '1b2f09a7-06d3-447d-933f-c5c10abf81d3']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:53:53.175703
# ['8397a52f-a6ff-4c5c-b27f-5340b23519fa', 'a7bcf6d6-559a-4379-bdd3-6ec2669cb8a6', 'f88e91d9-adb6-41d8-bb3c-a6a2e53dbb7c', 'c2d0eea1-2281-4001-bfba-c227656188f9']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:56:17.120828
# ['6eb49756-646f-4c81-853a-d5b853058c53', '146403e4-1f0b-423a-91c8-f04adb099f41', '3e115e50-5b5e-4aa4-af1c-ca616db3c1fe', 'd83b1bd0-4880-4a26-baf3-6586acda69b0']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:58:16.053092
# ['efce15fd-3c5c-48a7-b087-1f6feb5fb1dd', '0d3761fc-96e6-45f9-ae51-00b736e894d2', '3b70ec97-c1ee-4fa3-860e-428bdd033e3e', '61abfa76-bd1e-4ef0-94e5-3f1f69c2bdb7']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:54:53.476398
# ['ccfe1071-741a-493b-a85d-8a406f006df0', 'ba0aba31-b257-4d0f-92c2-1d2858cfd89b', '4d3ab9c5-db58-4c66-801c-e1662cf55ef6', '9225b3fe-a2c4-4df7-9020-4ace5213986b']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:59:29.062137
# ['81a0c8bd-6785-4a0e-8859-631585c82155', '1cf9f374-3a6e-4c04-ab2a-187790cad97f', '6831663a-77ab-43b7-81d8-2e7fb3fb6af5', '2ffe073d-2bd1-42e9-aedd-7dd8d484a30b']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:55:05.338162
# ['63b5e9cd-9465-402f-8dfc-ef104316fd9f', 'ca39b8fc-9c40-43d8-a354-d1419de2b99a', 'fe00eec9-7f9c-4718-b3c6-52bdc8c760fe', 'd7071882-f323-4a4b-9819-a6cd7ff5a5f9']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:55:29.495735
# ['aeb9c169-5f5c-484b-8148-f0313952100f', 'aced06d4-3afc-4ce8-b3e0-48e05dd651a1', 'b3ad21fc-40c2-4296-94eb-21817cc4a5f2', 'dad8ba1b-b62a-4f43-9d59-27c213a98407']
# hi-c-processing-parta-juicer/25 run 2017-07-16 19:55:41.876806
# ['7375284a-aa35-4343-98ee-07b77e6ef8ff', '02c5a470-e2ee-4d20-b1ed-bf540cb7efff', 'fbd62409-91d1-4a43-bff1-a74600b5755f', '1e3740c8-8433-45d4-b82f-03de6f3e5606']
# hi-c-processing-partb/38 run 2017-08-05 14:53:23.072082
# ['7ba5384f-a506-4251-ab28-3de4e80cb3dc', '17c9787a-5ea4-47f8-8f0e-64390675d9d9', '53e7f293-5ccb-42b0-8697-d6ba7f84efe2', 'acdab973-8876-4a58-a701-97e7f30e3f0a', 'd3e1036b-b78b-461d-b3d4-e7e482932dd3']
# hi-c-processing-partc/8 run 2017-08-14 17:27:52.701358
# ['0fe19e8e-c565-4c0c-8058-effe5d81f53b', '70b9fe1e-e262-4bd1-b80d-4e78e804e1ee', 'e13c45a8-a33a-4f2e-9667-ffe7b64d8676']

# %%
# TODO
# Check audits
def analyze(store, check_wfrs, delete_problematic, change_status):
    # create stash of wfrs to pass to delete_wfrs
    stash = store.get('workflow_run_sbg', []) + store.get('workflow_run_awsem', [])

    # to decide which items to ignore as they have a 'higher' status
    STATUS_LEVEL = {
        # standard_status
        "released": 10, "current": 10,
        "released to project": 9,
        "pre-release": 8,
        "planned": 6, "submission in progress": 6,
        "in review by lab": 4,
        "revoked": 0, "archived": 0,"deleted": 0, "obsolete": 0, "replaced": 0, "archived to project": 0,
        # additional file statuses
        'to be uploaded by workflow': 4, 'uploading': 4, 'uploaded': 4, 'upload failed': 4, 'draft': 4, 'released to lab': 4}

    for a_set in store['experiment_set_replicate']:
        if not a_set.get('completed_processes'):
            print(a_set['accession'], 'missing processing tag', a_set['description'][:50])

    # check for experiment numbers
    exp_names = [i for i in store if i.startswith('experiment') and i not in ['experiment_set', 'experiment_set_replicate', 'experiment_type']]
    all_exps_on_sets = [a for i in store['experiment_set_replicate'] for a in i['experiments_in_set']]
    all_exps = [a['uuid'] for i in store.keys() for a in store[i] if i in exp_names]
    if len(all_exps_on_sets) != len(all_exps):
        print([i['uuid'] for i in all_exps_on_sets])
        print(all_exps)
        print('Number of experiments is not same as experiments associated with sets')
        print('# of exps: {}. # of exps on sets: {}'.format(len(all_exps), len(all_exps_on_sets)))

    for a_file in store['file_fastq']:
        if not a_file.get('quality_metric'):
            print(a_file['accession'], 'missing fastqc')
        if not a_file.get('content_md5sum'):
            print(a_file['accession'], 'missing content md5 sum')
        if not a_file.get('md5sum'):
            print(a_file['accession'], 'md5 was not calculated during upload, missing md5sum')
        if check_wfrs:
            dw = delete_wfrs(a_file, my_auth, delete=delete_problematic, stash=stash)

    if store.get('file_processed'):
        for a_file in store['file_processed']:
            if a_file['file_format']['file_format'] == '/file-formats/pairs/':
                if not a_file.get('quality_metric'):
                    print(a_file['accession'], 'missing Pairsqc')
            if not a_file.get('source_experiments'):
                print(a_file['accession'], 'user submitted or produced by sbg runs')
            if check_wfrs:
                dw = delete_wfrs(a_file, my_auth, delete=delete_problematic, stash=stash)   


    if store.get('workflow_run_awsem'):
        for wfr in store['workflow_run_awsem']:
            if wfr['run_status'] != 'complete':
                print('problematic wfr', wfr['uuid'], wfr['run_status'])


    change_level = STATUS_LEVEL.get(change_status, 1)
    
    print_each = False
    counter = 0
    for a_type in store:
        total = len(store[a_type])
        change = 0
        matching = 0
        unusual = 0
        skipping = 0
        for raw_data in store[a_type]:
            if STATUS_LEVEL.get(raw_data['status']) > change_level:
                skipping += 1
                msg = ('{} {} ITEM HAS STATUS {} HIGHER THAN {} - SKIPPING'.format(a_type, raw_data['uuid'], raw_data['status'], change_status))
            elif STATUS_LEVEL.get(raw_data['status']) == STATUS_LEVEL.get(change_status):
                matching += 1
                msg = ('MATCHING ACCESS STATUS', a_type, raw_data['uuid'], raw_data['status'])
            elif STATUS_LEVEL.get(raw_data['status']) == 0:
                unusual += 1
                msg = ('SKIP UNUSUAL STATUS  ', a_type, raw_data['uuid'], raw_data['status'])
            else:
                change += 1
                msg = ('       CHANGE        ', a_type, raw_data['uuid'], raw_data['status'])
            if print_each:
                print(msg)
        if change>0:
            print('{:<25} Out of {t}, {r} skipped, {m} matching, {u} unusual, and {c} needs change'.format(a_type, t=total, r=skipping, m=matching, u=unusual, c=change))

# %%
# # clear opf
# for exp in  store.get('experiment_tsaseq'):
#     ff_utils.patch_metadata({}, exp['uuid'], my_auth, add_on='delete_fields=other_processed_files')
#     pass
# # clear tag
# for aset in store.get('experiment_set_replicate'):
#     ff_utils.patch_metadata({}, aset['uuid'], my_auth, add_on='delete_fields=completed_processes')
#     pass

# def fetch_wfr_associated(wfr_uuid, my_key):
#     """Given wfr_uuid, find associated output files and qcs"""
#     wfr_as_list = []
#     wfr_info = ff_utils.get_metadata(wfr_uuid, my_key)
#     print(wfr_info['display_title'])
#     wfr_as_list.append(wfr_info['uuid'])
#     if wfr_info.get('output_files'):
#         for o in wfr_info['output_files']:
#                 if o.get('value'):
#                     wfr_as_list.append(o['value']['uuid'])
#                 if o.get('value_qc'):
#                     wfr_as_list.append(o['value_qc']['uuid']) # this is a @id
#     if wfr_info.get('output_quality_metrics'):
#         for qc in wfr_info['output_quality_metrics']:
#             if qc.get('value'):
#                 wfr_as_list.append(qc['value']['uuid'])
#     return wfr_as_list

# for wfr in store['workflow_run_awsem']:
#     if wfr['display_title'].startswith('repliseq'):
#         lip = fetch_wfr_associated(wfr['uuid'], my_auth)
#         print(lip)
#         for uu in lip:
#             ff_utils.patch_metadata({'status': 'deleted'}, uu, my_auth)
#             pass
# Out:
# repliseq-parta v16 run 2019-03-12 19:49:16.023049
# ['e10765e2-ebaf-40c8-ac7d-a9ce006fff0b', '31a25232-884f-48fc-979b-463eb6e8a2dd', 'd2745e28-8536-450b-9fbb-e9d0ff92fbed', '47e18ae7-a426-4f00-9e6d-b69234850aa4']
# repliseq-parta v16 run 2019-03-12 19:49:22.994268
# ['b99b7355-58ab-4c3f-8f99-e4058acee00e', '12593b06-d2c0-40ac-989a-64ff934f9f71', '4670ad68-25e1-4401-9744-733d9fd8d991', '2f89c0f7-f8ae-4f97-bd46-65ffc03f2a3a']
# repliseq-parta v16 run 2019-03-12 19:49:08.219556
# ['28d0534f-a6c8-45c7-9a97-a72e377147ff', 'e0d4f71b-249b-4065-b004-879e630fc91c', '8c97269b-9169-4cee-b073-ec1e6c3600db', 'dbfd8f87-7463-4fe1-9c56-5d5612780073']
# repliseq-parta v16 run 2019-03-12 19:49:00.822963
# ['1be98d12-146b-4f25-8e31-3b0d9a500892', '9ff5d984-62f7-4412-961c-2e71808b427d', '0e616848-97ef-4914-a055-9be922c6bcdf', '9a420689-4866-4d8f-b803-128f3206d357']

# %%
# Check status

# Which status to change
change_status = 'released'


change_level = STATUS_LEVEL.get(change_status, 1)
    
    
print_each = False
counter = 0
for a_type in store:
    total = len(store[a_type])
    change = 0
    matching = 0
    unusual = 0
    skipping = 0
    for raw_data in store[a_type]:
        if STATUS_LEVEL.get(raw_data['status']) > change_level:
            skipping += 1
            msg = ('{} {} ITEM HAS STATUS {} HIGHER THAN {} - SKIPPING'.format(a_type, raw_data['uuid'], raw_data['status'], change_status))
        elif STATUS_LEVEL.get(raw_data['status']) == STATUS_LEVEL.get(change_status):
            matching += 1
            msg = ('MATCHING ACCESS STATUS', a_type, raw_data['uuid'], raw_data['status'])
        elif STATUS_LEVEL.get(raw_data['status']) == 0:
            unusual += 1
            msg = ('SKIP UNUSUAL STATUS  ', a_type, raw_data['uuid'], raw_data['status'])
        else:
            change += 1
            msg = ('       CHANGE        ', a_type, raw_data['uuid'], raw_data['status'])
        if print_each:
            print(msg)
    print('{:<25} Out of {t}, {r} skipped, {m} matching, {u} unusual, and {c} needs change'.format(a_type, t=total, r=skipping, m=matching, u=unusual, c=change))
# Out:
# protocol                  Out of 2, 0 skipped, 2 matching, 0 unusual, and 0 needs change
# file_fastq                Out of 16, 0 skipped, 16 matching, 0 unusual, and 0 needs change
# workflow_run_awsem        Out of 43, 0 skipped, 20 matching, 0 unusual, and 23 needs change
# biosample                 Out of 2, 0 skipped, 2 matching, 0 unusual, and 0 needs change
# biosample_cell_culture    Out of 2, 0 skipped, 2 matching, 0 unusual, and 0 needs change
# lab                       Out of 10, 0 skipped, 10 matching, 0 unusual, and 0 needs change
# target                    Out of 3, 0 skipped, 3 matching, 0 unusual, and 0 needs change
# experiment_type           Out of 1, 0 skipped, 1 matching, 0 unusual, and 0 needs change
# image                     Out of 1, 0 skipped, 1 matching, 0 unusual, and 0 needs change
# ontology                  Out of 2, 0 skipped, 2 matching, 0 unusual, and 0 needs change
# file_format               Out of 9, 0 skipped, 9 matching, 0 unusual, and 0 needs change
# antibody                  Out of 3, 0 skipped, 3 matching, 0 unusual, and 0 needs change
# quality_metric_fastqc     Out of 16, 0 skipped, 16 matching, 0 unusual, and 0 needs change
# ontology_term             Out of 10, 0 skipped, 10 matching, 0 unusual, and 0 needs change
# workflow                  Out of 5, 0 skipped, 5 matching, 0 unusual, and 0 needs change
# higlass_view_config       Out of 11, 0 skipped, 0 matching, 0 unusual, and 11 needs change
# vendor                    Out of 4, 0 skipped, 4 matching, 0 unusual, and 0 needs change
# individual_human          Out of 1, 0 skipped, 1 matching, 0 unusual, and 0 needs change
# award                     Out of 10, 0 skipped, 10 matching, 0 unusual, and 0 needs change
# static_section            Out of 1, 0 skipped, 1 matching, 0 unusual, and 0 needs change
# biosource                 Out of 1, 0 skipped, 1 matching, 0 unusual, and 0 needs change
# experiment_set_replicate  Out of 4, 0 skipped, 4 matching, 0 unusual, and 0 needs change
# quality_metric_chipseq    Out of 11, 0 skipped, 0 matching, 0 unusual, and 11 needs change
# user                      Out of 19, 0 skipped, 19 matching, 0 unusual, and 0 needs change
# file_processed            Out of 23, 0 skipped, 0 matching, 0 unusual, and 23 needs change
# organism                  Out of 1, 0 skipped, 1 matching, 0 unusual, and 0 needs change
# experiment_seq            Out of 8, 0 skipped, 8 matching, 0 unusual, and 0 needs change
# software                  Out of 11, 0 skipped, 11 matching, 0 unusual, and 0 needs change
# badge                     Out of 1, 0 skipped, 1 matching, 0 unusual, and 0 needs change
# file_reference            Out of 3, 0 skipped, 3 matching, 0 unusual, and 0 needs change

# %%
listem = ['experiment_hi_c',         
'experiment_set_replicate',
'experiment_chiapet',
'experiment_seq']

my_store = {i:store[i] for i in store if i in listem}
print(len(my_store))
print(my_store.keys())
# Out:
# 4
# dict_keys(['experiment_hi_c', 'experiment_set_replicate', 'experiment_chiapet', 'experiment_seq'])

# %%
# If you want to patch the status, change action to True
action = True

# Which status to change
change_status = 'released'


reviewed = ""
reviewed = input('Did another wrangler review this release? (y/n):')
if reviewed != 'y':
    raise KeyError('A key step is missing!')
    
print_each = False
counter = 0
for a_type in store:
    total = len(store[a_type])
    change = 0
    matching = 0
    unusual = 0
    skipping = 0
    for raw_data in store[a_type]:
        if STATUS_LEVEL.get(raw_data['status']) > change_level:
            skipping += 1
            msg = ('{} {} ITEM HAS STATUS {} HIGHER THAN {} - SKIPPING'.format(a_type, raw_data['uuid'], raw_data['status'], change_status))
        elif STATUS_LEVEL.get(raw_data['status']) == STATUS_LEVEL.get(change_status):
            matching += 1
            msg = ('MATCHING ACCESS STATUS', a_type, raw_data['uuid'], raw_data['status'])
        elif STATUS_LEVEL.get(raw_data['status']) == 0:
            unusual += 1
            msg = ('SKIP UNUSUAL STATUS  ', a_type, raw_data['uuid'], raw_data['status'])
        else:
            change += 1
            msg = ('       CHANGE        ', a_type, raw_data['uuid'], raw_data['status'])
            if action:
                patch_data = {'status': change_status}
                if change_status == 'released' and a_type in ['publication']:
                    patch_data = {'status': 'current'}
                   
                ff_utils.patch_metadata(patch_data, obj_id=raw_data['uuid'] ,key=my_auth) 

        if print_each:
            print(msg)
    print('{:<25} Out of {t}, {r} skipped, {m} matching, {u} unusual, and {c} UPDATED with status'.format(a_type, t=total, r=skipping, m=matching, u=unusual, c=change))
# Out:
# Did another wrangler review this release? (y/n):y
# protocol                  Out of 2, 0 skipped, 2 matching, 0 unusual, and 0 UPDATED with status
# file_fastq                Out of 16, 0 skipped, 16 matching, 0 unusual, and 0 UPDATED with status
# workflow_run_awsem        Out of 43, 0 skipped, 20 matching, 0 unusual, and 23 UPDATED with status
# biosample                 Out of 2, 0 skipped, 2 matching, 0 unusual, and 0 UPDATED with status
# biosample_cell_culture    Out of 2, 0 skipped, 2 matching, 0 unusual, and 0 UPDATED with status
# lab                       Out of 10, 0 skipped, 10 matching, 0 unusual, and 0 UPDATED with status
# target                    Out of 3, 0 skipped, 3 matching, 0 unusual, and 0 UPDATED with status
# experiment_type           Out of 1, 0 skipped, 1 matching, 0 unusual, and 0 UPDATED with status
# image                     Out of 1, 0 skipped, 1 matching, 0 unusual, and 0 UPDATED with status
# ontology                  Out of 2, 0 skipped, 2 matching, 0 unusual, and 0 UPDATED with status
# file_format               Out of 9, 0 skipped, 9 matching, 0 unusual, and 0 UPDATED with status
# antibody                  Out of 3, 0 skipped, 3 matching, 0 unusual, and 0 UPDATED with status
# quality_metric_fastqc     Out of 16, 0 skipped, 16 matching, 0 unusual, and 0 UPDATED with status
# ontology_term             Out of 10, 0 skipped, 10 matching, 0 unusual, and 0 UPDATED with status
# workflow                  Out of 5, 0 skipped, 5 matching, 0 unusual, and 0 UPDATED with status
# higlass_view_config       Out of 11, 0 skipped, 0 matching, 0 unusual, and 11 UPDATED with status
# vendor                    Out of 4, 0 skipped, 4 matching, 0 unusual, and 0 UPDATED with status
# individual_human          Out of 1, 0 skipped, 1 matching, 0 unusual, and 0 UPDATED with status
# award                     Out of 10, 0 skipped, 10 matching, 0 unusual, and 0 UPDATED with status
# static_section            Out of 1, 0 skipped, 1 matching, 0 unusual, and 0 UPDATED with status
# biosource                 Out of 1, 0 skipped, 1 matching, 0 unusual, and 0 UPDATED with status
# experiment_set_replicate  Out of 4, 0 skipped, 4 matching, 0 unusual, and 0 UPDATED with status
# quality_metric_chipseq    Out of 11, 0 skipped, 0 matching, 0 unusual, and 11 UPDATED with status
# user                      Out of 19, 0 skipped, 19 matching, 0 unusual, and 0 UPDATED with status
# file_processed            Out of 23, 0 skipped, 0 matching, 0 unusual, and 23 UPDATED with status
# organism                  Out of 1, 0 skipped, 1 matching, 0 unusual, and 0 UPDATED with status
# experiment_seq            Out of 8, 0 skipped, 8 matching, 0 unusual, and 0 UPDATED with status
# software                  Out of 11, 0 skipped, 11 matching, 0 unusual, and 0 UPDATED with status
# badge                     Out of 1, 0 skipped, 1 matching, 0 unusual, and 0 UPDATED with status
# file_reference            Out of 3, 0 skipped, 3 matching, 0 unusual, and 0 UPDATED with status
