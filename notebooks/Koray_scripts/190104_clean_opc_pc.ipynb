# %%
from dcicutils import ff_utils
from functions.notebook_functions import *

# get key from file
my_key = get_key('koray_data')
my_env = 'data'
# all usable env names
all_envs = ['data', 'staging', 'fourfront-webdev', 'fourfront-mastertest', 'fourfront-hotseat']
# get admin key from s3
#my_key = ff_utils.get_authentication_with_server({}, ff_env = 'data')

# %%
set_url = '/search/?award.project=External&experiments_in_set.experiment_type=in+situ+Hi-C&experimentset_type=replicate&type=ExperimentSetReplicate&completed_processes=HiC_Pipeline_0.2.5'
all_sets = ff_utils.search_metadata(set_url , key=my_key)
print(len(all_sets))
# Out:
# 31

# %%
def cleaner(resp):
    pc = False
    opc = False
    if resp.get('processed_files'):
        pc = True
    if resp.get('other_processed_files'):
        opc = True
    if pc or opc:
        print('cleaning')
        pass
        ff_utils.patch_metadata({}, obj_id=resp['uuid'], key=my_key, add_on = 'delete_fields=processed_files,other_processed_files')

for i in all_sets: 
    cleaner(i)
    exps = i['experiments_in_set']
    for exp in exps:
        e_resp = ff_utils.get_metadata(exp['uuid'], key=my_key)                      
        cleaner(e_resp)
        files = e_resp.get('files')
        if not files:
            print('no file in exp', e_resp['accession'])
            continue
        for f in files:
            f_resp = ff_utils.get_metadata(f['uuid'], key=my_key)
            runs = f_resp['workflow_run_inputs']
            rep_runs = [r for r in runs if r['display_title'].startswith('repli')]
            print(len(rep_runs), 'many runs')
            
            for rep in rep_runs:
                patch_data = {'description': "This workflow run is deleted", 'status': "deleted"}
                ff_utils.patch_metadata(patch_data, obj_id=rep['uuid'] ,key=my_key)
                # delete output files of the deleted workflow run
                for o in rep['output_files']:
                    if o.get('value'):
                        ud = o['value']['uuid']
                        ff_utils.patch_metadata({'status': "deleted"}, obj_id=ud ,key=my_key)
# Out:
# md5 run 2018-08-09 01:01:11.194747
# Repli-seq
# md5 run 2018-08-08 01:17:07.242591
# Repli-seq
# md5 run 2018-08-08 18:26:18.476776
# Repli-seq
# md5 run 2018-11-30 18:53:31.412942
# None
# md5 run 2018-08-08 19:04:54.456228
# Repli-seq
# md5 run 2018-08-09 21:35:45.245213
# Repli-seq
# md5 run 2018-08-07 22:30:43.123646
# Repli-seq
# md5 run 2018-08-07 23:03:54.709695
# Repli-seq
# md5 run 2018-08-09 19:15:14.072664
# Repli-seq
# md5 run 2018-08-09 18:37:21.915306
# Repli-seq
# md5 run 2018-08-08 00:16:53.893157
# Repli-seq
# md5 run 2018-08-08 15:50:00.724097
# Repli-seq
# md5  run 2018-11-30 21:09:35.594781
# None
# md5 run 2018-08-08 17:12:18.412818
# Repli-seq
# md5 run 2018-08-09 20:18:31.058751
# Repli-seq
# md5 run 2018-08-08 13:59:48.269652
# Repli-seq
# md5 run 2018-08-08 18:37:08.865392
# Repli-seq
# md5 run 2018-08-08 01:22:33.306766
# Repli-seq
# md5 run 2018-08-07 22:58:43.476792
# Repli-seq
# md5 run 2018-08-07 23:32:04.891459
# Repli-seq
# md5 run 2018-08-07 23:20:23.335772
# Repli-seq
# md5 run 2018-08-08 00:58:49.023800
# Repli-seq
# md5 run 2018-08-08 01:25:20.040347
# Repli-seq
# md5 run 2018-08-08 17:09:36.002687
# Repli-seq
# md5 run 2018-08-08 18:36:35.146941
# Repli-seq
# md5 run 2018-08-08 23:29:48.609419
# Repli-seq
# md5 run 2018-08-07 23:27:19.553620
# Repli-seq
# md5 run 2018-08-07 22:52:46.830901
# Repli-seq
# md5 run 2018-08-07 23:55:30.847808
# Repli-seq
# md5 run 2018-08-08 01:43:01.127300
# Repli-seq
# md5 run 2018-08-07 21:53:53.761377
# Repli-seq
# md5 run 2018-11-30 18:49:13.556744
# None
# md5 run 2018-08-08 17:45:56.896399
# Repli-seq
# md5 run 2018-08-09 08:50:48.805423
# Repli-seq
# md5 run 2018-08-08 00:53:14.240778
# Repli-seq
# md5 run 2018-08-08 18:09:46.909349
# Repli-seq
# md5 run 2018-08-07 22:58:02.302037
# Repli-seq
# md5 run 2018-08-08 00:44:35.795223
# Repli-seq
# md5 run 2018-08-07 22:25:48.184089
# Repli-seq
# md5 run 2018-08-09 00:33:40.168216
# Repli-seq
