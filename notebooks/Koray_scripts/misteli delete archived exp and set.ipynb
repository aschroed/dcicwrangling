# %%
from dcicutils import ff_utils
from functions.notebook_functions import *

# get key from file
my_key = get_key('koray_data')
# all usable env names
all_envs = ['data', 'staging', 'fourfront-webdev', 'fourfront-mastertest', 'fourfront-hotseat']
# get admin key from s3
#my_key = ff_utils.get_authentication_with_server({}, ff_env = 'data')

# %%
q = '/search/?lab.display_title=Tom+Misteli%2C+NCI&status=archived&type=ExperimentSetReplicate'
gen = ff_utils.search_metadata(q, key=my_key)
print(len(gen))
# Out:
# 26

# %%
for i in gen:
    acc = i['accession']
    exps = [a['accession'] for a in i['experiments_in_set']]
    print(exps)
    exps.append(acc)
    print(exps)
    for ac in exps:
        ff_utils.patch_metadata({'status':'deleted'}, obj_id=ac, key=my_key)
# Out:
# ['4DNEXHLB1TI7', '4DNEX3JJE5KO', '4DNEXQV7OS25']
# ['4DNEXHLB1TI7', '4DNEX3JJE5KO', '4DNEXQV7OS25', '4DNESSZKT7ZP']
# ['4DNEXCE6V9FJ', '4DNEXE2ZJ6TX', '4DNEXW41P1ZW']
# ['4DNEXCE6V9FJ', '4DNEXE2ZJ6TX', '4DNEXW41P1ZW', '4DNESX3UC958']
# ['4DNEXPN64DPD', '4DNEXA6VTFSW', '4DNEXE38RW3T']
# ['4DNEXPN64DPD', '4DNEXA6VTFSW', '4DNEXE38RW3T', '4DNESDQ36T34']
# ['4DNEXIF9IVCQ', '4DNEXRR7B1UW', '4DNEXDLH2GMB']
# ['4DNEXIF9IVCQ', '4DNEXRR7B1UW', '4DNEXDLH2GMB', '4DNESSUNIFRR']
# ['4DNEX84PTOV4', '4DNEXTPGP73R', '4DNEXAZXELHI']
# ['4DNEX84PTOV4', '4DNEXTPGP73R', '4DNEXAZXELHI', '4DNES7N97DU3']
# ['4DNEXYECZIT6', '4DNEX922LQMW', '4DNEX8WZ38T4']
# ['4DNEXYECZIT6', '4DNEX922LQMW', '4DNEX8WZ38T4', '4DNESSZP2LHD']
# ['4DNEX75MKDES', '4DNEX8TS4TMH', '4DNEXFMNLCX1']
# ['4DNEX75MKDES', '4DNEX8TS4TMH', '4DNEXFMNLCX1', '4DNESVNKUIUC']
# ['4DNEXPUYE5SQ', '4DNEXJI84TR8', '4DNEX892B7MC']
# ['4DNEXPUYE5SQ', '4DNEXJI84TR8', '4DNEX892B7MC', '4DNESF2Z37RM']
# ['4DNEXRRS2DGK', '4DNEXVW1JSAZ', '4DNEX2DDION3']
# ...

# %%
l = 0


def find_loc(chr, no, probes):
    for ix in probes:
        if ix[1] == chr:
            if ix[4] == no:
                return [ix[0], ix[1], ix[2], ix[3]]
                
for index, row in mic_data.iterrows():
    
    p_chr = i[2]
    bait = i[0]
    target = i[1]
    b_l = find_loc(p_chr, bait, probes)
    t_l = find_loc(p_chr, target, probes)
    
    print_l = b_l + t_l
    print(';'.join(print_l))
# Out:
# misteli:probe_11;1;2370445;2570720;misteli:probe_74;1;18566409;18766880
# misteli:probe_11;1;2370445;2570720;misteli:probe_91;1;22223362;22394657
# misteli:probe_11;1;2370445;2570720;misteli:probe_441;1;109469002;109662490
# misteli:probe_11;1;2370445;2570720;misteli:probe_994;1;248125293;248263553
# misteli:probe_52;1;12708719;12865743;misteli:probe_11;1;2370445;2570720
# misteli:probe_52;1;12708719;12865743;misteli:probe_74;1;18566409;18766880
# misteli:probe_52;1;12708719;12865743;misteli:probe_91;1;22223362;22394657
# misteli:probe_52;1;12708719;12865743;misteli:probe_441;1;109469002;109662490
# misteli:probe_52;1;12708719;12865743;misteli:probe_994;1;248125293;248263553
# misteli:probe_91;1;22223362;22394657;misteli:probe_74;1;18566409;18766880
# misteli:probe_385;1;96067992;96226766;misteli:probe_354;1;88222722;88418471
# misteli:probe_385;1;96067992;96226766;misteli:probe_360;1;89759075;89913486
# misteli:probe_385;1;96067992;96226766;misteli:probe_389;1;97025755;97207860
# ...
