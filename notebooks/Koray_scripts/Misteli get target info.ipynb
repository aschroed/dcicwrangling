# %%
from dcicutils import ff_utils
from functions.notebook_functions import *

# get key from file
my_key = get_key('koray_data')
# all usable env names
all_envs = ['data', 'staging', 'fourfront-webdev', 'fourfront-mastertest', 'fourfront-hotseat']
# get admin key from s3
#my_key = ff_utils.get_authentication_with_server({}, ff_env = 'data')

# %%
q = '/search/?lab.display_title=4DN+DCIC%2C+HMS&type=FileReference'
gen = ff_utils.search_metadata(q, key=my_key)
print(len(gen))

# %%
for f in gen:
    print(f['filename'])

# %%
text = """misteli:path_296_farred	misteli:path_186_red	misteli:path_89_18_green
misteli:path_193_farred	misteli:path_141_red	misteli:path_89_18_green
misteli:path_296_farred	misteli:path_186_red	misteli:path_250_green
misteli:path_163_farred	misteli:path_141_red	misteli:path_250_green
misteli:path_11_18_farred	misteli:path_89_18_red	misteli:path_250_green
misteli:path_193_farred	misteli:path_123_red	misteli:path_303_green
misteli:path_186_farred	misteli:path_163_red	misteli:path_303_green
misteli:path_141_farred	misteli:path_89_18_red	misteli:path_303_green
misteli:path_303_farred	misteli:path_250_red	misteli:path_11_18_green
misteli:path_296_farred	misteli:path_250_red	misteli:path_11_18_green
misteli:path_193_farred	misteli:path_186_red	misteli:path_11_18_green
misteli:path_163_farred	misteli:path_141_red	misteli:path_11_18_green
misteli:path_441_farred	misteli:path_11_1_red	misteli:path_52_green
misteli:path_91_farred	misteli:path_11_1_red	misteli:path_52_green
misteli:path_994_farred	misteli:path_441_red	misteli:path_52_green
misteli:path_433_farred	misteli:path_441_red	misteli:path_52_green
misteli:path_433_farred	misteli:path_255_red	misteli:path_52_green
misteli:path_994_farred	misteli:path_249_red	misteli:path_52_green
misteli:path_441_farred	misteli:path_249_red	misteli:path_52_green
misteli:path_255_farred	misteli:path_249_red	misteli:path_52_green
misteli:path_433_farred	misteli:path_91_red	misteli:path_52_green
misteli:path_255_farred	misteli:path_91_red	misteli:path_52_green
misteli:path_994_farred	misteli:path_11_1_red	misteli:path_52_green
misteli:path_249_farred	misteli:path_11_1_red	misteli:path_52_green
misteli:path_255_farred	misteli:path_232_red	misteli:path_52_green
misteli:path_254_farred	misteli:path_232_red	misteli:path_52_green
misteli:path_249_farred	misteli:path_232_red	misteli:path_52_green
misteli:path_89_1_farred	misteli:path_91_red	misteli:path_52_green
misteli:path_80_farred	misteli:path_91_red	misteli:path_52_green
misteli:path_74_farred	misteli:path_91_red	misteli:path_52_green
misteli:path_91_farred	misteli:path_11_1_red	misteli:path_52_green
misteli:path_482_farred	misteli:path_389_red	misteli:path_422_green
misteli:path_360_farred	misteli:path_389_red	misteli:path_422_green
misteli:path_482_farred	misteli:path_354_red	misteli:path_422_green
misteli:path_376_farred	misteli:path_354_red	misteli:path_422_green
misteli:path_482_farred	misteli:path_385_red	misteli:path_422_green
misteli:path_360_farred	misteli:path_385_red	misteli:path_422_green
misteli:path_354_farred	misteli:path_385_red	misteli:path_422_green
misteli:path_91_farred	misteli:path_80_red	misteli:path_52_green
misteli:path_89_1_farred	misteli:path_74_red	misteli:path_52_green
misteli:path_91_farred	misteli:path_11_1_red	misteli:path_52_green
misteli:path_389_farred	misteli:path_476_red	misteli:path_422_green
misteli:path_385_farred	misteli:path_476_red	misteli:path_422_green
misteli:path_376_farred	misteli:path_476_red	misteli:path_422_green
misteli:path_360_farred	misteli:path_476_red	misteli:path_422_green
misteli:path_354_farred	misteli:path_476_red	misteli:path_422_green
misteli:path_476_farred	misteli:path_463_red	misteli:path_422_green
misteli:path_389_farred	misteli:path_463_red	misteli:path_422_green
misteli:path_385_farred	misteli:path_463_red	misteli:path_422_green
misteli:path_376_farred	misteli:path_463_red	misteli:path_422_green
misteli:path_360_farred	misteli:path_463_red	misteli:path_422_green
misteli:path_354_farred	misteli:path_463_red	misteli:path_422_green
misteli:path_463_farred	misteli:path_476_red	misteli:path_422_green
misteli:path_389_farred	misteli:path_476_red	misteli:path_422_green
misteli:path_385_farred	misteli:path_476_red	misteli:path_422_green
misteli:path_354_farred	misteli:path_476_red	misteli:path_422_green
misteli:path_389_farred	misteli:path_463_red	misteli:path_422_green
misteli:path_385_farred	misteli:path_463_red	misteli:path_422_green
misteli:path_354_farred	misteli:path_463_red	misteli:path_422_green
misteli:path_89_1_farred	misteli:path_91_red	misteli:path_52_green
misteli:path_80_farred	misteli:path_91_red	misteli:path_52_green
misteli:path_74_farred	misteli:path_91_red	misteli:path_52_green
misteli:path_89_1_farred	misteli:path_11_1_red	misteli:path_52_green
misteli:path_80_farred	misteli:path_11_1_red	misteli:path_52_green
misteli:path_74_farred	misteli:path_11_1_red	misteli:path_52_green
misteli:path_91_farred	misteli:path_11_1_red	misteli:path_52_green
misteli:path_263_farred	misteli:path_156_red	misteli:path_121_green
misteli:path_256_farred	misteli:path_156_red	misteli:path_121_green
misteli:path_195_farred	misteli:path_156_red	misteli:path_121_green
misteli:path_40_farred	misteli:path_156_red	misteli:path_121_green
misteli:path_256_farred	misteli:path_146_red	misteli:path_121_green
misteli:path_195_farred	misteli:path_146_red	misteli:path_121_green
misteli:path_156_farred	misteli:path_146_red	misteli:path_121_green
misteli:path_263_farred	misteli:path_146_red	misteli:path_121_green
misteli:path_40_farred	misteli:path_146_red	misteli:path_121_green
misteli:path_263_farred	misteli:path_142_red	misteli:path_121_green
misteli:path_256_farred	misteli:path_142_red	misteli:path_121_green
misteli:path_195_farred	misteli:path_142_red	misteli:path_121_green
misteli:path_156_farred	misteli:path_142_red	misteli:path_121_green
misteli:path_40_farred	misteli:path_142_red	misteli:path_121_green
misteli:path_263_farred	misteli:path_156_red	misteli:path_121_green
misteli:path_256_farred	misteli:path_156_red	misteli:path_121_green
misteli:path_195_farred	misteli:path_156_red	misteli:path_121_green
misteli:path_40_farred	misteli:path_156_red	misteli:path_121_green
misteli:path_256_farred	misteli:path_146_red	misteli:path_121_green
misteli:path_195_farred	misteli:path_146_red	misteli:path_121_green
misteli:path_156_farred	misteli:path_146_red	misteli:path_121_green
misteli:path_263_farred	misteli:path_146_red	misteli:path_121_green
misteli:path_40_farred	misteli:path_146_red	misteli:path_121_green
misteli:path_263_farred	misteli:path_142_red	misteli:path_121_green
misteli:path_256_farred	misteli:path_142_red	misteli:path_121_green
misteli:path_195_farred	misteli:path_142_red	misteli:path_121_green
misteli:path_156_farred	misteli:path_142_red	misteli:path_121_green
misteli:path_40_farred	misteli:path_142_red	misteli:path_121_green
misteli:path_86_farred	misteli:path_133_red	misteli:path_123_green
misteli:path_206_farred	misteli:path_133_red	misteli:path_123_green
misteli:path_278_farred	misteli:path_133_red	misteli:path_123_green
misteli:path_86_farred	misteli:path_156_red	misteli:path_123_green
misteli:path_206_farred	misteli:path_156_red	misteli:path_123_green
misteli:path_278_farred	misteli:path_156_red	misteli:path_123_green
misteli:path_86_farred	misteli:path_146_red	misteli:path_123_green
misteli:path_133_farred	misteli:path_146_red	misteli:path_123_green
misteli:path_206_farred	misteli:path_146_red	misteli:path_123_green
misteli:path_278_farred	misteli:path_146_red	misteli:path_123_green
misteli:path_133_farred	misteli:path_142_red	misteli:path_123_green
misteli:path_86_farred	misteli:path_142_red	misteli:path_123_green
misteli:path_206_farred	misteli:path_142_red	misteli:path_123_green
misteli:path_278_farred	misteli:path_142_red	misteli:path_123_green
misteli:path_206_farred	misteli:path_263_red	misteli:path_123_green
misteli:path_278_farred	misteli:path_263_red	misteli:path_123_green
misteli:path_142_farred	misteli:path_133_red	misteli:path_123_green
misteli:path_40_farred	misteli:path_86_red	misteli:path_123_green
misteli:path_206_farred	misteli:path_142_red	misteli:path_123_green
misteli:path_142_farred	misteli:path_146_red	misteli:path_123_green
misteli:path_156_farred	misteli:path_146_red	misteli:path_123_green
misteli:path_206_farred	misteli:path_278_red	misteli:path_123_green
misteli:path_278_farred	misteli:path_195_red	misteli:path_123_green
misteli:path
red	misteli:path_607_green	misteli:path_618_farred
misteli:path_613_red	misteli:path_607_green	misteli:path_618_farred
misteli:path_613_red	misteli:path_607_green	misteli:path_614_5_farred
misteli:path_610_red	misteli:path_607_green	misteli:path_618_farred
misteli:path_610_red	misteli:path_607_green	misteli:path_614_5_farred
misteli:path_610_red	misteli:path_607_green	misteli:path_613_farred
misteli:path_607_red	misteli:path_607_green	misteli:path_607_farred
misteli:path_224_red	misteli:path_224_green	misteli:path_224_farred
misteli:path_609_red	misteli:path_607_green	misteli:path_610_farred
misteli:path_611_red	misteli:path_613_green	misteli:path_610_farred
misteli:path_614_red	misteli:path_613_green	misteli:path_614_5_farred
misteli:path_617_red	misteli:path_616_green	misteli:path_618_farred
misteli:path_221_red	misteli:path_220_green	misteli:path_222_farred
misteli:path_223_red	misteli:path_224_green	misteli:path_222_farred
misteli:path_225_red	misteli:path_224_green	misteli:path_225_5_farred
misteli:path_226_red	misteli:path_226_5_green	misteli:path_225_5_farred
misteli:path_227_red	misteli:path_226_5_green	misteli:path_228_farred
misteli:path_225_red	misteli:path_220_green	misteli:path_228_farred
misteli:path_614_red	misteli:path_607_green	misteli:path_618_farred
misteli:path_226_red	misteli:path_224_green	misteli:path_228_farred
misteli:path_610_red	misteli:path_610_green	misteli:path_610_farred
misteli:path_616_red	misteli:path_614_5_green	misteli:path_618_farred
misteli:path_615_red	misteli:path_614_green	misteli:path_617_farred
misteli:path_615_red	misteli:path_613_green	misteli:path_614_5_farred
misteli:path_616_red	misteli:path_613_green	misteli:path_617_farred
misteli:path_614_red	misteli:path_613_green	misteli:path_618_farred
misteli:path_613_red	misteli:path_610_green	misteli:path_614_farred
misteli:path_617_red	misteli:path_609_green	misteli:path_618_farred
misteli:path_615_red	misteli:path_609_green	misteli:path_616_farred
misteli:path_613_red	misteli:path_609_green	misteli:path_614_5_farred
misteli:path_611_red	misteli:path_609_green	misteli:path_614_farred
misteli:path_614_red	misteli:path_607_green	misteli:path_614_5_farred
misteli:path_611_red	misteli:path_607_green	misteli:path_613_farred
misteli:path_609_red	misteli:path_607_green	misteli:path_610_farred
misteli:path_613_red	misteli:path_613_green	misteli:path_613_farred
misteli:path_611_red	misteli:path_611_green	misteli:path_611_farred
misteli:path_614_red	misteli:path_609_green	misteli:path_616_farred
misteli:path_611_red	misteli:path_609_green	misteli:path_616_farred
misteli:path_611_red	misteli:path_609_green	misteli:path_614_farred
misteli:path_223_red	misteli:path_223_green	misteli:path_231_farred
misteli:path_227_red	misteli:path_222_green	misteli:path_228_farred
misteli:path_226_red	misteli:path_222_green	misteli:path_231_farred
misteli:path_224_red	misteli:path_222_green	misteli:path_225_farred
misteli:path_223_red	misteli:path_222_green	misteli:path_225_5_farred
misteli:path_227_red	misteli:path_221_green	misteli:path_231_farred
misteli:path_226_red	misteli:path_221_green	misteli:path_228_farred
misteli:path_224_red	misteli:path_221_green	misteli:path_225_5_farred
misteli:path_223_red	misteli:path_221_green	misteli:path_225_farred
misteli:path_228_red	misteli:path_220_green	misteli:path_231_farred
misteli:path_226_red	misteli:path_220_green	misteli:path_227_farred
misteli:path_225_red	misteli:path_220_green	misteli:path_225_5_farred
misteli:path_223_red	misteli:path_220_green	misteli:path_224_farred
misteli:path_221_red	misteli:path_220_green	misteli:path_222_farred
misteli:path_614_5_red	misteli:path_609_green	misteli:path_617_farred
misteli:path_610_red	misteli:path_609_green	misteli:path_615_farred
misteli:path_611_red	misteli:path_609_green	misteli:path_616_farred
misteli:path_610_red	misteli:path_607_green	misteli:path_618_farred
misteli:path_616_red	misteli:path_607_green	misteli:path_618_farred
misteli:path_609_red	misteli:path_607_green	misteli:path_611_farred
misteli:path_610_red	misteli:path_607_green	misteli:path_614_5_farred
misteli:path_615_red	misteli:path_607_green	misteli:path_617_farred
misteli:path_611_red	misteli:path_611_green	misteli:path_611_farred
misteli:path_615_red	misteli:path_611_green	misteli:path_618_farred
misteli:path_614_5_red	misteli:path_611_green	misteli:path_616_farred
misteli:path_616_red	misteli:path_610_green	misteli:path_618_farred
misteli:path_611_red	misteli:path_610_green	misteli:path_617_farred
misteli:path_614_5_red	misteli:path_609_green	misteli:path_618_farred
misteli:path_249	misteli:path_11	misteli:path_52
misteli:path_89	misteli:path_11	misteli:path_52
misteli:path_80	misteli:path_11	misteli:path_52
misteli:path_74	misteli:path_11	misteli:path_52
misteli:path_91	misteli:path_11	misteli:path_52"""

text2 = []
for i in text.split('\n'):
    text2.extend(i.split('\t'))
print(len(text2))
text3 = list(set(text2))
print(len(text3))
# Out:
# 771
# 146

# %%
target_uuids = []
for i in text3:
    path_resp = ff_utils.get_metadata(i,key=my_key)
    target = path_resp['target'][0]['uuid']
    target_uuids.append(target)
print(len(target_uuids))
un_target = list(set(target_uuids))
print(len(un_target))
# Out:
# 146
# 71

# %%
n_target = ['misteli:path_226_5_green']
for i in n_target:
    tg_resp = ff_utils.get_metadata(i, key=my_key)
    for i in tg_resp:
        print(i)
        print(tg_resp[i])
    tg = tg_resp['targeted_genome_regions'][0]
    try:
        prb_no = tg['aliases'][0].split('probe_')[1]
    except:
        prb_no = ""
    try:
        liste = [tg['aliases'][0], str(tg['chromosome']), str(tg['start_coordinate']), str(tg['end_coordinate']), prb_no]
        print(','.join(liste))
    except:
        print(tg)
# Out:
# labels
# ['Alexa488']
# external_references
# []
# link_id
# ~imaging-paths~672003e8-81a8-427b-b95a-80f9f5322d32~
# audit
# {}
# description
# 226_5
# display_title
# GRCh38:4 targeted by Alexa488-labeled BAC
# last_modified
# {'date_modified': '2018-08-03T13:08:19.471431+00:00', 'modified_by': {'uuid': 'd1f45a59-b6e2-4559-8ed8-3d86358367a8', 'principals_allowed': {'audit': ['system.Everyone'], 'edit': ['group.admin', 'userid.d1f45a59-b6e2-4559-8ed8-3d86358367a8'], 'view': ['group.admin', 'group.read-only-admin', 'remoteuser.EMBED', 'remoteuser.INDEXER', 'userid.d1f45a59-b6e2-4559-8ed8-3d86358367a8']}, '@id': '/users/d1f45a59-b6e2-4559-8ed8-3d86358367a8/', 'link_id': '~users~d1f45a59-b6e2-4559-8ed8-3d86358367a8~', 'display_title': 'Gianluca Pegoraro'}}
# @context
# /terms/
# status
# in review by lab
# uuid
# 672003e8-81a8-427b-b95a-80f9f5322d32
# award
# ...
